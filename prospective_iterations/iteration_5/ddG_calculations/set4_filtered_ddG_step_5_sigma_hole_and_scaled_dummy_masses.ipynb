# %%
import pmx
from pmx.utils import create_folder
from pmx import gmx, ligand_alchemy, jobscript
import sys
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline 
# %pylab inline
from IPython.core.display import clear_output
import os,shutil
import re
import subprocess
import glob
import random
import pandas as pd
import importlib
if 'AZtutorial' in sys.modules:
    importlib.reload(sys.modules['AZtutorial'])
else:
    import AZtutorial
from AZtutorial import *
from IPython.display import Image


from rdkit import Chem
from rdkit.Chem import AllChem, Draw, Descriptors, rdmolfiles, rdMolAlign, rdmolops, rdchem, PyMol, Crippen, PropertyMol
from rdkit import DataStructs
from rdkit import RDLogger

from rdkit.Chem.Draw import IPythonConsole
from rdkit.Geometry import Point3D
from rdkit.Numerics.rdAlignment import GetAlignmentTransform
from rdkit.Chem.AtomPairs import Pairs
from rdkit import DataStructs
from rdkit.Chem import MACCSkeys
from rdkit.Chem import rdFMCS
from rdkit.Chem import rdMolTransforms
from tqdm import tqdm
from copy import deepcopy

try:
    import cPickle as pickle
except:
    import pickle
import os
from contextlib import contextmanager,redirect_stderr,redirect_stdout
from os import devnull


@contextmanager
def suppress_stdout_stderr():
    """A context manager that redirects stdout and stderr to devnull"""
    with open(devnull, 'w') as fnull:
        with redirect_stderr(fnull) as err, redirect_stdout(fnull) as out:
            yield (err, out)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # Step -3. Set up paths for the workflow

# %%
# initialize the free energy environment object: it will store the main parameters for the calculations
fe = AZtutorial( )

# set the workpath
fe.workPath = 'workpath'
# set the path to the molecular dynamics parameter files
fe.mdpPath = 'input/mdppath'
# set the number of replicas (several repetitions of calculation are useful to obtain reliable statistics)
fe.replicas = 3
# provide the path to the protein structure and topology
fe.proteinPath = 'input/protein_amber'
# provide the path to the folder with ligand structures and topologies
fe.ligandPath = 'input/ligands'


os.environ['GMXLIB'] = "/home/ykhalak/private/gmx_share_top_w_new_vdwradii"

# %%
! echo $GMXLIB
# Out:
# /home/ykhalak/private/gmx_share_top_w_new_vdwradii

# %%
! which gmx
# Out:
# /usr/local/gromacs/2021/2021-impi2017-fftw337-gcc93-cuda11.1-fix3943/bin/gmx

# %% [markdown]
# # Step -2. Select ligands

# %%
training_ligand_databse_fn="/home/ykhalak/Projects/ML_dG/pde2_dG/how_do_ligs_fit_in_pocket_4d09_protein/processed_69_cl13_ligs_in_4d09_for_ddG_calc.pickle"
with open(training_ligand_databse_fn, 'rb') as f:
    training_ligs = pickle.load(f)

reference_lig_name="JAN_PDE2_1345"
for i,l in enumerate(training_ligs):
    if(reference_lig_name in l.GetProp("ID")):
        print(i)
        reference_lig_id=i
        
reference_lig=training_ligs[reference_lig_id]

del training_ligand_databse_fn,training_ligs
import gc
gc.collect()
# Out:
# 54
# 0

# %%
folder="/home/ykhalak/Projects/ML_dG/pde2_dG/generators/structures/set_4"
pocket_fit_folder=f"{folder}/morphing_annealing_4d09_filtered_subset/"

with open(pocket_fit_folder+"/step_5_picks.pickle", 'rb') as f:
    test_ligs = pickle.load(f)

# %%
Draw.MolsToGridImage(test_ligs+[reference_lig],
                     legends=[l.GetProp("ID") for l in test_ligs+[reference_lig]],
                     subImgSize = (400,400), molsPerRow=5, maxMols=101)

# %% [markdown]
# # Step -1. Properly parametrize ligands

# %%
# parametrize in parallel
from multiprocessing import Process, Queue, Pool, TimeoutError, Lock

mp_lock = Lock()
cur_folder=os.path.abspath(os.getcwd())

def mp_worker(mol):
    mp_lock.acquire()
    print(mol.GetProp('ID'),"\t starting in process", os.getpid())
    mp_lock.release()
    
    mol_folder=f"{fe.ligandPath}/lig_{mol.GetProp('ID')}/"
    os.makedirs(mol_folder, exist_ok=True)
    
    mol_pdb=f"{mol_folder}/mol_gmx.pdb"
    if(not os.path.exists(mol_pdb)):
        with open(mol_pdb,"w") as f:
            f.write(rdmolfiles.MolToPDBBlock(mol))
            
    mol_itp=mol_folder+"/MOL.acpype/MOL_GMX.itp"
    if(not os.path.exists(mol_itp)):
        mol_file=mol_folder+"/MOL.mol"
        rdmolfiles.MolToMolFile(mol, mol_file)

        #find total charge
        totQ=rdmolops.GetFormalCharge(mol)

        #acpype
        os.chdir(mol_folder)
        mol_file = "MOL.mol"
        process = subprocess.Popen(['acpype', '-i', mol_file, '-a', 'gaff', '-c', 'bcc', '-b', "MOL", '-n', repr(totQ)],
                    stdout=subprocess.PIPE,
                    stderr=subprocess.PIPE)
        process.wait()
#         out=process.stdout.read().decode("utf-8")
#         err=process.stderr.read().decode("utf-8")
#         print(out)
#         print(err)

        os.system("sed '/\\[ moleculetype \\]/Q' MOL.acpype/MOL_GMX.itp > ffMOL.itp 2>&1")
        os.system("sed -n '/\\[ moleculetype \\]/,$p' MOL.acpype/MOL_GMX.itp > MOL.itp  2>&1")

#         #make sigmahole versions
#         os.system("python /home/ykhalak/custom_scripts/sigmahole.py -itp MOL.itp -pdb mol_gmx.pdb -ffitp ffMOL.itp"+\
#                   " -oitp MOL_sigmahole.itp -offitp ffMOL_sigmahole.itp -opdb mol_sigmahole.pdb"+\
#                   " -ff gaff -rule ibrahim 2>&1")

        os.chdir(cur_folder)
        
        mp_lock.acquire()
        if(not os.path.exists(mol_itp)):
            print(mol.GetProp('ID'),"\t parametrization failed.")
        else:
            print(mol.GetProp('ID'),"\t done parametrizing")
        mp_lock.release()
#         break;
    else:
        mp_lock.acquire()
        print(mol.GetProp('ID'),"\t previously done")
        mp_lock.release()
        
use_cores=4
with Pool(processes=use_cores) as pool:
    res=pool.map(mp_worker, test_ligs+[reference_lig])

print("Now the pool is closed and no longer available")
# Out:
# set4_190778 	 starting in process 11134
# set4_122463 	 starting in process 11135
# set4_190844 	 starting in process 11136
# set4_73375 	 starting in process 11137
# set4_73375 	 done parametrizing
# set4_204549 	 starting in process 11137
# set4_190844 	 done parametrizing
# set4_73008 	 starting in process 11136
# set4_190778 	 done parametrizing
# set4_240291 	 starting in process 11134
# set4_122463 	 done parametrizing
# set4_71401 	 starting in process 11135
# set4_204549 	 done parametrizing
# set4_122460 	 starting in process 11137
# set4_71401 	 done parametrizing
# set4_73883 	 starting in process 11135
# set4_73883 	 done parametrizing
# set4_202087 	 starting in process 11135
# set4_73008 	 done parametrizing
# set4_316733 	 starting in process 11136
# set4_202087 	 done parametrizing
# set4_357530 	 starting in process 11135
# set4_240291 	 done parametrizing
# set4_204497 	 starting in process 11134
# set4_316733 	 done parametrizing
# set4_287307 	 starting in process 11136
# set4_204497 	 done parametrizing
# set4_121483 	 starting in process 11134
# set4_122460 	 done parametrizing
# set4_315931 	 starting in process 11137
# set4_357530 	 done parametrizing
# set4_46560 	 starting in process 11135
# set4_121483 	 done parametrizing
# set4_190914 	 starting in process 11134
# set4_46560 	 done parametrizing
# set4_72639 	 starting in process 11135
# set4_287307 	 done parametrizing
# set4_9233 	 starting in process 11136
# set4_9233 	 done parametrizing
# set4_239416 	 starting in process 11136
# set4_315931 	 done parametrizing
# set4_46739 	 starting in process 11137
# set4_239416 	 done parametrizing
# set4_49417 	 starting in process 11136
# set4_46739 	 done parametrizing
# set4_44746 	 starting in process 11137
# set4_72639 	 done parametrizing
# set4_318412 	 starting in process 11135
# set4_44746 	 done parametrizing
# set4_190886 	 starting in process 11137
# set4_49417 	 done parametrizing
# set4_72643 	 starting in process 11136
# set4_190914 	 done parametrizing
# set4_314311 	 starting in process 11134
# set4_318412 	 done parametrizing
# set4_200839 	 starting in process 11135
# set4_72643 	 done parametrizing
# set4_186054 	 starting in process 11136
# set4_200839 	 done parametrizing
# set4_204487 	 starting in process 11135
# set4_186054 	 done parametrizing
# set4_72600 	 starting in process 11136
# set4_314311 	 done parametrizing
# set4_39459 	 starting in process 11134
# set4_190886 	 done parametrizing
# set4_73813
#  	 starting in process 11137set4_72600 	 done parametrizing
# set4_188271 	 starting in process 11136
# set4_204487 	 done parametrizing
# set4_200519 	 starting in process 11135
# set4_39459 	 done parametrizing
# set4_73153 	 starting in process 11134
# set4_188271 	 done parametrizing
# set4_73007 	 starting in process 11136
# set4_73813 	 done parametrizing
# set4_121481 	 starting in process 11137
# set4_200519 	 done parametrizing
# set4_204450 	 starting in process 11135
# set4_204450 	 done parametrizing
# set4_190882 	 starting in process 11135
# set4_73153 	 done parametrizing
# set4_318340 	 starting in process 11134
# set4_73007 	 done parametrizing
# set4_26471 	 starting in process 11136
# set4_318340 	 done parametrizing
# set4_71992 	 starting in process 11134
# set4_26471 	 done parametrizing
# set4_190807 	 starting in process 11136
# set4_71992 	 done parametrizing
# set4_121458 	 starting in process 11134
# set4_121481 	 done parametrizing
# set4_73724 	 starting in process 11137
# set4_190882 	 done parametrizing
# set4_122489 	 starting in process 11135
# set4_190807 	 done parametrizing
# set4_204316 	 starting in process 11136
# set4_73724 	 done parametrizing
# set4_49347 	 starting in process 11137
# set4_204316 	 done parametrizing
# set4_315054 	 starting in process 11136
# set4_49347 	 done parametrizing
# set4_204435 	 starting in process 11137
# set4_122489 	 done parametrizing
# set4_186899 	 starting in process 11135
# set4_204435 	 done parametrizing
# set4_316574 	 starting in process 11137
# set4_315054 	 done parametrizing
# set4_7468 	 starting in process 11136
# set4_121458 	 done parametrizing
# set4_287108 	 starting in process 11134
# set4_186899 	 done parametrizing
# set4_122477 	 starting in process 11135
# set4_287108 	 done parametrizing
# set4_287305 	 starting in process 11134
# set4_7468 	 done parametrizing
# set4_121456 	 starting in process 11136
# set4_287305 	 done parametrizing
# set4_358538 	 starting in process 11134
# set4_121456 	 done parametrizing
# set4_204440 	 starting in process 11136
# set4_316574 	 done parametrizing
# set4_187035 	 starting in process 11137
# set4_122477 	 done parametrizing
# set4_316584 	 starting in process 11135
# set4_204440 	 done parametrizing
# set4_315055 	 starting in process 11136
# set4_358538 	 done parametrizing
# set4_12907 	 starting in process 11134
# set4_316584 	 done parametrizing
# set4_122492 	 starting in process 11135
# set4_187035 	 done parametrizing
# set4_315639 	 starting in process 11137
# set4_12907 	 done parametrizing
# set4_358553 	 starting in process 11134
# set4_315055 	 done parametrizing
# set4_200493 	 starting in process 11136
# set4_315639 	 done parametrizing
# set4_117342 	 starting in process 11137
# set4_358553 	 done parametrizing
# set4_237843 	 starting in process 11134
# set4_200493 	 done parametrizing
# set4_240139 	 starting in process 11136
# set4_240139 	 done parametrizing
# set4_190853 	 starting in process 11136
# set4_237843 	 done parametrizing
# set4_49395 	 starting in process 11134
# set4_122492 	 done parametrizing
# set4_240165 	 starting in process 11135
# set4_190853 	 done parametrizing
# set4_73446 	 starting in process 11136
# set4_117342 	 done parametrizing
# set4_240197 	 starting in process 11137
# set4_240165 	 done parametrizing
# set4_73781 	 starting in process 11135
# set4_49395 	 done parametrizing
# set4_120342 	 starting in process 11134
# set4_240197 	 done parametrizing
# set4_376385 	 starting in process 11137
# set4_73781 	 done parametrizing
# set4_1830 	 starting in process 11135
# set4_376385 	 done parametrizing
# set4_204476 	 starting in process 11137
# set4_120342 	 done parametrizing
# set4_46563 	 starting in process 11134
# set4_1830 	 done parametrizing
# set4_287279 	 starting in process 11135
# set4_46563 	 done parametrizing
# set4_297010 	 starting in process 11134
# set4_73446 	 done parametrizing
# set4_190819 	 starting in process 11136
# set4_204476 	 done parametrizing
# set4_282491 	 starting in process 11137
# set4_297010 	 done parametrizing
# set4_287340 	 starting in process 11134
# set4_287279 	 done parametrizing
# set4_204510 	 starting in process 11135
# set4_190819 	 done parametrizing
# set4_200833 	 starting in process 11136
# set4_200833 	 done parametrizing
# set4_295347 	 starting in process 11136
# set4_287340 	 done parametrizing
# set4_12308 	 starting in process 11134
# set4_204510 	 done parametrizing
# set4_7467 	 starting in process 11135
# set4_282491 	 done parametrizing
# set4_48416 	 starting in process 11137
# set4_295347 	 done parametrizing
# set4_28055 	 starting in process 11136
# set4_12308 	 done parametrizing
# JAN_PDE2_1345 	 starting in process 11134
# set4_48416 	 done parametrizing
# JAN_PDE2_1345 	 done parametrizing
# set4_28055 	 done parametrizing
# set4_7467 	 done parametrizing
# set4_49408 	 starting in process 11135
# set4_49408 	 done parametrizing
# set4_318271 	 starting in process 11135
# set4_318271 	 done parametrizing
# set4_7276 	 starting in process 11135
# set4_7276 	 done parametrizing
# set4_43306 	 starting in process 11135
# set4_43306 	 done parametrizing
# Now the pool is closed and no longer available

# %%
# parametrize in parallel
from multiprocessing import Process, Queue, Pool, TimeoutError, Lock

mp_lock = Lock()
cur_folder=os.path.abspath(os.getcwd())

def mp_worker(mol):
#     mp_lock.acquire()
    print(mol.GetProp('ID'),"\t starting in process", os.getpid())
#     mp_lock.release()
    
    mol_folder=f"{fe.ligandPath}/lig_{mol.GetProp('ID')}/"
    os.makedirs(mol_folder, exist_ok=True)
            
    mol_sigmahole_itp=mol_folder+"/MOL_sigmahole.itp"
    if(not os.path.exists(mol_sigmahole_itp)):
        mol_file=mol_folder+"/MOL.mol"
        rdmolfiles.MolToMolFile(mol, mol_file)

        #find total charge
        totQ=rdmolops.GetFormalCharge(mol)

        #acpype
        os.chdir(mol_folder)
        
        #make sigmahole versions
        os.system("python /home/ykhalak/custom_scripts/sigmahole.py -itp MOL.itp -pdb mol_gmx.pdb -ffitp ffMOL.itp"+\
                  " -oitp MOL_sigmahole.itp -offitp ffMOL_sigmahole.itp -opdb mol_sigmahole.pdb"+\
                  f" -q {totQ} -ff gaff -rule ibrahim 2>&1")

        os.chdir(cur_folder)
        
#         mp_lock.acquire()
        if(not os.path.exists(mol_sigmahole_itp)):
            print(mol.GetProp('ID'),"\t parametrization failed.")
        else:
            print(mol.GetProp('ID'),"\t done parametrizing")
#         mp_lock.release()
#         break;
    else:
#         mp_lock.acquire()
        print(mol.GetProp('ID'),"\t previously done")
#         mp_lock.release()
        
use_cores=4
with Pool(processes=use_cores) as pool:
    res=pool.map(mp_worker, test_ligs+[reference_lig])
# Out:
# set4_190778 	 starting in process set4_12246326554
# 	 starting in processset4_190844 	 starting in process
# 26555
# set4_73375 	 starting in process 2655726556
# set4_122463 	 done parametrizing
# set4_71401 	 starting in process 26555
# set4_190778 	 done parametrizing
# set4_240291 	 starting in process 26554
# set4_73375set4_190844  	 done parametrizing	 done parametrizing
# set4_204549
# set4_73008 	 starting in process  	 starting in process26557
# 26556
# set4_71401 	 done parametrizing
# set4_73883 	 starting in process 26555
# set4_204549 	 done parametrizing
# set4_122460 	 starting in process 26557
# set4_240291set4_73008 	 done parametrizing
# set4_316733 	 starting in process 26556
#  	 done parametrizing
# set4_204497 	 starting in process 26554
# set4_73883 	 done parametrizing
# set4_202087 	 starting in process 26555
# set4_204497 	 done parametrizing
# set4_121483 	 starting in process 26554
# set4_316733 	 done parametrizing
# set4_287307 set4_122460 	 starting in process	 done parametrizing
#  set4_31593126556
# 	 starting in process 26557
# set4_202087set4_121483  	 done parametrizing	 done parametrizing
# set4_357530 	 starting in process 26555
#
# set4_190914 	 starting in process 26554
# set4_287307 	 done parametrizing
# set4_9233 	 starting in process 26556
# set4_315931 	 done parametrizing
# set4_46739 	 starting in process 26557
# set4_357530 	 done parametrizing
# set4_46560 	 starting in process 26555
# set4_190914 	 done parametrizing
# set4_314311 	 starting in process 26554
# set4_46739 	 done parametrizing
# set4_44746 	 starting in process 26557
# set4_9233 	 done parametrizing
# set4_239416 	 starting in process 26556
# set4_46560 set4_314311	 done parametrizing
# 	 done parametrizingset4_72639
# set4_39459  	 starting in process	 starting in process  26555
# 26554
# set4_239416 	 done parametrizing
# set4_49417 	 starting in process 26556
# set4_44746 	 done parametrizing
# set4_190886 	 starting in process 26557
# set4_72639 set4_39459	 done parametrizing
# set4_318412	 done parametrizing
# 	 starting in processset4_72643  26555	 starting in process
#  26554
# set4_190886 	 done parametrizing
# set4_73813 set4_49417 	 starting in process	 done parametrizing
#  26557set4_73153
# 	 starting in process 26556
# set4_318412 	 done parametrizing
# set4_200839 	 starting in process 26555
# set4_72643 	 done parametrizing
# set4_186054 	 starting in process 26554
# set4_73813 	 done parametrizing
# set4_121481 	 starting in process 26557
# set4_73153 	 done parametrizing
# set4_318340 	 starting in process 26556
# set4_121481 	 done parametrizing
# set4_73724 	 starting in process 26557
# set4_200839 	 done parametrizing
# set4_204487 	 starting in process 26555
# set4_186054 	 done parametrizing
# set4_72600 	 starting in process 26554
# set4_318340 	 done parametrizing
# set4_71992 	 starting in process 26556
# set4_204487 	 done parametrizing
# set4_200519 	 starting in process 26555
# set4_72600 	 done parametrizing
# set4_188271 	 starting in process 26554
# set4_73724 	 done parametrizing
# set4_49347 	 starting in process 26557
# set4_71992 	 done parametrizing
# set4_121458 	 starting in process 26556
# set4_188271 	 done parametrizing
# set4_73007 	 starting in process 26554
# set4_49347 	 done parametrizing
# set4_204435 	 starting in process 26557
# set4_121458 	 done parametrizing
# set4_287108 	 starting in process 26556
# set4_200519 	 done parametrizing
# set4_204450 	 starting in process 26555
# set4_204435 	 done parametrizing
# set4_316574 	 starting in process 26557
# set4_73007 	 done parametrizing
# set4_26471 	 starting in process 26554
# set4_287108 	 done parametrizing
# set4_287305 	 starting in process 26556
# set4_204450 	 done parametrizing
# set4_190882 	 starting in process 26555
# set4_316574 	 done parametrizing
# set4_187035 	 starting in process 26557
# set4_190882 	 done parametrizing
# set4_122489 	 starting in process 26555
# set4_26471 	 done parametrizing
# set4_190807 	 starting in process 26554
# set4_287305 	 done parametrizing
# set4_358538 	 starting in process 26556
# set4_187035 	 done parametrizing
# set4_204316 	 starting in process 26557
# set4_190807 	 done parametrizing
# set4_186899 	 starting in process 26554
# set4_122489 	 done parametrizing
# set4_12907 	 starting in process 26555
# set4_358538 	 done parametrizing
# set4_315639 	 starting in process 26556
# set4_204316 	 done parametrizing
# set4_315054 	 starting in process 26557
# set4_186899 	 done parametrizing
# set4_122477 	 starting in process 26554
# set4_315639 	 done parametrizing
# set4_117342 	 starting in process 26556
# set4_12907 	 done parametrizing
# set4_358553 	 starting in process 26555
# set4_122477 	 done parametrizing
# set4_316584 	 starting in process 26554
# set4_315054 	 done parametrizing
# set4_7468 	 starting in process 26557
# set4_117342 	 done parametrizing
# set4_240197 	 starting in process 26556
# set4_358553 	 done parametrizing
# set4_237843 	 starting in process 26555
# set4_316584 	 done parametrizing
# set4_122492 	 starting in process 26554
# set4_7468 	 done parametrizing
# set4_121456 	 starting in process 26557
# set4_240197 	 done parametrizing
# set4_376385 	 starting in process 26556
# set4_237843 	 done parametrizing
# set4_49395 	 starting in process 26555
# set4_122492 	 done parametrizing
# set4_240165 	 starting in process 26554
# set4_121456 	 done parametrizing
# set4_204440 	 starting in process 26557
# set4_376385 	 done parametrizing
# set4_204476 	 starting in process 26556
# set4_49395 	 done parametrizing
# set4_120342 	 starting in process 26555
# set4_204440 	 done parametrizing
# set4_315055 	 starting in process set4_20447626557
#  	 done parametrizing
# set4_282491 	 starting in process 26556
# set4_120342 	 done parametrizing
# set4_46563 	 starting in process 26555
# set4_240165 	 done parametrizing
# set4_73781 	 starting in process 26554
# set4_315055 	 done parametrizing
# set4_200493 	 starting in process 26557
# set4_46563 	 done parametrizing
# set4_297010 	 starting in process 26555
# set4_282491 	 done parametrizing
# set4_48416 	 starting in process 26556
# set4_73781 	 done parametrizing
# set4_1830 	 starting in process 26554
# set4_200493 	 done parametrizing
# set4_240139 	 starting in process 26557
# set4_297010 	 done parametrizing
# set4_287279 	 starting in process 26555
# set4_1830 	 done parametrizing
# set4_287340set4_48416  	 starting in process	 done parametrizing
# 26554
# set4_240139 	 done parametrizing
# set4_190853 	 starting in process 26557
# set4_287279 	 done parametrizing
# set4_204510 	 starting in process 26555
# set4_287340 	 done parametrizing
# set4_12308 	 starting in process 26554
# set4_204510 	 done parametrizing
# set4_7467 	 starting in process 26555
# set4_190853 	 done parametrizing
# set4_73446 	 starting in process 26557
# set4_12308 	 done parametrizing
# JAN_PDE2_1345 	 starting in process 26554
# set4_7467 	 done parametrizing
# set4_49408 	 starting in process 26555
# set4_73446 	 done parametrizing
# set4_190819 	 starting in process 26557
# JAN_PDE2_1345 	 done parametrizing
# set4_49408 	 done parametrizing
# set4_318271 	 starting in process 26555
# set4_190819 	 done parametrizing
# set4_200833 	 starting in process 26557
# set4_318271 	 done parametrizing
# set4_7276 	 starting in process 26555
# set4_200833 	 done parametrizing
# set4_295347 	 starting in process 26557
# set4_7276 	 done parametrizing
# set4_43306 	 starting in process 26555
# set4_295347 	 done parametrizing
# set4_28055 	 starting in process 26557
# set4_43306 	 done parametrizing
# set4_28055 	 done parametrizing

# %% [markdown]
# ----------------
# Step 0. Initialize working environment
# -----------------
#
# Here, we will define the paths to the protein and ligand topologies, as well as to the molecular dynamics parameter files (.mdp).
#
# We will also set some main parameters: water model, salt concentration, number of simulation replicas to use.

# %%
# provide edges
fe.edges = [ [reference_lig.GetProp('ID'), mol.GetProp('ID')] for mol in test_ligs]
fe.simTypes = ['em','eq_posre','eq','transitions']
#fe.simTypes = ['em','eq','transitions']

# finally, let's prepare the overall free energy calculation directory structure
fe.prepareFreeEnergyDir( )
# Out:
# edge_JAN_PDE2_1345_set4_190778
# edge_JAN_PDE2_1345_set4_240291
# edge_JAN_PDE2_1345_set4_204497
# edge_JAN_PDE2_1345_set4_121483
# edge_JAN_PDE2_1345_set4_190914
# edge_JAN_PDE2_1345_set4_314311
# edge_JAN_PDE2_1345_set4_39459
# edge_JAN_PDE2_1345_set4_122463
# edge_JAN_PDE2_1345_set4_71401
# edge_JAN_PDE2_1345_set4_73883
# edge_JAN_PDE2_1345_set4_202087
# edge_JAN_PDE2_1345_set4_357530
# edge_JAN_PDE2_1345_set4_46560
# edge_JAN_PDE2_1345_set4_72639
# edge_JAN_PDE2_1345_set4_190844
# edge_JAN_PDE2_1345_set4_73008
# edge_JAN_PDE2_1345_set4_316733
# edge_JAN_PDE2_1345_set4_287307
# edge_JAN_PDE2_1345_set4_9233
# edge_JAN_PDE2_1345_set4_239416
# edge_JAN_PDE2_1345_set4_49417
# edge_JAN_PDE2_1345_set4_73375
# edge_JAN_PDE2_1345_set4_204549
# edge_JAN_PDE2_1345_set4_122460
# edge_JAN_PDE2_1345_set4_315931
# edge_JAN_PDE2_1345_set4_46739
# edge_JAN_PDE2_1345_set4_44746
# edge_JAN_PDE2_1345_set4_190886
# edge_JAN_PDE2_1345_set4_318412
# edge_JAN_PDE2_1345_set4_200839
# edge_JAN_PDE2_1345_set4_204487
# edge_JAN_PDE2_1345_set4_200519
# edge_JAN_PDE2_1345_set4_204450
# edge_JAN_PDE2_1345_set4_190882
# edge_JAN_PDE2_1345_set4_122489
# edge_JAN_PDE2_1345_set4_72643
# edge_JAN_PDE2_1345_set4_186054
# edge_JAN_PDE2_1345_set4_72600
# edge_JAN_PDE2_1345_set4_188271
# edge_JAN_PDE2_1345_set4_73007
# edge_JAN_PDE2_1345_set4_26471
# edge_JAN_PDE2_1345_set4_190807
# edge_JAN_PDE2_1345_set4_73813
# edge_JAN_PDE2_1345_set4_121481
# edge_JAN_PDE2_1345_set4_73724
# edge_JAN_PDE2_1345_set4_49347
# edge_JAN_PDE2_1345_set4_204435
# edge_JAN_PDE2_1345_set4_316574
# edge_JAN_PDE2_1345_set4_187035
# edge_JAN_PDE2_1345_set4_73153
# edge_JAN_PDE2_1345_set4_318340
# edge_JAN_PDE2_1345_set4_71992
# edge_JAN_PDE2_1345_set4_121458
# edge_JAN_PDE2_1345_set4_287108
# edge_JAN_PDE2_1345_set4_287305
# edge_JAN_PDE2_1345_set4_358538
# edge_JAN_PDE2_1345_set4_204316
# edge_JAN_PDE2_1345_set4_315054
# edge_JAN_PDE2_1345_set4_7468
# edge_JAN_PDE2_1345_set4_121456
# edge_JAN_PDE2_1345_set4_204440
# edge_JAN_PDE2_1345_set4_315055
# edge_JAN_PDE2_1345_set4_200493
# edge_JAN_PDE2_1345_set4_186899
# edge_JAN_PDE2_1345_set4_122477
# edge_JAN_PDE2_1345_set4_316584
# edge_JAN_PDE2_1345_set4_122492
# edge_JAN_PDE2_1345_set4_240165
# edge_JAN_PDE2_1345_set4_73781
# edge_JAN_PDE2_1345_set4_1830
# edge_JAN_PDE2_1345_set4_12907
# edge_JAN_PDE2_1345_set4_358553
# edge_JAN_PDE2_1345_set4_237843
# edge_JAN_PDE2_1345_set4_49395
# edge_JAN_PDE2_1345_set4_120342
# edge_JAN_PDE2_1345_set4_46563
# edge_JAN_PDE2_1345_set4_297010
# edge_JAN_PDE2_1345_set4_315639
# edge_JAN_PDE2_1345_set4_117342
# edge_JAN_PDE2_1345_set4_240197
# edge_JAN_PDE2_1345_set4_376385
# edge_JAN_PDE2_1345_set4_204476
# edge_JAN_PDE2_1345_set4_282491
# edge_JAN_PDE2_1345_set4_48416
# edge_JAN_PDE2_1345_set4_240139
# edge_JAN_PDE2_1345_set4_190853
# edge_JAN_PDE2_1345_set4_73446
# edge_JAN_PDE2_1345_set4_190819
# edge_JAN_PDE2_1345_set4_200833
# edge_JAN_PDE2_1345_set4_295347
# edge_JAN_PDE2_1345_set4_28055
# edge_JAN_PDE2_1345_set4_287279
# edge_JAN_PDE2_1345_set4_204510
# edge_JAN_PDE2_1345_set4_7467
# edge_JAN_PDE2_1345_set4_49408
# edge_JAN_PDE2_1345_set4_318271
# edge_JAN_PDE2_1345_set4_7276
# edge_JAN_PDE2_1345_set4_43306
# edge_JAN_PDE2_1345_set4_287340
# edge_JAN_PDE2_1345_set4_12308
#
# ---------------------
# Summary of the setup:
# ---------------------
#
#    workpath: /home/ykhalak/Projects/ML_dG/pde2_dG/generators/structures/set_4/morphing_annealing_4d09_filtered_subset/ddG_step_5_sigmahole_scaled_dummy_masses/workpath
#    mdp path: /home/ykhalak/Projects/ML_dG/pde2_dG/generators/structures/set_4/morphing_annealing_4d09_filtered_subset/ddG_step_5_sigmahole_scaled_dummy_masses/input/mdppath
#    protein files: /home/ykhalak/Projects/ML_dG/pde2_dG/generators/structures/set_4/morphing_annealing_4d09_filtered_subset/ddG_step_5_sigmahole_scaled_dummy_masses/input/protein_amber
#    ligand files: /home/ykhalak/Projects/ML_dG/pde2_dG/generators/structures/set_4/morphing_annealing_4d09_filtered_subset/ddG_step_5_sigmahole_scaled_dummy_masses/input/ligands
#    number of replicase: 3
#    edges:
#         edge_JAN_PDE2_1345_set4_190778
#         edge_JAN_PDE2_1345_set4_240291
#         edge_JAN_PDE2_1345_set4_204497
#         edge_JAN_PDE2_1345_set4_121483
#         edge_JAN_PDE2_1345_set4_190914
#         edge_JAN_PDE2_1345_set4_314311
#         edge_JAN_PDE2_1345_set4_39459
#         edge_JAN_PDE2_1345_set4_122463
#         edge_JAN_PDE2_1345_set4_71401
#         edge_JAN_PDE2_1345_set4_73883
#         edge_JAN_PDE2_1345_set4_202087
#         edge_JAN_PDE2_1345_set4_357530
#         edge_JAN_PDE2_1345_set4_46560
#         edge_JAN_PDE2_1345_set4_72639
#         edge_JAN_PDE2_1345_set4_190844
#         edge_JAN_PDE2_1345_set4_73008
#         edge_JAN_PDE2_1345_set4_316733
#         edge_JAN_PDE2_1345_set4_287307
#         edge_JAN_PDE2_1345_set4_9233
#         edge_JAN_PDE2_1345_set4_239416
#         edge_JAN_PDE2_1345_set4_49417
#         edge_JAN_PDE2_1345_set4_73375
#         edge_JAN_PDE2_1345_set4_204549
#         edge_JAN_PDE2_1345_set4_122460
#         edge_JAN_PDE2_1345_set4_315931
#         edge_JAN_PDE2_1345_set4_46739
#         edge_JAN_PDE2_1345_set4_44746
#         edge_JAN_PDE2_1345_set4_190886
#         edge_JAN_PDE2_1345_set4_318412
#         edge_JAN_PDE2_1345_set4_200839
#         edge_JAN_PDE2_1345_set4_204487
#         edge_JAN_PDE2_1345_set4_200519
#         edge_JAN_PDE2_1345_set4_204450
#         edge_JAN_PDE2_1345_set4_190882
#         edge_JAN_PDE2_1345_set4_122489
#         edge_JAN_PDE2_1345_set4_72643
#         edge_JAN_PDE2_1345_set4_186054
#         edge_JAN_PDE2_1345_set4_72600
#         edge_JAN_PDE2_1345_set4_188271
#         edge_JAN_PDE2_1345_set4_73007
#         edge_JAN_PDE2_1345_set4_26471
#         edge_JAN_PDE2_1345_set4_190807
#         edge_JAN_PDE2_1345_set4_73813
#         edge_JAN_PDE2_1345_set4_121481
#         edge_JAN_PDE2_1345_set4_73724
#         edge_JAN_PDE2_1345_set4_49347
#         edge_JAN_PDE2_1345_set4_204435
#         edge_JAN_PDE2_1345_set4_316574
#         edge_JAN_PDE2_1345_set4_187035
#         edge_JAN_PDE2_1345_set4_73153
#         edge_JAN_PDE2_1345_set4_318340
#         edge_JAN_PDE2_1345_set4_71992
#         edge_JAN_PDE2_1345_set4_121458
#         edge_JAN_PDE2_1345_set4_287108
#         edge_JAN_PDE2_1345_set4_287305
#         edge_JAN_PDE2_1345_set4_358538
#         edge_JAN_PDE2_1345_set4_204316
#         edge_JAN_PDE2_1345_set4_315054
#         edge_JAN_PDE2_1345_set4_7468
#         edge_JAN_PDE2_1345_set4_121456
#         edge_JAN_PDE2_1345_set4_204440
#         edge_JAN_PDE2_1345_set4_315055
#         edge_JAN_PDE2_1345_set4_200493
#         edge_JAN_PDE2_1345_set4_186899
#         edge_JAN_PDE2_1345_set4_122477
#         edge_JAN_PDE2_1345_set4_316584
#         edge_JAN_PDE2_1345_set4_122492
#         edge_JAN_PDE2_1345_set4_240165
#         edge_JAN_PDE2_1345_set4_73781
#         edge_JAN_PDE2_1345_set4_1830
#         edge_JAN_PDE2_1345_set4_12907
#         edge_JAN_PDE2_1345_set4_358553
#         edge_JAN_PDE2_1345_set4_237843
#         edge_JAN_PDE2_1345_set4_49395
#         edge_JAN_PDE2_1345_set4_120342
#         edge_JAN_PDE2_1345_set4_46563
#         edge_JAN_PDE2_1345_set4_297010
#         edge_JAN_PDE2_1345_set4_315639
#         edge_JAN_PDE2_1345_set4_117342
#         edge_JAN_PDE2_1345_set4_240197
#         edge_JAN_PDE2_1345_set4_376385
#         edge_JAN_PDE2_1345_set4_204476
#         edge_JAN_PDE2_1345_set4_282491
#         edge_JAN_PDE2_1345_set4_48416
#         edge_JAN_PDE2_1345_set4_240139
#         edge_JAN_PDE2_1345_set4_190853
#         edge_JAN_PDE2_1345_set4_73446
#         edge_JAN_PDE2_1345_set4_190819
#         edge_JAN_PDE2_1345_set4_200833
#         edge_JAN_PDE2_1345_set4_295347
#         edge_JAN_PDE2_1345_set4_28055
#         edge_JAN_PDE2_1345_set4_287279
#         edge_JAN_PDE2_1345_set4_204510
#         edge_JAN_PDE2_1345_set4_7467
#         edge_JAN_PDE2_1345_set4_49408
#         edge_JAN_PDE2_1345_set4_318271
#         edge_JAN_PDE2_1345_set4_7276
#         edge_JAN_PDE2_1345_set4_43306
#         edge_JAN_PDE2_1345_set4_287340
#         edge_JAN_PDE2_1345_set4_12308
#
# ---------------------
# Directory structure:
# ---------------------
#
# /home/ykhalak/Projects/ML_dG/pde2_dG/generators/structures/set_4/morphing_annealing_4d09_filtered_subset/ddG_step_5_sigmahole_scaled_dummy_masses/workpath/
# |
# |--edge_X_Y
# |--|--water
# |--|--|--stateA
# |--|--|--|--run1/2/3
# |--|--|--|--|--em/eq_posre/eq/transitions
# |--|--|--stateB
# |--|--|--|--run1/2/3
# |--|--|--|--|--em/eq_posre/eq/transitions
# |--|--protein
# |--|--|--stateA
# |--|--|--|--run1/2/3
# |--|--|--|--|--em/eq_posre/eq/transitions
# |--|--|--stateB
# |--|--|--|--run1/2/3
# |--|--|--|--|--em/eq_posre/eq/transitions
# |--|--hybridStrTop
# |--edge_..
# DONE

# %% [markdown]
# `1a. Firstly, let's create a hybrid structure/topology for the two ligands forming an edge.
# For that we will establish a mapping of atoms to be morphed between the molecules.`

# %%
# this command will map the atoms of all edges found in the 'fe' object
# bVerbose flag prints the output of the command
fe.atom_mapping(bVerbose=False, n_processes=8)
#fe.atom_mapping(bVerbose=True)
# Out:
# -----------------------
# Performing atom mapping
# -----------------------
# edge_JAN_PDE2_1345_set4_190778
# edge_JAN_PDE2_1345_set4_46560
# edge_JAN_PDE2_1345_set4_190914
# edge_JAN_PDE2_1345_set4_71401
# edge_JAN_PDE2_1345_set4_315931
# edge_JAN_PDE2_1345_set4_316733
# edge_JAN_PDE2_1345_set4_49417
# edge_JAN_PDE2_1345_set4_318412
# edge_JAN_PDE2_1345_set4_72639
# edge_JAN_PDE2_1345_set4_287307
# edge_JAN_PDE2_1345_set4_46739
# edge_JAN_PDE2_1345_set4_240291
# edge_JAN_PDE2_1345_set4_314311
# edge_JAN_PDE2_1345_set4_73883
# edge_JAN_PDE2_1345_set4_200839
# edge_JAN_PDE2_1345_set4_73375
# edge_JAN_PDE2_1345_set4_9233
# edge_JAN_PDE2_1345_set4_204497
# edge_JAN_PDE2_1345_set4_39459
# edge_JAN_PDE2_1345_set4_202087
# edge_JAN_PDE2_1345_set4_190844
# edge_JAN_PDE2_1345_set4_204487
# edge_JAN_PDE2_1345_set4_204549
# edge_JAN_PDE2_1345_set4_44746
# edge_JAN_PDE2_1345_set4_121483
# edge_JAN_PDE2_1345_set4_239416
# edge_JAN_PDE2_1345_set4_122463
# edge_JAN_PDE2_1345_set4_357530
# edge_JAN_PDE2_1345_set4_200519
# edge_JAN_PDE2_1345_set4_190886
# edge_JAN_PDE2_1345_set4_73008
# edge_JAN_PDE2_1345_set4_122460
# edge_JAN_PDE2_1345_set4_204450
# edge_JAN_PDE2_1345_set4_186054
# edge_JAN_PDE2_1345_set4_26471
# edge_JAN_PDE2_1345_set4_73724
# edge_JAN_PDE2_1345_set4_187035
# edge_JAN_PDE2_1345_set4_121458
# edge_JAN_PDE2_1345_set4_204316
# edge_JAN_PDE2_1345_set4_204440
# edge_JAN_PDE2_1345_set4_190882
# edge_JAN_PDE2_1345_set4_72600
# edge_JAN_PDE2_1345_set4_49347
# edge_JAN_PDE2_1345_set4_287108
# edge_JAN_PDE2_1345_set4_315054
# edge_JAN_PDE2_1345_set4_315055
# edge_JAN_PDE2_1345_set4_73153
# edge_JAN_PDE2_1345_set4_188271
# edge_JAN_PDE2_1345_set4_287305
# edge_JAN_PDE2_1345_set4_204435
# edge_JAN_PDE2_1345_set4_7468
# edge_JAN_PDE2_1345_set4_318340
# edge_JAN_PDE2_1345_set4_122489
# edge_JAN_PDE2_1345_set4_200493
# edge_JAN_PDE2_1345_set4_190807
# edge_JAN_PDE2_1345_set4_73007
# edge_JAN_PDE2_1345_set4_358538
# edge_JAN_PDE2_1345_set4_121456
# edge_JAN_PDE2_1345_set4_316574
# edge_JAN_PDE2_1345_set4_71992
# edge_JAN_PDE2_1345_set4_72643
# edge_JAN_PDE2_1345_set4_186899
# edge_JAN_PDE2_1345_set4_73813
# edge_JAN_PDE2_1345_set4_122477
# edge_JAN_PDE2_1345_set4_73781
# edge_JAN_PDE2_1345_set4_237843
# edge_JAN_PDE2_1345_set4_297010
# edge_JAN_PDE2_1345_set4_376385
# edge_JAN_PDE2_1345_set4_240139
# edge_JAN_PDE2_1345_set4_200833
# edge_JAN_PDE2_1345_set4_121481
# edge_JAN_PDE2_1345_set4_316584
# edge_JAN_PDE2_1345_set4_1830
# edge_JAN_PDE2_1345_set4_315639
# edge_JAN_PDE2_1345_set4_49395
# edge_JAN_PDE2_1345_set4_190853
# edge_JAN_PDE2_1345_set4_295347
# edge_JAN_PDE2_1345_set4_204476
# edge_JAN_PDE2_1345_set4_204510
# edge_JAN_PDE2_1345_set4_122492
# edge_JAN_PDE2_1345_set4_120342
# edge_JAN_PDE2_1345_set4_117342
# edge_JAN_PDE2_1345_set4_12907
# edge_JAN_PDE2_1345_set4_28055
# edge_JAN_PDE2_1345_set4_73446
# edge_JAN_PDE2_1345_set4_282491
# edge_JAN_PDE2_1345_set4_7467
# edge_JAN_PDE2_1345_set4_240165
# edge_JAN_PDE2_1345_set4_46563
# edge_JAN_PDE2_1345_set4_358553
# edge_JAN_PDE2_1345_set4_240197
# edge_JAN_PDE2_1345_set4_190819
# edge_JAN_PDE2_1345_set4_48416
# edge_JAN_PDE2_1345_set4_49408
# edge_JAN_PDE2_1345_set4_7276
# edge_JAN_PDE2_1345_set4_318271
# edge_JAN_PDE2_1345_set4_43306
# edge_JAN_PDE2_1345_set4_287279
# edge_JAN_PDE2_1345_set4_287340
# edge_JAN_PDE2_1345_set4_12308
# DONE

# %% [markdown]
# `1b. Secondly, we will construct a hybrid structure and topology based on the established mapping`

# %%
# import importlib
# if 'AZtutorial' in sys.modules:
#     importlib.reload(sys.modules['AZtutorial'])
# else:
#     import AZtutorial
# from AZtutorial import *

# # initialize the free energy environment object: it will store the main parameters for the calculations
# fe = AZtutorial( )

# # set the workpath
# fe.workPath = 'workpath'
# # set the path to the molecular dynamics parameter files
# fe.mdpPath = 'input/mdppath'
# # set the number of replicas (several repetitions of calculation are useful to obtain reliable statistics)
# fe.replicas = 3
# # provide the path to the protein structure and topology
# fe.proteinPath = 'input/protein_amber'
# # provide the path to the folder with ligand structures and topologies
# fe.ligandPath = 'input/ligands'

# # provide edges
# fe.edges = [ [reference_lig.GetProp('ID'), mol.GetProp('ID')] for mol in test_ligs]
# fe.simTypes = ['em','eq_posre','eq','transitions']
# #fe.simTypes = ['em','eq','transitions']

# # finally, let's prepare the overall free energy calculation directory structure
# fe.prepareFreeEnergyDir( )

# %%
fe.hybrid_structure_topology(bVerbose=False, n_processes=1, DummyMassScale=0.001)
# Out:
# ----------------------------------
# Creating hybrid structure/topology
# ----------------------------------
# edge_JAN_PDE2_1345_set4_190778
# edge_JAN_PDE2_1345_set4_240291
# edge_JAN_PDE2_1345_set4_204497
# edge_JAN_PDE2_1345_set4_121483
# edge_JAN_PDE2_1345_set4_190914
# edge_JAN_PDE2_1345_set4_314311
# edge_JAN_PDE2_1345_set4_39459
# edge_JAN_PDE2_1345_set4_122463
# edge_JAN_PDE2_1345_set4_71401
# edge_JAN_PDE2_1345_set4_73883
# edge_JAN_PDE2_1345_set4_202087
# edge_JAN_PDE2_1345_set4_357530
# edge_JAN_PDE2_1345_set4_46560
# edge_JAN_PDE2_1345_set4_72639
# edge_JAN_PDE2_1345_set4_190844
# edge_JAN_PDE2_1345_set4_73008
# edge_JAN_PDE2_1345_set4_316733
# edge_JAN_PDE2_1345_set4_287307
# edge_JAN_PDE2_1345_set4_9233
# edge_JAN_PDE2_1345_set4_239416
# edge_JAN_PDE2_1345_set4_49417
# edge_JAN_PDE2_1345_set4_73375
# edge_JAN_PDE2_1345_set4_204549
# edge_JAN_PDE2_1345_set4_122460
# edge_JAN_PDE2_1345_set4_315931
# edge_JAN_PDE2_1345_set4_46739
# edge_JAN_PDE2_1345_set4_44746
# edge_JAN_PDE2_1345_set4_190886
# edge_JAN_PDE2_1345_set4_318412
# edge_JAN_PDE2_1345_set4_200839
# edge_JAN_PDE2_1345_set4_204487
# edge_JAN_PDE2_1345_set4_200519
# edge_JAN_PDE2_1345_set4_204450
# edge_JAN_PDE2_1345_set4_190882
# edge_JAN_PDE2_1345_set4_122489
# edge_JAN_PDE2_1345_set4_72643
# edge_JAN_PDE2_1345_set4_186054
# edge_JAN_PDE2_1345_set4_72600
# edge_JAN_PDE2_1345_set4_188271
# edge_JAN_PDE2_1345_set4_73007
# edge_JAN_PDE2_1345_set4_26471
# edge_JAN_PDE2_1345_set4_190807
# edge_JAN_PDE2_1345_set4_73813
# edge_JAN_PDE2_1345_set4_121481
# edge_JAN_PDE2_1345_set4_73724
# edge_JAN_PDE2_1345_set4_49347
# edge_JAN_PDE2_1345_set4_204435
# edge_JAN_PDE2_1345_set4_316574
# edge_JAN_PDE2_1345_set4_187035
# edge_JAN_PDE2_1345_set4_73153
# edge_JAN_PDE2_1345_set4_318340
# edge_JAN_PDE2_1345_set4_71992
# edge_JAN_PDE2_1345_set4_121458
# edge_JAN_PDE2_1345_set4_287108
# edge_JAN_PDE2_1345_set4_287305
# edge_JAN_PDE2_1345_set4_358538
# edge_JAN_PDE2_1345_set4_204316
# edge_JAN_PDE2_1345_set4_315054
# edge_JAN_PDE2_1345_set4_7468
# edge_JAN_PDE2_1345_set4_121456
# edge_JAN_PDE2_1345_set4_204440
# edge_JAN_PDE2_1345_set4_315055
# edge_JAN_PDE2_1345_set4_200493
# edge_JAN_PDE2_1345_set4_186899
# edge_JAN_PDE2_1345_set4_122477
# edge_JAN_PDE2_1345_set4_316584
# edge_JAN_PDE2_1345_set4_122492
# edge_JAN_PDE2_1345_set4_240165
# edge_JAN_PDE2_1345_set4_73781
# edge_JAN_PDE2_1345_set4_1830
# edge_JAN_PDE2_1345_set4_12907
# edge_JAN_PDE2_1345_set4_358553
# edge_JAN_PDE2_1345_set4_237843
# edge_JAN_PDE2_1345_set4_49395
# edge_JAN_PDE2_1345_set4_120342
# edge_JAN_PDE2_1345_set4_46563
# edge_JAN_PDE2_1345_set4_297010
# edge_JAN_PDE2_1345_set4_315639
# edge_JAN_PDE2_1345_set4_117342
# edge_JAN_PDE2_1345_set4_240197
# edge_JAN_PDE2_1345_set4_376385
# edge_JAN_PDE2_1345_set4_204476
# edge_JAN_PDE2_1345_set4_282491
# edge_JAN_PDE2_1345_set4_48416
# edge_JAN_PDE2_1345_set4_240139
# edge_JAN_PDE2_1345_set4_190853
# edge_JAN_PDE2_1345_set4_73446
# edge_JAN_PDE2_1345_set4_190819
# edge_JAN_PDE2_1345_set4_200833
# edge_JAN_PDE2_1345_set4_295347
# edge_JAN_PDE2_1345_set4_28055
# edge_JAN_PDE2_1345_set4_287279
# edge_JAN_PDE2_1345_set4_204510
# edge_JAN_PDE2_1345_set4_7467
# edge_JAN_PDE2_1345_set4_49408
# edge_JAN_PDE2_1345_set4_318271
# edge_JAN_PDE2_1345_set4_7276
# edge_JAN_PDE2_1345_set4_43306
# edge_JAN_PDE2_1345_set4_287340
# edge_JAN_PDE2_1345_set4_12308
# DONE

# %% [markdown]
# `1c. Generate position restraints for the ligands`

# %%
fe.hybrid_structure_restraints(bVerbose=False, n_processes=8)
# Out:
# -----------------------------------------------
# Creating position restraints for hybrid ligands
# -----------------------------------------------
# edge_JAN_PDE2_1345_set4_315931
# edge_JAN_PDE2_1345_set4_190778
# edge_JAN_PDE2_1345_set4_318412
# edge_JAN_PDE2_1345_set4_71401
# edge_JAN_PDE2_1345_set4_46560
# edge_JAN_PDE2_1345_set4_316733
# edge_JAN_PDE2_1345_set4_49417
# edge_JAN_PDE2_1345_set4_190914
# edge_JAN_PDE2_1345_set4_73375
# edge_JAN_PDE2_1345_set4_200839
# edge_JAN_PDE2_1345_set4_73883
# edge_JAN_PDE2_1345_set4_240291
# edge_JAN_PDE2_1345_set4_287307
# edge_JAN_PDE2_1345_set4_46739
# edge_JAN_PDE2_1345_set4_72639
# edge_JAN_PDE2_1345_set4_314311
# edge_JAN_PDE2_1345_set4_204487
# edge_JAN_PDE2_1345_set4_202087
# edge_JAN_PDE2_1345_set4_44746
# edge_JAN_PDE2_1345_set4_204549
# edge_JAN_PDE2_1345_set4_9233
# edge_JAN_PDE2_1345_set4_204497
# edge_JAN_PDE2_1345_set4_190844
# edge_JAN_PDE2_1345_set4_357530
# edge_JAN_PDE2_1345_set4_200519
# edge_JAN_PDE2_1345_set4_39459
# edge_JAN_PDE2_1345_set4_190886
# edge_JAN_PDE2_1345_set4_122460
# edge_JAN_PDE2_1345_set4_239416
# edge_JAN_PDE2_1345_set4_121483
# edge_JAN_PDE2_1345_set4_204450
# edge_JAN_PDE2_1345_set4_73008
# edge_JAN_PDE2_1345_set4_186054
# edge_JAN_PDE2_1345_set4_122463
# edge_JAN_PDE2_1345_set4_26471
# edge_JAN_PDE2_1345_set4_73724
# edge_JAN_PDE2_1345_set4_187035
# edge_JAN_PDE2_1345_set4_190882
# edge_JAN_PDE2_1345_set4_72600
# edge_JAN_PDE2_1345_set4_121458
# edge_JAN_PDE2_1345_set4_204316
# edge_JAN_PDE2_1345_set4_190807
# edge_JAN_PDE2_1345_set4_204440
# edge_JAN_PDE2_1345_set4_122489
# edge_JAN_PDE2_1345_set4_49347
# edge_JAN_PDE2_1345_set4_73153
# edge_JAN_PDE2_1345_set4_188271
# edge_JAN_PDE2_1345_set4_287108
# edge_JAN_PDE2_1345_set4_315054
# edge_JAN_PDE2_1345_set4_73813
# edge_JAN_PDE2_1345_set4_204435
# edge_JAN_PDE2_1345_set4_72643
# edge_JAN_PDE2_1345_set4_315055
# edge_JAN_PDE2_1345_set4_73007
# edge_JAN_PDE2_1345_set4_7468
# edge_JAN_PDE2_1345_set4_318340
# edge_JAN_PDE2_1345_set4_287305
# edge_JAN_PDE2_1345_set4_121481
# edge_JAN_PDE2_1345_set4_316574
# edge_JAN_PDE2_1345_set4_122477
# edge_JAN_PDE2_1345_set4_200493
# edge_JAN_PDE2_1345_set4_121456
# edge_JAN_PDE2_1345_set4_73781
# edge_JAN_PDE2_1345_set4_358538
# edge_JAN_PDE2_1345_set4_71992
# edge_JAN_PDE2_1345_set4_237843
# edge_JAN_PDE2_1345_set4_186899
# edge_JAN_PDE2_1345_set4_316584
# edge_JAN_PDE2_1345_set4_297010
# edge_JAN_PDE2_1345_set4_1830
# edge_JAN_PDE2_1345_set4_49395
# edge_JAN_PDE2_1345_set4_376385
# edge_JAN_PDE2_1345_set4_240139
# edge_JAN_PDE2_1345_set4_200833
# edge_JAN_PDE2_1345_set4_204510
# edge_JAN_PDE2_1345_set4_122492
# edge_JAN_PDE2_1345_set4_315639
# edge_JAN_PDE2_1345_set4_12907
# edge_JAN_PDE2_1345_set4_120342
# edge_JAN_PDE2_1345_set4_204476
# edge_JAN_PDE2_1345_set4_295347
# edge_JAN_PDE2_1345_set4_190853
# edge_JAN_PDE2_1345_set4_7467
# edge_JAN_PDE2_1345_set4_240165
# edge_JAN_PDE2_1345_set4_117342
# edge_JAN_PDE2_1345_set4_358553
# edge_JAN_PDE2_1345_set4_46563
# edge_JAN_PDE2_1345_set4_73446
# edge_JAN_PDE2_1345_set4_28055
# edge_JAN_PDE2_1345_set4_282491
# edge_JAN_PDE2_1345_set4_49408
# edge_JAN_PDE2_1345_set4_7276
# edge_JAN_PDE2_1345_set4_240197
# edge_JAN_PDE2_1345_set4_190819
# edge_JAN_PDE2_1345_set4_318271
# edge_JAN_PDE2_1345_set4_287279
# edge_JAN_PDE2_1345_set4_48416
# edge_JAN_PDE2_1345_set4_43306
# edge_JAN_PDE2_1345_set4_287340
# edge_JAN_PDE2_1345_set4_12308
# DONE

# %% [markdown]
# `1d. Finally, we assemble the ligand and ligand+protein systems, i.e. create structures and topologies that will be used further in the step 2.`

# %%
prot_extra_mols={}
prot_extra_mols["MG"]=1
prot_extra_mols["ZN"]=1
prot_extra_mols["SOL"]=88

fe.assemble_systems( filter_prot_water=True, prot_extra_mols=prot_extra_mols)
# Out:
# ----------------------
# Assembling the systems
# ----------------------
# edge_JAN_PDE2_1345_set4_190778
# /home/ykhalak/soft/anaconda3/envs/python3_ML_v2/lib/python3.6/site-packages/MDAnalysis/topology/guessers.py:80: UserWarning: Failed to guess the mass for the following atom types:
#   warnings.warn("Failed to guess the mass for the following atom types: {}".format(atom_type))
# /home/ykhalak/soft/anaconda3/envs/python3_ML_v2/lib/python3.6/site-packages/MDAnalysis/topology/PDBParser.py:330: UserWarning: Element information is absent or missing for a few atoms. Elements attributes will not be populated.
#   warnings.warn("Element information is absent or missing for a few "
# /home/ykhalak/soft/anaconda3/envs/python3_ML_v2/lib/python3.6/site-packages/MDAnalysis/coordinates/PDB.py:864: DeprecationWarning: Using the last letter of the segid for the chainID is now deprecated and will be changed in 2.0. In 2.0, the chainID attribute will be used if it exists, or a placeholder value.
#   "exists, or a placeholder value.", DeprecationWarning)
# /home/ykhalak/soft/anaconda3/envs/python3_ML_v2/lib/python3.6/site-packages/MDAnalysis/coordinates/PDB.py:722: UserWarning: Unit cell dimensions not found. CRYST1 record set to unitary values.
#   warnings.warn("Unit cell dimensions not found. "
# changing number of waters to 87
# edge_JAN_PDE2_1345_set4_240291
# changing number of waters to 86
# edge_JAN_PDE2_1345_set4_204497
# changing number of waters to 87
# edge_JAN_PDE2_1345_set4_121483
# changing number of waters to 87
# edge_JAN_PDE2_1345_set4_190914
# changing number of waters to 87
# edge_JAN_PDE2_1345_set4_314311
# edge_JAN_PDE2_1345_set4_39459
# changing number of waters to 87
# edge_JAN_PDE2_1345_set4_122463
# changing number of waters to 87
# edge_JAN_PDE2_1345_set4_71401
# changing number of waters to 87
# edge_JAN_PDE2_1345_set4_73883
# changing number of waters to 87
# edge_JAN_PDE2_1345_set4_202087
# changing number of waters to 87
# edge_JAN_PDE2_1345_set4_357530
# changing number of waters to 87
# edge_JAN_PDE2_1345_set4_46560
# changing number of waters to 87
# edge_JAN_PDE2_1345_set4_72639
# changing number of waters to 86
# edge_JAN_PDE2_1345_set4_190844
# changing number of waters to 86
# edge_JAN_PDE2_1345_set4_73008
# changing number of waters to 87
# edge_JAN_PDE2_1345_set4_316733
# edge_JAN_PDE2_1345_set4_287307
# changing number of waters to 87
# edge_JAN_PDE2_1345_set4_9233
# edge_JAN_PDE2_1345_set4_239416
# changing number of waters to 87
# edge_JAN_PDE2_1345_set4_49417
# changing number of waters to 87
# edge_JAN_PDE2_1345_set4_73375
# changing number of waters to 87
# edge_JAN_PDE2_1345_set4_204549
# changing number of waters to 87
# edge_JAN_PDE2_1345_set4_122460
# changing number of waters to 87
# edge_JAN_PDE2_1345_set4_315931
# edge_JAN_PDE2_1345_set4_46739
# changing number of waters to 87
# edge_JAN_PDE2_1345_set4_44746
# changing number of waters to 87
# edge_JAN_PDE2_1345_set4_190886
# changing number of waters to 87
# edge_JAN_PDE2_1345_set4_318412
# changing number of waters to 87
# edge_JAN_PDE2_1345_set4_200839
# changing number of waters to 87
# edge_JAN_PDE2_1345_set4_204487
# changing number of waters to 87
# edge_JAN_PDE2_1345_set4_200519
# changing number of waters to 86
# edge_JAN_PDE2_1345_set4_204450
# changing number of waters to 87
# edge_JAN_PDE2_1345_set4_190882
# changing number of waters to 86
# edge_JAN_PDE2_1345_set4_122489
# changing number of waters to 87
# edge_JAN_PDE2_1345_set4_72643
# changing number of waters to 87
# edge_JAN_PDE2_1345_set4_186054
# changing number of waters to 87
# edge_JAN_PDE2_1345_set4_72600
# changing number of waters to 87
# edge_JAN_PDE2_1345_set4_188271
# changing number of waters to 87
# edge_JAN_PDE2_1345_set4_73007
# changing number of waters to 87
# edge_JAN_PDE2_1345_set4_26471
# edge_JAN_PDE2_1345_set4_190807
# changing number of waters to 86
# edge_JAN_PDE2_1345_set4_73813
# changing number of waters to 87
# edge_JAN_PDE2_1345_set4_121481
# changing number of waters to 87
# edge_JAN_PDE2_1345_set4_73724
# changing number of waters to 87
# edge_JAN_PDE2_1345_set4_49347
# changing number of waters to 87
# edge_JAN_PDE2_1345_set4_204435
# changing number of waters to 87
# edge_JAN_PDE2_1345_set4_316574
# edge_JAN_PDE2_1345_set4_187035
# changing number of waters to 87
# edge_JAN_PDE2_1345_set4_73153
# changing number of waters to 87
# edge_JAN_PDE2_1345_set4_318340
# edge_JAN_PDE2_1345_set4_71992
# changing number of waters to 87
# edge_JAN_PDE2_1345_set4_121458
# changing number of waters to 87
# edge_JAN_PDE2_1345_set4_287108
# changing number of waters to 87
# edge_JAN_PDE2_1345_set4_287305
# changing number of waters to 87
# edge_JAN_PDE2_1345_set4_358538
# changing number of waters to 87
# edge_JAN_PDE2_1345_set4_204316
# changing number of waters to 87
# edge_JAN_PDE2_1345_set4_315054
# edge_JAN_PDE2_1345_set4_7468
# edge_JAN_PDE2_1345_set4_121456
# changing number of waters to 86
# edge_JAN_PDE2_1345_set4_204440
# changing number of waters to 87
# edge_JAN_PDE2_1345_set4_315055
# edge_JAN_PDE2_1345_set4_200493
# changing number of waters to 87
# edge_JAN_PDE2_1345_set4_186899
# changing number of waters to 87
# edge_JAN_PDE2_1345_set4_122477
# changing number of waters to 87
# edge_JAN_PDE2_1345_set4_316584
# changing number of waters to 86
# edge_JAN_PDE2_1345_set4_122492
# changing number of waters to 87
# edge_JAN_PDE2_1345_set4_240165
# edge_JAN_PDE2_1345_set4_73781
# changing number of waters to 87
# edge_JAN_PDE2_1345_set4_1830
# edge_JAN_PDE2_1345_set4_12907
# edge_JAN_PDE2_1345_set4_358553
# changing number of waters to 87
# edge_JAN_PDE2_1345_set4_237843
# changing number of waters to 87
# edge_JAN_PDE2_1345_set4_49395
# changing number of waters to 87
# edge_JAN_PDE2_1345_set4_120342
# changing number of waters to 87
# edge_JAN_PDE2_1345_set4_46563
# changing number of waters to 87
# edge_JAN_PDE2_1345_set4_297010
# changing number of waters to 87
# edge_JAN_PDE2_1345_set4_315639
# changing number of waters to 87
# edge_JAN_PDE2_1345_set4_117342
# changing number of waters to 87
# edge_JAN_PDE2_1345_set4_240197
# changing number of waters to 87
# edge_JAN_PDE2_1345_set4_376385
# changing number of waters to 87
# edge_JAN_PDE2_1345_set4_204476
# changing number of waters to 87
# edge_JAN_PDE2_1345_set4_282491
# changing number of waters to 87
# edge_JAN_PDE2_1345_set4_48416
# changing number of waters to 87
# edge_JAN_PDE2_1345_set4_240139
# changing number of waters to 87
# edge_JAN_PDE2_1345_set4_190853
# changing number of waters to 87
# edge_JAN_PDE2_1345_set4_73446
# changing number of waters to 87
# edge_JAN_PDE2_1345_set4_190819
# changing number of waters to 87
# edge_JAN_PDE2_1345_set4_200833
# changing number of waters to 87
# edge_JAN_PDE2_1345_set4_295347
# edge_JAN_PDE2_1345_set4_28055
# edge_JAN_PDE2_1345_set4_287279
# changing number of waters to 87
# edge_JAN_PDE2_1345_set4_204510
# changing number of waters to 86
# edge_JAN_PDE2_1345_set4_7467
# edge_JAN_PDE2_1345_set4_49408
# changing number of waters to 87
# edge_JAN_PDE2_1345_set4_318271
# changing number of waters to 87
# edge_JAN_PDE2_1345_set4_7276
# changing number of waters to 87
# edge_JAN_PDE2_1345_set4_43306
# changing number of waters to 86
# edge_JAN_PDE2_1345_set4_287340
# changing number of waters to 87
# edge_JAN_PDE2_1345_set4_12308
# DONE

# %% [markdown]
# ------------------
# Step 2. Prepare equilibrium simulations.
# ---------------------
# Prepare simulation boxes with solvent and ions.
# Subsequently energy minimize the systems, prepare equilibrium simulations and start the runs.

# %% [markdown]
# `2a. Build boxes, solvate, add ions`

# %%
fe.boxWaterIons(    bBoxLig=True, bBoxProt=True, 
                    bWatLig=True, bWatProt=True,
                    bIonLig=True, bIonProt=True, n_processes=4 )
# Out:
# ----------------
# Box, water, ions
# ----------------
# edge_JAN_PDE2_1345_set4_122463
# edge_JAN_PDE2_1345_set4_190844
# edge_JAN_PDE2_1345_set4_190778
# edge_JAN_PDE2_1345_set4_73375
# IndexFile has group MG !!
# Group MG will be replaced !!
# IndexFile has group ZN !!
# Group ZN will be replaced !!
# IndexFile has group UNL !!
# Group UNL will be replaced !!
# IndexFile has group MG !!
# Group MG will be replaced !!
# IndexFile has group ZN !!
# Group ZN will be replaced !!
# IndexFile has group UNL !!
# Group UNL will be replaced !!
# IndexFile has group MG !!
# Group MG will be replaced !!
# IndexFile has group ZN !!
# Group ZN will be replaced !!
# IndexFile has group UNL !!
# Group UNL will be replaced !!
# IndexFile has group MG !!
# Group MG will be replaced !!
# IndexFile has group ZN !!
# Group ZN will be replaced !!
# IndexFile has group UNL !!
# Group UNL will be replaced !!
# edge_JAN_PDE2_1345_set4_240291
# edge_JAN_PDE2_1345_set4_71401
# edge_JAN_PDE2_1345_set4_73008
# edge_JAN_PDE2_1345_set4_204549
# IndexFile has group MG !!
# Group MG will be replaced !!
# IndexFile has group ZN !!
# Group ZN will be replaced !!
# IndexFile has group UNL !!
# Group UNL will be replaced !!
# IndexFile has group MG !!
# Group MG will be replaced !!
# IndexFile has group ZN !!
# Group ZN will be replaced !!
# IndexFile has group UNL !!
# Group UNL will be replaced !!
# IndexFile has group MG !!
# Group MG will be replaced !!
# IndexFile has group ZN !!
# Group ZN will be replaced !!
# IndexFile has group UNL !!
# Group UNL will be replaced !!
# IndexFile has group MG !!
# Group MG will be replaced !!
# IndexFile has group ZN !!
# Group ZN will be replaced !!
# IndexFile has group UNL !!
# Group UNL will be replaced !!
# edge_JAN_PDE2_1345_set4_204497
# edge_JAN_PDE2_1345_set4_73883
# edge_JAN_PDE2_1345_set4_316733
# edge_JAN_PDE2_1345_set4_122460
# IndexFile has group MG !!
# Group MG will be replaced !!
# IndexFile has group ZN !!
# Group ZN will be replaced !!
# IndexFile has group UNL !!
# Group UNL will be replaced !!
# IndexFile has group MG !!
# Group MG will be replaced !!
# IndexFile has group ZN !!
# Group ZN will be replaced !!
# IndexFile has group UNL !!
# Group UNL will be replaced !!
# IndexFile has group MG !!
# Group MG will be replaced !!
# IndexFile has group ZN !!
# Group ZN will be replaced !!
# IndexFile has group UNL !!
# Group UNL will be replaced !!
# IndexFile has group MG !!
# Group MG will be replaced !!
# IndexFile has group ZN !!
# Group ZN will be replaced !!
# IndexFile has group UNL !!
# Group UNL will be replaced !!
# edge_JAN_PDE2_1345_set4_121483
# edge_JAN_PDE2_1345_set4_202087
# edge_JAN_PDE2_1345_set4_287307
# edge_JAN_PDE2_1345_set4_315931
# IndexFile has group MG !!
# Group MG will be replaced !!
# IndexFile has group ZN !!
# Group ZN will be replaced !!
# IndexFile has group UNL !!
# IndexFile has group MG !!
# Group UNL will be replaced !!
# Group MG will be replaced !!
# IndexFile has group ZN !!
# Group ZN will be replaced !!
# IndexFile has group UNL !!
# Group UNL will be replaced !!
# IndexFile has group MG !!
# Group MG will be replaced !!
# IndexFile has group ZN !!
# Group ZN will be replaced !!
# IndexFile has group UNL !!
# Group UNL will be replaced !!
# IndexFile has group MG !!
# Group MG will be replaced !!
# IndexFile has group ZN !!
# Group ZN will be replaced !!
# IndexFile has group UNL !!
# Group UNL will be replaced !!
# edge_JAN_PDE2_1345_set4_190914
# edge_JAN_PDE2_1345_set4_357530
# edge_JAN_PDE2_1345_set4_46739
# edge_JAN_PDE2_1345_set4_9233
# IndexFile has group MG !!
# Group MG will be replaced !!
# IndexFile has group ZN !!
# Group ZN will be replaced !!
# IndexFile has group UNL !!
# Group UNL will be replaced !!
# IndexFile has group MG !!
# Group MG will be replaced !!
# IndexFile has group ZN !!
# Group ZN will be replaced !!
# IndexFile has group UNL !!
# Group UNL will be replaced !!
# IndexFile has group MG !!
# Group MG will be replaced !!
# IndexFile has group ZN !!
# Group ZN will be replaced !!
# IndexFile has group UNL !!
# Group UNL will be replaced !!
# IndexFile has group MG !!
# Group MG will be replaced !!
# IndexFile has group ZN !!
# Group ZN will be replaced !!
# IndexFile has group UNL !!
# Group UNL will be replaced !!
# edge_JAN_PDE2_1345_set4_46560
# edge_JAN_PDE2_1345_set4_314311
# edge_JAN_PDE2_1345_set4_239416
# edge_JAN_PDE2_1345_set4_44746
# IndexFile has group MG !!
# Group MG will be replaced !!
# IndexFile has group ZN !!
# Group ZN will be replaced !!
# IndexFile has group UNL !!
# Group UNL will be replaced !!
# IndexFile has group MG !!
# Group MG will be replaced !!
# IndexFile has group ZN !!
# Group ZN will be replaced !!
# IndexFile has group UNL !!
# Group UNL will be replaced !!
# IndexFile has group MG !!
# Group MG will be replaced !!
# IndexFile has group ZN !!
# Group ZN will be replaced !!
# IndexFile has group UNL !!
# Group UNL will be replaced !!
# IndexFile has group MG !!
# Group MG will be replaced !!
# IndexFile has group ZN !!
# Group ZN will be replaced !!
# IndexFile has group UNL !!
# Group UNL will be replaced !!
# edge_JAN_PDE2_1345_set4_72639
# edge_JAN_PDE2_1345_set4_39459
# edge_JAN_PDE2_1345_set4_190886
# edge_JAN_PDE2_1345_set4_49417
# IndexFile has group MG !!
# Group MG will be replaced !!
# IndexFile has group ZN !!
# Group ZN will be replaced !!
# IndexFile has group UNL !!
# Group UNL will be replaced !!IndexFile has group MG !!
#
# Group MG will be replaced !!
# IndexFile has group ZN !!
# Group ZN will be replaced !!
# IndexFile has group UNL !!
# Group UNL will be replaced !!
# IndexFile has group MG !!
# Group MG will be replaced !!
# IndexFile has group ZN !!
# Group ZN will be replaced !!
# IndexFile has group UNL !!
# Group UNL will be replaced !!
# IndexFile has group MG !!
# Group MG will be replaced !!
# IndexFile has group ZN !!
# Group ZN will be replaced !!
# IndexFile has group UNL !!
# Group UNL will be replaced !!
# edge_JAN_PDE2_1345_set4_318412
# edge_JAN_PDE2_1345_set4_72643
# edge_JAN_PDE2_1345_set4_73813
# edge_JAN_PDE2_1345_set4_73153
# IndexFile has group MG !!
# Group MG will be replaced !!
# IndexFile has group ZN !!
# Group ZN will be replaced !!
# IndexFile has group UNL !!
# Group UNL will be replaced !!
# IndexFile has group MG !!
# Group MG will be replaced !!
# IndexFile has group ZN !!
# Group ZN will be replaced !!
# IndexFile has group UNL !!
# Group UNL will be replaced !!
# IndexFile has group MG !!
# Group MG will be replaced !!
# IndexFile has group ZN !!
# Group ZN will be replaced !!
# IndexFile has group UNL !!
# Group UNL will be replaced !!
# IndexFile has group MG !!
# Group MG will be replaced !!
# IndexFile has group ZN !!
# Group ZN will be replaced !!
# IndexFile has group UNL !!
# Group UNL will be replaced !!
# edge_JAN_PDE2_1345_set4_200839
# edge_JAN_PDE2_1345_set4_121481
# edge_JAN_PDE2_1345_set4_318340
# edge_JAN_PDE2_1345_set4_186054
# IndexFile has group MG !!
# Group MG will be replaced !!
# IndexFile has group ZN !!
# Group ZN will be replaced !!
# IndexFile has group UNL !!
# Group UNL will be replaced !!
# IndexFile has group MG !!
# Group MG will be replaced !!
# IndexFile has group ZN !!
# Group ZN will be replaced !!
# IndexFile has group UNL !!
# Group UNL will be replaced !!
# IndexFile has group MG !!
# Group MG will be replaced !!
# IndexFile has group ZN !!
# Group ZN will be replaced !!
# IndexFile has group UNL !!
# Group UNL will be replaced !!
# IndexFile has group MG !!
# Group MG will be replaced !!
# IndexFile has group ZN !!
# Group ZN will be replaced !!
# IndexFile has group UNL !!
# Group UNL will be replaced !!
# edge_JAN_PDE2_1345_set4_73724
# edge_JAN_PDE2_1345_set4_204487
# edge_JAN_PDE2_1345_set4_71992
# edge_JAN_PDE2_1345_set4_72600
# IndexFile has group MG !!
# Group MG will be replaced !!
# IndexFile has group ZN !!
# Group ZN will be replaced !!
# IndexFile has group UNL !!
# Group UNL will be replaced !!
# IndexFile has group MG !!
# Group MG will be replaced !!
# IndexFile has group ZN !!
# Group ZN will be replaced !!
# IndexFile has group UNL !!
# Group UNL will be replaced !!
# IndexFile has group MG !!
# Group MG will be replaced !!
# IndexFile has group ZN !!
# Group ZN will be replaced !!
# IndexFile has group UNL !!
# Group UNL will be replaced !!
# edge_JAN_PDE2_1345_set4_200519
# IndexFile has group MG !!
# Group MG will be replaced !!
# IndexFile has group ZN !!
# Group ZN will be replaced !!
# IndexFile has group UNL !!
# Group UNL will be replaced !!
# edge_JAN_PDE2_1345_set4_49347
# IndexFile has group MG !!
# Group MG will be replaced !!
# IndexFile has group ZN !!
# Group ZN will be replaced !!
# IndexFile has group UNL !!
# Group UNL will be replaced !!
# edge_JAN_PDE2_1345_set4_188271
# IndexFile has group MG !!
# Group MG will be replaced !!
# IndexFile has group ZN !!
# Group ZN will be replaced !!
# IndexFile has group UNL !!
# Group UNL will be replaced !!
# edge_JAN_PDE2_1345_set4_121458
# edge_JAN_PDE2_1345_set4_204450
# IndexFile has group MG !!
# Group MG will be replaced !!
# IndexFile has group ZN !!
# Group ZN will be replaced !!
# IndexFile has group UNL !!
# Group UNL will be replaced !!
# edge_JAN_PDE2_1345_set4_204435
# IndexFile has group MG !!
# Group MG will be replaced !!
# IndexFile has group ZN !!
# Group ZN will be replaced !!
# IndexFile has group UNL !!
# Group UNL will be replaced !!
# IndexFile has group MG !!
# Group MG will be replaced !!
# IndexFile has group ZN !!
# Group ZN will be replaced !!
# IndexFile has group UNL !!
# Group UNL will be replaced !!
# IndexFile has group MG !!
# Group MG will be replaced !!
# IndexFile has group ZN !!
# Group ZN will be replaced !!
# IndexFile has group UNL !!
# Group UNL will be replaced !!
# edge_JAN_PDE2_1345_set4_73007
# edge_JAN_PDE2_1345_set4_287108
# edge_JAN_PDE2_1345_set4_190882
# IndexFile has group MG !!
# Group MG will be replaced !!
# IndexFile has group ZN !!
# Group ZN will be replaced !!
# IndexFile has group UNL !!
# Group UNL will be replaced !!
# edge_JAN_PDE2_1345_set4_316574
# IndexFile has group MG !!
# Group MG will be replaced !!
# IndexFile has group ZN !!
# Group ZN will be replaced !!
# IndexFile has group UNL !!
# Group UNL will be replaced !!
# IndexFile has group MG !!
# Group MG will be replaced !!
# IndexFile has group ZN !!
# Group ZN will be replaced !!
# IndexFile has group UNL !!
# Group UNL will be replaced !!
# edge_JAN_PDE2_1345_set4_26471
# IndexFile has group MG !!
# Group MG will be replaced !!
# IndexFile has group ZN !!
# Group ZN will be replaced !!
# IndexFile has group UNL !!
# Group UNL will be replaced !!
# edge_JAN_PDE2_1345_set4_287305
# edge_JAN_PDE2_1345_set4_122489
# IndexFile has group MG !!
# Group MG will be replaced !!
# IndexFile has group ZN !!
# Group ZN will be replaced !!
# IndexFile has group UNL !!
# Group UNL will be replaced !!
# edge_JAN_PDE2_1345_set4_187035
# IndexFile has group MG !!
# Group MG will be replaced !!
# IndexFile has group ZN !!
# Group ZN will be replaced !!
# IndexFile has group UNL !!
# Group UNL will be replaced !!
# IndexFile has group MG !!
# Group MG will be replaced !!
# IndexFile has group ZN !!
# Group ZN will be replaced !!
# IndexFile has group UNL !!
# Group UNL will be replaced !!
# edge_JAN_PDE2_1345_set4_190807
# IndexFile has group MG !!
# Group MG will be replaced !!
# IndexFile has group ZN !!
# Group ZN will be replaced !!
# IndexFile has group UNL !!
# Group UNL will be replaced !!
# IndexFile has group MG !!
# Group MG will be replaced !!
# IndexFile has group ZN !!
# Group ZN will be replaced !!
# IndexFile has group UNL !!
# Group UNL will be replaced !!
# edge_JAN_PDE2_1345_set4_204316
# edge_JAN_PDE2_1345_set4_186899
# edge_JAN_PDE2_1345_set4_358538
# edge_JAN_PDE2_1345_set4_12907
# IndexFile has group MG !!
# Group MG will be replaced !!
# IndexFile has group ZN !!
# Group ZN will be replaced !!
# IndexFile has group UNL !!
# Group UNL will be replaced !!
# IndexFile has group MG !!
# Group MG will be replaced !!
# IndexFile has group ZN !!
# Group ZN will be replaced !!
# IndexFile has group UNL !!
# Group UNL will be replaced !!
# IndexFile has group MG !!
# Group MG will be replaced !!
# IndexFile has group ZN !!
# Group ZN will be replaced !!
# IndexFile has group UNL !!
# Group UNL will be replaced !!
# IndexFile has group MG !!
# Group MG will be replaced !!
# IndexFile has group ZN !!
# Group ZN will be replaced !!
# IndexFile has group UNL !!
# Group UNL will be replaced !!
# edge_JAN_PDE2_1345_set4_122477
# edge_JAN_PDE2_1345_set4_315639
# edge_JAN_PDE2_1345_set4_315054
# edge_JAN_PDE2_1345_set4_358553
# IndexFile has group MG !!
# Group MG will be replaced !!
# IndexFile has group ZN !!
# Group ZN will be replaced !!
# IndexFile has group UNL !!
# Group UNL will be replaced !!
# IndexFile has group MG !!
# Group MG will be replaced !!
# IndexFile has group ZN !!
# Group ZN will be replaced !!
# IndexFile has group UNL !!
# Group UNL will be replaced !!
# IndexFile has group MG !!
# Group MG will be replaced !!
# IndexFile has group ZN !!
# Group ZN will be replaced !!
# IndexFile has group UNL !!
# Group UNL will be replaced !!
# IndexFile has group MG !!
# Group MG will be replaced !!
# IndexFile has group ZN !!
# Group ZN will be replaced !!
# IndexFile has group UNL !!
# Group UNL will be replaced !!
# edge_JAN_PDE2_1345_set4_7468
# edge_JAN_PDE2_1345_set4_117342
# edge_JAN_PDE2_1345_set4_237843
# edge_JAN_PDE2_1345_set4_316584
# IndexFile has group MG !!
# Group MG will be replaced !!
# IndexFile has group ZN !!
# Group ZN will be replaced !!
# IndexFile has group UNL !!
# Group UNL will be replaced !!
# IndexFile has group MG !!
# Group MG will be replaced !!
# IndexFile has group ZN !!
# Group ZN will be replaced !!
# IndexFile has group UNL !!
# Group UNL will be replaced !!
# IndexFile has group MG !!
# Group MG will be replaced !!
# IndexFile has group ZN !!
# Group ZN will be replaced !!
# IndexFile has group UNL !!
# Group UNL will be replaced !!IndexFile has group MG !!
#
# Group MG will be replaced !!
# IndexFile has group ZN !!
# Group ZN will be replaced !!
# IndexFile has group UNL !!
# Group UNL will be replaced !!
# edge_JAN_PDE2_1345_set4_121456
# edge_JAN_PDE2_1345_set4_49395
# edge_JAN_PDE2_1345_set4_122492
# edge_JAN_PDE2_1345_set4_240197
# IndexFile has group MG !!
# Group MG will be replaced !!
# IndexFile has group ZN !!
# Group ZN will be replaced !!
# IndexFile has group UNL !!
# Group UNL will be replaced !!
# IndexFile has group MG !!
# Group MG will be replaced !!
# IndexFile has group ZN !!
# Group ZN will be replaced !!
# IndexFile has group UNL !! IndexFile has group MG !!
# Group UNL will be replaced !!
#
# Group MG will be replaced !!
# IndexFile has group ZN !!
# Group ZN will be replaced !!
# IndexFile has group UNL !!
# Group UNL will be replaced !!
# edge_JAN_PDE2_1345_set4_120342
# edge_JAN_PDE2_1345_set4_240165
# edge_JAN_PDE2_1345_set4_204440
# IndexFile has group MG !!
# Group MG will be replaced !!
# IndexFile has group ZN !!
# Group ZN will be replaced !!
# IndexFile has group UNL !!
# Group UNL will be replaced !!
# IndexFile has group MG !!
# Group MG will be replaced !!
# IndexFile has group ZN !!
# Group ZN will be replaced !!
# IndexFile has group UNL !!
# Group UNL will be replaced !!
# IndexFile has group MG !!
# Group MG will be replaced !!
# IndexFile has group ZN !!
# Group ZN will be replaced !!
# IndexFile has group UNL !!
# Group UNL will be replaced !!
# IndexFile has group MG !!
# Group MG will be replaced !!
# IndexFile has group ZN !!
# Group ZN will be replaced !!
# IndexFile has group UNL !!
# Group UNL will be replaced !!
# edge_JAN_PDE2_1345_set4_376385
# edge_JAN_PDE2_1345_set4_315055
# edge_JAN_PDE2_1345_set4_46563
# IndexFile has group MG !!
# Group MG will be replaced !!
# IndexFile has group ZN !!
# Group ZN will be replaced !!
# IndexFile has group UNL !!
# Group UNL will be replaced !!
# edge_JAN_PDE2_1345_set4_73781
# edge_JAN_PDE2_1345_set4_204476
# IndexFile has group MG !!
# Group MG will be replaced !!
# IndexFile has group ZN !!
# Group ZN will be replaced !!
# IndexFile has group UNL !!
# Group UNL will be replaced !!
# IndexFile has group MG !!
# Group MG will be replaced !!
# IndexFile has group ZN !!
# Group ZN will be replaced !!
# IndexFile has group UNL !!
# Group UNL will be replaced !!
# IndexFile has group MG !!
# Group MG will be replaced !!
# IndexFile has group ZN !!
# Group ZN will be replaced !!
# IndexFile has group UNL !!
# Group UNL will be replaced !!
# IndexFile has group MG !!
# Group MG will be replaced !!
# IndexFile has group ZN !!
# Group ZN will be replaced !!
# edge_JAN_PDE2_1345_set4_297010
# IndexFile has group UNL !!
# Group UNL will be replaced !!
# edge_JAN_PDE2_1345_set4_200493
# edge_JAN_PDE2_1345_set4_1830
# edge_JAN_PDE2_1345_set4_282491
# IndexFile has group MG !!
# Group MG will be replaced !!
# IndexFile has group ZN !!
# Group ZN will be replaced !!
# IndexFile has group UNL !!
# Group UNL will be replaced !!
# IndexFile has group MG !!
# Group MG will be replaced !!
# IndexFile has group ZN !!
# Group ZN will be replaced !!
# IndexFile has group UNL !!
# Group UNL will be replaced !!
# IndexFile has group MG !!
# Group MG will be replaced !!
# IndexFile has group ZN !!
# Group ZN will be replaced !!
# IndexFile has group UNL !!
# Group UNL will be replaced !!
# edge_JAN_PDE2_1345_set4_240139
# IndexFile has group MG !!
# Group MG will be replaced !!
# IndexFile has group ZN !!
# Group ZN will be replaced !!
# IndexFile has group UNL !!
# Group UNL will be replaced !!
# edge_JAN_PDE2_1345_set4_287279
# edge_JAN_PDE2_1345_set4_287340
# edge_JAN_PDE2_1345_set4_48416
# IndexFile has group MG !!
# Group MG will be replaced !!
# IndexFile has group ZN !!
# Group ZN will be replaced !!
# IndexFile has group UNL !!
# Group UNL will be replaced !!
# IndexFile has group MG !!
# Group MG will be replaced !!
# IndexFile has group ZN !!
# Group ZN will be replaced !!
# IndexFile has group UNL !!
# Group UNL will be replaced !!
# IndexFile has group MG !!
# Group MG will be replaced !!
# IndexFile has group ZN !!
# Group ZN will be replaced !!
# IndexFile has group UNL !!
# Group UNL will be replaced !!
# edge_JAN_PDE2_1345_set4_204510
# edge_JAN_PDE2_1345_set4_12308
# IndexFile has group MG !!
# Group MG will be replaced !!
# edge_JAN_PDE2_1345_set4_190853
# IndexFile has group ZN !!
# Group ZN will be replaced !!
# IndexFile has group UNL !!
# Group UNL will be replaced !!
# IndexFile has group MG !!
# Group MG will be replaced !!
# IndexFile has group ZN !!
# Group ZN will be replaced !!
# IndexFile has group UNL !!
# Group UNL will be replaced !!
# IndexFile has group MG !!
# Group MG will be replaced !!
# IndexFile has group ZN !!
# Group ZN will be replaced !!
# IndexFile has group UNL !!
# Group UNL will be replaced !!
# IndexFile has group MG !!
# Group MG will be replaced !!
# IndexFile has group ZN !!
# Group ZN will be replaced !!
# IndexFile has group UNL !!
# Group UNL will be replaced !!
# edge_JAN_PDE2_1345_set4_73446
# edge_JAN_PDE2_1345_set4_7467
# IndexFile has group MG !!
# Group MG will be replaced !!
# IndexFile has group ZN !!
# Group ZN will be replaced !!
# IndexFile has group UNL !!
# Group UNL will be replaced !!
# IndexFile has group MG !!
# Group MG will be replaced !!
# IndexFile has group ZN !!
# Group ZN will be replaced !!
# IndexFile has group UNL !!
# Group UNL will be replaced !!
# edge_JAN_PDE2_1345_set4_190819
# edge_JAN_PDE2_1345_set4_49408
# IndexFile has group MG !!
# Group MG will be replaced !!
# IndexFile has group ZN !!
# Group ZN will be replaced !!
# IndexFile has group UNL !!
# Group UNL will be replaced !!
# IndexFile has group MG !!
# Group MG will be replaced !!
# IndexFile has group ZN !!
# Group ZN will be replaced !!
# IndexFile has group UNL !!
# Group UNL will be replaced !!
# edge_JAN_PDE2_1345_set4_200833
# edge_JAN_PDE2_1345_set4_318271
# IndexFile has group MG !!
# Group MG will be replaced !!
# IndexFile has group ZN !!
# Group ZN will be replaced !!
# IndexFile has group UNL !!
# Group UNL will be replaced !!
# IndexFile has group MG !!
# Group MG will be replaced !!
# IndexFile has group ZN !!
# Group ZN will be replaced !!
# IndexFile has group UNL !!
# Group UNL will be replaced !!
# edge_JAN_PDE2_1345_set4_7276
# edge_JAN_PDE2_1345_set4_295347
# IndexFile has group MG !!
# Group MG will be replaced !!
# IndexFile has group ZN !!
# Group ZN will be replaced !!
# IndexFile has group UNL !!
# Group UNL will be replaced !!
# IndexFile has group MG !!
# Group MG will be replaced !!
# IndexFile has group ZN !!
# Group ZN will be replaced !!
# IndexFile has group UNL !!
# Group UNL will be replaced !!
# edge_JAN_PDE2_1345_set4_43306
# edge_JAN_PDE2_1345_set4_28055
# IndexFile has group MG !!
# Group MG will be replaced !!
# IndexFile has group ZN !!
# Group ZN will be replaced !!
# IndexFile has group UNL !!
# Group UNL will be replaced !!
# IndexFile has group MG !!
# Group MG will be replaced !!
# IndexFile has group ZN !!
# Group ZN will be replaced !!
# IndexFile has group UNL !!
# Group UNL will be replaced !!
# DONE

# %% [markdown]
# `2b. Energy minimization.`<br>
# Prepare the simulation and subsequently either<br>
#  a) run locally (suitable for the tutorial purpose)<br>
#  b) create jobscripts to submit to the cluster

# %%
fe.prepare_simulation( simType='em', bLig=True, bProt=True, n_processes=8  )
# Out:
# -----------------------------------------
# Preparing simulation: em
# -----------------------------------------
# edge_JAN_PDE2_1345_set4_316733
# edge_JAN_PDE2_1345_set4_190914
# edge_JAN_PDE2_1345_set4_190778
# edge_JAN_PDE2_1345_set4_71401
# edge_JAN_PDE2_1345_set4_46560
# edge_JAN_PDE2_1345_set4_315931
# edge_JAN_PDE2_1345_set4_49417
# edge_JAN_PDE2_1345_set4_318412
# edge_JAN_PDE2_1345_set4_314311
# edge_JAN_PDE2_1345_set4_46739
# edge_JAN_PDE2_1345_set4_73375
# edge_JAN_PDE2_1345_set4_72639
# edge_JAN_PDE2_1345_set4_73883
# edge_JAN_PDE2_1345_set4_240291
# edge_JAN_PDE2_1345_set4_287307
# edge_JAN_PDE2_1345_set4_200839
# edge_JAN_PDE2_1345_set4_39459
# edge_JAN_PDE2_1345_set4_44746
# edge_JAN_PDE2_1345_set4_190844
# edge_JAN_PDE2_1345_set4_204549
# edge_JAN_PDE2_1345_set4_204487
# edge_JAN_PDE2_1345_set4_202087
# edge_JAN_PDE2_1345_set4_9233
# edge_JAN_PDE2_1345_set4_204497
# edge_JAN_PDE2_1345_set4_121483
# edge_JAN_PDE2_1345_set4_357530
# edge_JAN_PDE2_1345_set4_190886
# edge_JAN_PDE2_1345_set4_122460
# edge_JAN_PDE2_1345_set4_73008
# edge_JAN_PDE2_1345_set4_122463
# edge_JAN_PDE2_1345_set4_200519
# edge_JAN_PDE2_1345_set4_239416
# edge_JAN_PDE2_1345_set4_204450
# edge_JAN_PDE2_1345_set4_186054
# edge_JAN_PDE2_1345_set4_26471
# edge_JAN_PDE2_1345_set4_73724
# edge_JAN_PDE2_1345_set4_187035
# edge_JAN_PDE2_1345_set4_121458
# edge_JAN_PDE2_1345_set4_204316
# edge_JAN_PDE2_1345_set4_204440
# edge_JAN_PDE2_1345_set4_49347
# edge_JAN_PDE2_1345_set4_190882
# edge_JAN_PDE2_1345_set4_190807
# edge_JAN_PDE2_1345_set4_72600
# edge_JAN_PDE2_1345_set4_73153
# edge_JAN_PDE2_1345_set4_287108
# edge_JAN_PDE2_1345_set4_315054
# edge_JAN_PDE2_1345_set4_315055
# edge_JAN_PDE2_1345_set4_188271
# edge_JAN_PDE2_1345_set4_122489
# edge_JAN_PDE2_1345_set4_73813
# edge_JAN_PDE2_1345_set4_204435
# edge_JAN_PDE2_1345_set4_318340
# edge_JAN_PDE2_1345_set4_7468
# edge_JAN_PDE2_1345_set4_287305
# edge_JAN_PDE2_1345_set4_200493
# edge_JAN_PDE2_1345_set4_73007
# edge_JAN_PDE2_1345_set4_72643
# edge_JAN_PDE2_1345_set4_316574
# edge_JAN_PDE2_1345_set4_121481
# edge_JAN_PDE2_1345_set4_121456
# edge_JAN_PDE2_1345_set4_71992
# edge_JAN_PDE2_1345_set4_186899
# edge_JAN_PDE2_1345_set4_358538
# edge_JAN_PDE2_1345_set4_122477
# edge_JAN_PDE2_1345_set4_73781
# edge_JAN_PDE2_1345_set4_237843
# edge_JAN_PDE2_1345_set4_297010
# edge_JAN_PDE2_1345_set4_376385
# edge_JAN_PDE2_1345_set4_240139
# edge_JAN_PDE2_1345_set4_200833
# edge_JAN_PDE2_1345_set4_204510
# edge_JAN_PDE2_1345_set4_316584
# edge_JAN_PDE2_1345_set4_49395
# edge_JAN_PDE2_1345_set4_204476
# edge_JAN_PDE2_1345_set4_295347
# edge_JAN_PDE2_1345_set4_315639
# edge_JAN_PDE2_1345_set4_1830
# edge_JAN_PDE2_1345_set4_190853
# edge_JAN_PDE2_1345_set4_7467
# edge_JAN_PDE2_1345_set4_122492
# edge_JAN_PDE2_1345_set4_282491
# edge_JAN_PDE2_1345_set4_120342
# edge_JAN_PDE2_1345_set4_28055
# edge_JAN_PDE2_1345_set4_117342
# edge_JAN_PDE2_1345_set4_12907
# edge_JAN_PDE2_1345_set4_73446
# edge_JAN_PDE2_1345_set4_49408
# edge_JAN_PDE2_1345_set4_240165
# edge_JAN_PDE2_1345_set4_287279
# edge_JAN_PDE2_1345_set4_46563
# edge_JAN_PDE2_1345_set4_48416
# edge_JAN_PDE2_1345_set4_240197
# edge_JAN_PDE2_1345_set4_358553
# edge_JAN_PDE2_1345_set4_318271
# edge_JAN_PDE2_1345_set4_190819
# edge_JAN_PDE2_1345_set4_7276
# edge_JAN_PDE2_1345_set4_43306
# edge_JAN_PDE2_1345_set4_287340
# edge_JAN_PDE2_1345_set4_12308

# %% [markdown]
# Running energy minimization locally (e.g. on a laptop) will take 10-15 minutes for one edge.<br>
# You can use the command below for that.
# If you do not want to wait that long and have an access to a cluster, skip this step and proceed to the next step.

# %%
#fe.run_simulation_locally( simType='em', bProt=True, bLig=False, bVerbose=True, mdrun=["mdrun_threads_d"])

# %% [markdown]
# We can also submit the jobs to run on the cluster.<br>
# This, naturally, requires some knowledge of the cluster available, queueing system and some dependencies. Several jobscript parameters allow to define the environment on the cluster. If there are additional cluster specifics, the jobscripts can be easily modified.<br>
#
# Together with the jobscripts, a script `submit.py` will be generated. This script can be used to simply submit all the jobs to the cluster.

# %%
# set several parameters
#fe.JOBqueue = 'SGE'
#fe.JOBsource = ['/etc/profile.d/modules.sh','/usr/local/gromacs/GMXRC2021']
#fe.JOBmodules = ['shared','owl/intel-mpi-default','cuda91']
fe.JOBqueue = 'SLURM'
fe.JOBsource = ['/usr/local/gromacs/GMXRC2021']
fe.JOBmodules = []
fe.JOBbGPU = True
fe.JOBgmx = 'mdrun_threads_d'
#fe.JOBsimcpu = 20
fe.JOBsimtime = 2 # hours
#fe.JOBpartition = 'p20'

fe.JOBsimcpu = None
fe.JOBpartition = 'p20,p16,p10,p08'

# create the jobscripts
fe.prepare_jobscripts(simType='em', bProt=True, bLig=True)
# Out:
# ---------------------------------------------
# Preparing jobscripts for: em
# ---------------------------------------------
# DONE

# %%
# set several parameters
fe.JOBqueue = 'SGE'
fe.JOBsource = ['/etc/profile.d/modules.sh','/usr/local/gromacs/GMXRC2021']
fe.JOBmodules = ['shared','owl/intel-mpi-default','cuda91']
fe.JOBbGPU = True
fe.JOBgmx = 'mdrun_threads_d'
fe.JOBsimcpu = 10
fe.JOBsimtime = 2 # hours

# create the jobscripts
fe.prepare_jobscripts(simType='em', bProt=True, bLig=True)

# %% [markdown]
# # Check what stages are finished

# %%
print("protein:")

simType='em'
print("\t", simType)
for edge in fe.edges:
    for state in fe.states:
        for r in range(1,fe.replicas+1):
            simpath = fe._get_specific_path(edge=edge,wp='protein',state=state,r=r,sim=simType)
            if(not os.path.exists(f"{simpath}/confout.gro")):
                print(f"Not finished: {edge} {state} {r}")
                


# simType='eq_posre'
# print("\t", simType)
# for edge in fe.edges:
#     for state in fe.states:
#         for r in range(1,fe.replicas+1):
#             simpath = fe._get_specific_path(edge=edge,wp='protein',state=state,r=r,sim=simType)
#             if(not os.path.exists(f"{simpath}/confout.gro")):
#                 print(f"Not finished: {edge} {state} {r}")
                
# simType='eq'
# print("\t", simType)
# for edge in fe.edges:
#     for state in fe.states:
#         for r in range(1,fe.replicas+1):
#             simpath = fe._get_specific_path(edge=edge,wp='protein',state=state,r=r,sim=simType)
#             if(not os.path.exists(f"{simpath}/confout.gro")):
#                 print(f"Not finished: {edge} {state} {r}")
# Out:
# protein:
# 	 em

# %%
print("water:")

simType='em'
print("\t", simType)
for edge in fe.edges:
    for state in fe.states:
        for r in range(1,fe.replicas+1):
            simpath = fe._get_specific_path(edge=edge,wp='water',state=state,r=r,sim=simType)
            if(not os.path.exists(f"{simpath}/confout.gro")):
                print(f"Not finished: {edge} {state} {r}")
                
# simType='eq'
# print("\t", simType)
# for edge in fe.edges:
#     for state in fe.states:
#         for r in range(1,fe.replicas+1):
#             simpath = fe._get_specific_path(edge=edge,wp='water',state=state,r=r,sim=simType)
#             if(not os.path.exists(f"{simpath}/confout.gro")):
#                 print(f"Not finished: {edge} {state} {r}")
# Out:
# water:
# 	 em

# %% [markdown]
# # Posre only for Prot

# %% [markdown]
# `prepare and run NVT with simulated annealing to get the temp up smoothly`

# %%
fe.prepare_simulation( simType='eq_posre', bProt=True, bLig=False, n_processes=8)
# Out:
# -----------------------------------------
# Preparing simulation: eq_posre
# -----------------------------------------
# edge_JAN_PDE2_1345_set4_315931
# edge_JAN_PDE2_1345_set4_190778
# edge_JAN_PDE2_1345_set4_190914
# edge_JAN_PDE2_1345_set4_71401
# edge_JAN_PDE2_1345_set4_49417
# edge_JAN_PDE2_1345_set4_46560
# edge_JAN_PDE2_1345_set4_318412
# edge_JAN_PDE2_1345_set4_316733
# edge_JAN_PDE2_1345_set4_46739
# edge_JAN_PDE2_1345_set4_240291
# edge_JAN_PDE2_1345_set4_200839
# edge_JAN_PDE2_1345_set4_287307
# edge_JAN_PDE2_1345_set4_73883
# edge_JAN_PDE2_1345_set4_72639
# edge_JAN_PDE2_1345_set4_73375
# edge_JAN_PDE2_1345_set4_314311
# edge_JAN_PDE2_1345_set4_204497
# edge_JAN_PDE2_1345_set4_44746
# edge_JAN_PDE2_1345_set4_204487
# edge_JAN_PDE2_1345_set4_190844
# edge_JAN_PDE2_1345_set4_204549
# edge_JAN_PDE2_1345_set4_39459
# edge_JAN_PDE2_1345_set4_202087
# edge_JAN_PDE2_1345_set4_9233
# edge_JAN_PDE2_1345_set4_190886
# edge_JAN_PDE2_1345_set4_121483
# edge_JAN_PDE2_1345_set4_122460
# edge_JAN_PDE2_1345_set4_73008
# edge_JAN_PDE2_1345_set4_200519
# edge_JAN_PDE2_1345_set4_357530
# edge_JAN_PDE2_1345_set4_239416
# edge_JAN_PDE2_1345_set4_122463
# edge_JAN_PDE2_1345_set4_204450
# edge_JAN_PDE2_1345_set4_186054
# edge_JAN_PDE2_1345_set4_26471
# edge_JAN_PDE2_1345_set4_73724
# edge_JAN_PDE2_1345_set4_187035
# edge_JAN_PDE2_1345_set4_121458
# edge_JAN_PDE2_1345_set4_204316
# edge_JAN_PDE2_1345_set4_204440
# edge_JAN_PDE2_1345_set4_190882
# edge_JAN_PDE2_1345_set4_72600
# edge_JAN_PDE2_1345_set4_190807
# edge_JAN_PDE2_1345_set4_73153
# edge_JAN_PDE2_1345_set4_49347
# edge_JAN_PDE2_1345_set4_315055
# edge_JAN_PDE2_1345_set4_315054
# edge_JAN_PDE2_1345_set4_287108
# edge_JAN_PDE2_1345_set4_122489
# edge_JAN_PDE2_1345_set4_73813
# edge_JAN_PDE2_1345_set4_318340
# edge_JAN_PDE2_1345_set4_204435
# edge_JAN_PDE2_1345_set4_188271
# edge_JAN_PDE2_1345_set4_200493
# edge_JAN_PDE2_1345_set4_287305
# edge_JAN_PDE2_1345_set4_7468
# edge_JAN_PDE2_1345_set4_121481
# edge_JAN_PDE2_1345_set4_72643
# edge_JAN_PDE2_1345_set4_71992
# edge_JAN_PDE2_1345_set4_316574
# edge_JAN_PDE2_1345_set4_73007
# edge_JAN_PDE2_1345_set4_186899
# edge_JAN_PDE2_1345_set4_358538
# edge_JAN_PDE2_1345_set4_121456
# edge_JAN_PDE2_1345_set4_122477
# edge_JAN_PDE2_1345_set4_73781
# edge_JAN_PDE2_1345_set4_237843
# edge_JAN_PDE2_1345_set4_297010
# edge_JAN_PDE2_1345_set4_376385
# edge_JAN_PDE2_1345_set4_240139
# edge_JAN_PDE2_1345_set4_200833
# edge_JAN_PDE2_1345_set4_204510
# edge_JAN_PDE2_1345_set4_1830
# edge_JAN_PDE2_1345_set4_315639
# edge_JAN_PDE2_1345_set4_204476
# edge_JAN_PDE2_1345_set4_49395
# edge_JAN_PDE2_1345_set4_316584
# edge_JAN_PDE2_1345_set4_190853
# edge_JAN_PDE2_1345_set4_7467
# edge_JAN_PDE2_1345_set4_295347
# edge_JAN_PDE2_1345_set4_12907
# edge_JAN_PDE2_1345_set4_117342
# edge_JAN_PDE2_1345_set4_122492
# edge_JAN_PDE2_1345_set4_282491
# edge_JAN_PDE2_1345_set4_73446
# edge_JAN_PDE2_1345_set4_120342
# edge_JAN_PDE2_1345_set4_49408
# edge_JAN_PDE2_1345_set4_28055
# edge_JAN_PDE2_1345_set4_358553
# edge_JAN_PDE2_1345_set4_240197
# edge_JAN_PDE2_1345_set4_190819
# edge_JAN_PDE2_1345_set4_318271
# edge_JAN_PDE2_1345_set4_48416
# edge_JAN_PDE2_1345_set4_240165
# edge_JAN_PDE2_1345_set4_46563
# edge_JAN_PDE2_1345_set4_287279
# edge_JAN_PDE2_1345_set4_7276
# edge_JAN_PDE2_1345_set4_43306
# edge_JAN_PDE2_1345_set4_287340
# edge_JAN_PDE2_1345_set4_12308

# %%
#fe.run_simulation_locally( simType='eq_posre', bProt=True, bLig=False, bVerbose=True, mdrun=["mdrun_threads"])

# %%
fe.JOBqueue = 'SLURM'
fe.JOBsource = ['/usr/local/gromacs/GMXRC2021']
fe.JOBmodules = []
fe.JOBbGPU = True
fe.JOBgmx = 'mdrun_threads'
#fe.JOBsimcpu = 20
fe.JOBsimtime = 2 # hours
fe.JOBpartition = 'p20'
#fe.JOBpartition = 'p20,p16,p10,p08'

fe.prepare_jobscripts(simType='eq_posre', bProt=True, bLig=False)
# Out:
# ---------------------------------------------
# Preparing jobscripts for: eq_posre
# ---------------------------------------------
# DONE

# %%
# set several parameters
fe.JOBqueue = 'SGE'
fe.JOBsource = ['/etc/profile.d/modules.sh','/usr/local/gromacs/GMXRC2021']
fe.JOBmodules = ['shared','owl/intel-mpi-default','cuda91']
fe.JOBbGPU = True
fe.JOBgmx = 'mdrun_threads'
fe.JOBsimcpu = 10
fe.JOBsimtime = 2 # hours

# create the jobscripts
fe.prepare_jobscripts(simType='eq_posre', bProt=True, bLig=False)
# Out:
# ---------------------------------------------
# Preparing jobscripts for: eq_posre
# ---------------------------------------------
# DONE

# %% [markdown]
# ### Check eq_posre completition

# %%
simType='eq_posre'
for edge in fe.edges:
    for state in fe.states:
        for r in range(1,fe.replicas+1):
            simpath = fe._get_specific_path(edge=edge,wp='protein',state=state,r=r,sim=simType)
            if(not os.path.exists(f"{simpath}/confout.gro")):
                print(f"Not finished: {edge} {state} {r}")

# %%
# # TI xvgs are incomplete and NPT took a long time
# unstable_edges_names=[
#     "edge_JAN_PDE2_1345_set4_26990",
# ]

# stable_edges={e:fe.edges[e] for e in fe.edges if e not in unstable_edges_names}

# %% [markdown]
# `2c. Once the energy minimization has finished, we can prepare equilibrium simulations.`

# %%
#fe.prepare_simulation( simType='eq', bProt=True, bLig=True, n_processes=8, edges=stable_edges)
# fe.prepare_simulation( simType='eq', bProt=True, bLig=True, n_processes=8, edges=rerun_edges)
fe.prepare_simulation( simType='eq', bProt=True, bLig=True, n_processes=8)
# Out:
# -----------------------------------------
# Preparing simulation: eq
# -----------------------------------------
# edge_JAN_PDE2_1345_set4_46560
# edge_JAN_PDE2_1345_set4_190778
# edge_JAN_PDE2_1345_set4_318412
# edge_JAN_PDE2_1345_set4_315931
# edge_JAN_PDE2_1345_set4_190914
# edge_JAN_PDE2_1345_set4_316733
# edge_JAN_PDE2_1345_set4_71401
# edge_JAN_PDE2_1345_set4_49417
# edge_JAN_PDE2_1345_set4_73375
# edge_JAN_PDE2_1345_set4_200839
# edge_JAN_PDE2_1345_set4_73883
# edge_JAN_PDE2_1345_set4_240291
# edge_JAN_PDE2_1345_set4_46739
# edge_JAN_PDE2_1345_set4_287307
# edge_JAN_PDE2_1345_set4_72639
# edge_JAN_PDE2_1345_set4_314311
# edge_JAN_PDE2_1345_set4_204549
# edge_JAN_PDE2_1345_set4_190844
# edge_JAN_PDE2_1345_set4_204487
# edge_JAN_PDE2_1345_set4_39459
# edge_JAN_PDE2_1345_set4_202087
# edge_JAN_PDE2_1345_set4_204497
# edge_JAN_PDE2_1345_set4_44746
# edge_JAN_PDE2_1345_set4_9233
# edge_JAN_PDE2_1345_set4_239416
# edge_JAN_PDE2_1345_set4_121483
# edge_JAN_PDE2_1345_set4_122460
# edge_JAN_PDE2_1345_set4_200519
# edge_JAN_PDE2_1345_set4_73008
# edge_JAN_PDE2_1345_set4_122463
# edge_JAN_PDE2_1345_set4_204450
# edge_JAN_PDE2_1345_set4_357530
# edge_JAN_PDE2_1345_set4_190886
# edge_JAN_PDE2_1345_set4_186054
# edge_JAN_PDE2_1345_set4_26471
# edge_JAN_PDE2_1345_set4_73724
# edge_JAN_PDE2_1345_set4_187035
# edge_JAN_PDE2_1345_set4_121458
# edge_JAN_PDE2_1345_set4_190882
# edge_JAN_PDE2_1345_set4_72600
# edge_JAN_PDE2_1345_set4_204316
# edge_JAN_PDE2_1345_set4_204440
# edge_JAN_PDE2_1345_set4_190807
# edge_JAN_PDE2_1345_set4_122489
# edge_JAN_PDE2_1345_set4_73153
# edge_JAN_PDE2_1345_set4_49347
# edge_JAN_PDE2_1345_set4_287108
# edge_JAN_PDE2_1345_set4_188271
# edge_JAN_PDE2_1345_set4_315054
# edge_JAN_PDE2_1345_set4_315055
# edge_JAN_PDE2_1345_set4_318340
# edge_JAN_PDE2_1345_set4_73813
# edge_JAN_PDE2_1345_set4_72643
# edge_JAN_PDE2_1345_set4_287305
# edge_JAN_PDE2_1345_set4_204435
# edge_JAN_PDE2_1345_set4_73007
# edge_JAN_PDE2_1345_set4_200493
# edge_JAN_PDE2_1345_set4_121481
# edge_JAN_PDE2_1345_set4_7468
# edge_JAN_PDE2_1345_set4_122477
# edge_JAN_PDE2_1345_set4_71992
# edge_JAN_PDE2_1345_set4_73781
# edge_JAN_PDE2_1345_set4_121456
# edge_JAN_PDE2_1345_set4_237843
# edge_JAN_PDE2_1345_set4_316574
# edge_JAN_PDE2_1345_set4_358538
# edge_JAN_PDE2_1345_set4_186899
# edge_JAN_PDE2_1345_set4_316584
# edge_JAN_PDE2_1345_set4_1830
# edge_JAN_PDE2_1345_set4_297010
# edge_JAN_PDE2_1345_set4_376385
# edge_JAN_PDE2_1345_set4_49395
# edge_JAN_PDE2_1345_set4_240139
# edge_JAN_PDE2_1345_set4_200833
# edge_JAN_PDE2_1345_set4_204510
# edge_JAN_PDE2_1345_set4_122492
# edge_JAN_PDE2_1345_set4_12907
# edge_JAN_PDE2_1345_set4_315639
# edge_JAN_PDE2_1345_set4_204476
# edge_JAN_PDE2_1345_set4_120342
# edge_JAN_PDE2_1345_set4_295347
# edge_JAN_PDE2_1345_set4_7467
# edge_JAN_PDE2_1345_set4_190853
# edge_JAN_PDE2_1345_set4_358553
# edge_JAN_PDE2_1345_set4_240165
# edge_JAN_PDE2_1345_set4_117342
# edge_JAN_PDE2_1345_set4_282491
# edge_JAN_PDE2_1345_set4_46563
# edge_JAN_PDE2_1345_set4_28055
# edge_JAN_PDE2_1345_set4_49408
# edge_JAN_PDE2_1345_set4_7276
# edge_JAN_PDE2_1345_set4_73446
# edge_JAN_PDE2_1345_set4_48416
# edge_JAN_PDE2_1345_set4_190819
# edge_JAN_PDE2_1345_set4_240197
# edge_JAN_PDE2_1345_set4_318271
# edge_JAN_PDE2_1345_set4_43306
# edge_JAN_PDE2_1345_set4_287279
# edge_JAN_PDE2_1345_set4_287340
# edge_JAN_PDE2_1345_set4_12308

# %%
#fe.run_simulation_locally( simType='eq', bProt=True, bLig=False, bVerbose=True, mdrun=["mdrun_threads"])

# %% [markdown]
# Again, prepare and submit the equilibrium simulation jobs to the cluster.<br>
# This time the calculation will take longer (we are performing 6 ns simulations).<br>
# On a node with a GPU and 8 CPUs simulations of ligand in water will take ~2 hours, ligand-protein complex will take ~10 hours.

# %%
fe.JOBqueue = 'SLURM'
fe.JOBsource = ['/usr/local/gromacs/GMXRC2021']
fe.JOBmodules = []
fe.JOBbGPU = True
fe.JOBgmx = 'mdrun_threads'
#fe.JOBsimcpu = 20
fe.JOBsimtime = 23 # hours
#fe.JOBpartition = 'p20'
fe.JOBsimcpu = None
fe.JOBpartition = 'p20,p16,p10,p08'

fe.prepare_jobscripts(simType='eq',  bLig=True, bProt=True)
# Out:
# ---------------------------------------------
# Preparing jobscripts for: eq
# ---------------------------------------------
# DONE

# %%
#fe.prepare_simulation( simType='eq', bProt=True, bLig=True, n_processes=8, edges=rerun_edges)
fe.prepare_simulation( simType='eq', bProt=True, bLig=True, n_processes=8)

fe.JOBqueue = 'SGE'
fe.JOBsource = ['/etc/profile.d/modules.sh','/usr/local/gromacs/GMXRC2021']
fe.JOBmodules = ['shared','owl/intel-mpi-default','cuda91']
fe.JOBgmx = 'mdrun_threads'
fe.JOBsimcpu = 20
fe.JOBsimtime = 10 # hours

#fe.prepare_jobscripts(simType='eq',  bLig=True, bProt=True, edges=stable_edges)
fe.prepare_jobscripts(simType='eq',  bLig=True, bProt=True)
# Out:
# -----------------------------------------
# Preparing simulation: eq
# -----------------------------------------
# edge_JAN_PDE2_1345_set4_49417
# edge_JAN_PDE2_1345_set4_315931
# edge_JAN_PDE2_1345_set4_71401
# edge_JAN_PDE2_1345_set4_46560
# edge_JAN_PDE2_1345_set4_190914
# edge_JAN_PDE2_1345_set4_318412
# edge_JAN_PDE2_1345_set4_316733
# edge_JAN_PDE2_1345_set4_190778
# edge_JAN_PDE2_1345_set4_314311
# edge_JAN_PDE2_1345_set4_200839
# edge_JAN_PDE2_1345_set4_73375
# edge_JAN_PDE2_1345_set4_72639
# edge_JAN_PDE2_1345_set4_287307
# edge_JAN_PDE2_1345_set4_46739
# edge_JAN_PDE2_1345_set4_73883
# edge_JAN_PDE2_1345_set4_240291
# edge_JAN_PDE2_1345_set4_190844
# edge_JAN_PDE2_1345_set4_204549
# edge_JAN_PDE2_1345_set4_204487
# edge_JAN_PDE2_1345_set4_39459
# edge_JAN_PDE2_1345_set4_204497
# edge_JAN_PDE2_1345_set4_44746
# edge_JAN_PDE2_1345_set4_202087
# edge_JAN_PDE2_1345_set4_9233
# edge_JAN_PDE2_1345_set4_239416
# edge_JAN_PDE2_1345_set4_121483
# edge_JAN_PDE2_1345_set4_122460
# edge_JAN_PDE2_1345_set4_73008
# edge_JAN_PDE2_1345_set4_122463
# edge_JAN_PDE2_1345_set4_200519
# edge_JAN_PDE2_1345_set4_190886
# edge_JAN_PDE2_1345_set4_357530
# edge_JAN_PDE2_1345_set4_204450
# edge_JAN_PDE2_1345_set4_190882
# edge_JAN_PDE2_1345_set4_122489
# edge_JAN_PDE2_1345_set4_186054
# edge_JAN_PDE2_1345_set4_26471
# edge_JAN_PDE2_1345_set4_73724
# edge_JAN_PDE2_1345_set4_187035
# edge_JAN_PDE2_1345_set4_121458
# edge_JAN_PDE2_1345_set4_204440
# edge_JAN_PDE2_1345_set4_72600
# edge_JAN_PDE2_1345_set4_204316
# edge_JAN_PDE2_1345_set4_72643
# edge_JAN_PDE2_1345_set4_188271
# edge_JAN_PDE2_1345_set4_49347
# edge_JAN_PDE2_1345_set4_73153
# edge_JAN_PDE2_1345_set4_190807
# edge_JAN_PDE2_1345_set4_287108
# edge_JAN_PDE2_1345_set4_315055
# edge_JAN_PDE2_1345_set4_315054
# edge_JAN_PDE2_1345_set4_73007
# edge_JAN_PDE2_1345_set4_73813
# edge_JAN_PDE2_1345_set4_287305
# edge_JAN_PDE2_1345_set4_318340
# edge_JAN_PDE2_1345_set4_204435
# edge_JAN_PDE2_1345_set4_7468
# edge_JAN_PDE2_1345_set4_121481
# edge_JAN_PDE2_1345_set4_200493
# edge_JAN_PDE2_1345_set4_122477
# edge_JAN_PDE2_1345_set4_73781
# edge_JAN_PDE2_1345_set4_237843
# edge_JAN_PDE2_1345_set4_71992
# edge_JAN_PDE2_1345_set4_121456
# edge_JAN_PDE2_1345_set4_358538
# edge_JAN_PDE2_1345_set4_316574
# edge_JAN_PDE2_1345_set4_186899
# edge_JAN_PDE2_1345_set4_1830
# edge_JAN_PDE2_1345_set4_297010
# edge_JAN_PDE2_1345_set4_240139
# edge_JAN_PDE2_1345_set4_200833
# edge_JAN_PDE2_1345_set4_376385
# edge_JAN_PDE2_1345_set4_204510
# edge_JAN_PDE2_1345_set4_49395
# edge_JAN_PDE2_1345_set4_316584
# edge_JAN_PDE2_1345_set4_190853
# edge_JAN_PDE2_1345_set4_7467
# edge_JAN_PDE2_1345_set4_315639
# edge_JAN_PDE2_1345_set4_122492
# edge_JAN_PDE2_1345_set4_12907
# edge_JAN_PDE2_1345_set4_295347
# edge_JAN_PDE2_1345_set4_204476
# edge_JAN_PDE2_1345_set4_120342
# edge_JAN_PDE2_1345_set4_240165
# edge_JAN_PDE2_1345_set4_358553
# edge_JAN_PDE2_1345_set4_28055
# edge_JAN_PDE2_1345_set4_49408
# edge_JAN_PDE2_1345_set4_117342
# edge_JAN_PDE2_1345_set4_282491
# edge_JAN_PDE2_1345_set4_73446
# edge_JAN_PDE2_1345_set4_48416
# edge_JAN_PDE2_1345_set4_46563
# edge_JAN_PDE2_1345_set4_240197
# edge_JAN_PDE2_1345_set4_7276
# edge_JAN_PDE2_1345_set4_190819
# edge_JAN_PDE2_1345_set4_318271
# edge_JAN_PDE2_1345_set4_43306
# edge_JAN_PDE2_1345_set4_287279
# edge_JAN_PDE2_1345_set4_287340
# edge_JAN_PDE2_1345_set4_12308
# ---------------------------------------------
# Preparing jobscripts for: eq
# ---------------------------------------------
# DONE

# %% [markdown]
# # exclude slow running edges (NPT not done yet)

# %%
# find slow-running edges
slow_edges_names=[]

simType='eq'
print("\t", simType)
print("\t\t protein")
for edge in fe.edges:
    for state in fe.states:
        for r in range(1,fe.replicas+1):
            simpath = fe._get_specific_path(edge=edge,wp='protein',state=state,r=r,sim=simType)
            if(not os.path.exists(f"{simpath}/confout.gro")):
                print(f"Not finished: {edge} {state} {r}")
                slow_edges_names.append(edge)
                
print("\t\t water")
for edge in fe.edges:
    for state in fe.states:
        for r in range(1,fe.replicas+1):
            simpath = fe._get_specific_path(edge=edge,wp='water',state=state,r=r,sim=simType)
            if(not os.path.exists(f"{simpath}/confout.gro")):
                print(f"Not finished: {edge} {state} {r}")
                slow_edges_names.append(edge)
                
#make sure they are unique
slow_edges_names=list(set(slow_edges_names))
# Out:
# 	 eq
# 		 protein
# 		 water

# %%
# slow_edges_names=[
#     "edge_JAN_PDE2_1345_set4_26990",
#     "edge_JAN_PDE2_1345_set4_5596"
# ]

# %%
normal_edges={e:fe.edges[e] for e in fe.edges if e not in slow_edges_names}
slow_edges={e:fe.edges[e] for e in fe.edges if e in slow_edges_names}
print(slow_edges)
# Out:
# {}

# %% [markdown]
# # Run TI on the edges that finished eq
# no unstable opnes this time

# %%
fe.JOBqueue = 'SGE'
fe.JOBsource = ['/etc/profile.d/modules.sh','/usr/local/gromacs/GMXRC2021']
fe.JOBmodules = ['shared','owl/intel-mpi-default','cuda91']
fe.JOBgmx = 'mdrun_threads'
fe.JOBsimcpu = 20
fe.JOBsimtime = 8 # hours
fe.prepare_jobscripts(simType='transitions',  bLig=True, bProt=True, edges=normal_edges )
# fe.prepare_jobscripts(simType='transitions',  bLig=True, bProt=True, edges=slow_edges, job_folder_suffix="_from_slow_NPT" )
# fe.prepare_jobscripts(simType='transitions',  bLig=True, bProt=True )
# Out:
# ---------------------------------------------
# Preparing jobscripts for: transitions
# ---------------------------------------------
# DONE

# %% [markdown]
# # Check structure of unstable lig

# %%
unstable_ligs=[]
unstable_lignames=[]
for i,l in enumerate(test_ligs):
    if("edge_JAN_PDE2_1345_"+l.GetProp("ID") in unstable_edges_names):
        unstable_ligs.append(l)
        unstable_lignames.append(l.GetProp("ID"))

Draw.MolsToGridImage([Chem.MolFromSmiles(Chem.MolToSmiles(lig))for lig in unstable_ligs], legends=unstable_lignames,
                     subImgSize = (200,200), molsPerRow=2, maxMols=10)

# %% [markdown]
# # Analysis

# %% [markdown]
# ----------------
# Step 4. Analysis
# ------------------

# %% [markdown]
# `4a.` Firstly, let's process the calculated work values and estimate free energy differences.<br>
# The `pmx analyse` program will integrate the dhdl.xvg files to obtain the forward and reverse work values.<br>
# Subsequently, the Crooks fluctuation theorem and Jarzynski estimators will be applied to relate the work distributions to $\Delta G$

# %%
# # TI xvgs are incomplete and NPT took a long time
# not_finsished_edges_names=[
#     "edge_JAN_PDE2_1345_set4_26990",
#     "edge_JAN_PDE2_1345_set4_5596",
# #     "edge_JAN_PDE2_1345_set4_42807",
# #     "edge_JAN_PDE2_1345_set4_375984"
# ]

# finished_edges={e:fe.edges[e] for e in fe.edges if e not in not_finsished_edges_names}

# %%
# build a list of finished edges

finished_edges_names=[]

for edge in tqdm(fe.edges):
    fin=[False]*fe.replicas
    for r in range(1,fe.replicas+1):
        # ligand
        wp = 'water'
        analysispath = '{0}/analyse{1}'.format(fe._get_specific_path(edge=edge,wp=wp),r)
        create_folder(analysispath)
        stateApath = fe._get_specific_path(edge=edge,wp=wp,state='stateA',r=r,sim='transitions')
        stateBpath = fe._get_specific_path(edge=edge,wp=wp,state='stateB',r=r,sim='transitions')
        gA_w = glob.glob('{0}/*xvg'.format(stateApath))
        gB_w = glob.glob('{0}/*xvg'.format(stateBpath))

        # protein
        wp = 'protein'
        analysispath = '{0}/analyse{1}'.format(fe._get_specific_path(edge=edge,wp=wp),r)
        create_folder(analysispath)
        stateApath = fe._get_specific_path(edge=edge,wp=wp,state='stateA',r=r,sim='transitions')
        stateBpath = fe._get_specific_path(edge=edge,wp=wp,state='stateB',r=r,sim='transitions')
        gA_p = glob.glob('{0}/*xvg'.format(stateApath))
        gB_p = glob.glob('{0}/*xvg'.format(stateBpath))

        if(len(gA_w)>=80 and len(gB_w)>=80 and len(gA_p)>=80 and len(gB_p)>=80):
            fin[r-1]=True
    if(all(fin)):
        finished_edges_names.append(edge)

finished_edges={e:fe.edges[e] for e in finished_edges_names}
# print(finished_edges)
print(len(finished_edges))
# Out:
# 100%|██████████| 100/100 [00:00<00:00, 353.05it/s]
# 100

# %%
#fe.run_analysis( bVerbose=True)

# excluded=["edge_JAN_PDE2_1345_JAN_PDE2_994"] # we don't have water for this one yet
# ana_edges={x: fe.edges[x] for x in fe.edges if x not in excluded}
# fe.run_analysis(edges=ana_edges, bLig=False, bProt=True, bVerbose=False)

# fe.run_analysis( bLig=False, bProt=True, bVerbose=False)
# fe.run_analysis( bLig=True, bProt=True, bVerbose=False, only_check_completition=True)
fe.run_analysis( bLig=True, bProt=True, bVerbose=False,
                 n_processes=min(8, len(finished_edges)),
                 edges=finished_edges )
# fe.run_analysis( bLig=True, bProt=True, bVerbose=False, n_processes=8)
# Out:
# ----------------
# Running analysis
# ----------------
# edge_JAN_PDE2_1345_set4_190778
# edge_JAN_PDE2_1345_set4_190914
# edge_JAN_PDE2_1345_set4_71401
# edge_JAN_PDE2_1345_set4_46560
# edge_JAN_PDE2_1345_set4_316733
# edge_JAN_PDE2_1345_set4_49417
# edge_JAN_PDE2_1345_set4_315931
# edge_JAN_PDE2_1345_set4_318412
# edge_JAN_PDE2_1345_set4_287307
# edge_JAN_PDE2_1345_set4_73375
# edge_JAN_PDE2_1345_set4_314311
# edge_JAN_PDE2_1345_set4_73883
# edge_JAN_PDE2_1345_set4_46739
# edge_JAN_PDE2_1345_set4_240291
# edge_JAN_PDE2_1345_set4_200839
# edge_JAN_PDE2_1345_set4_72639
# edge_JAN_PDE2_1345_set4_9233
# edge_JAN_PDE2_1345_set4_204549
# edge_JAN_PDE2_1345_set4_204497
# edge_JAN_PDE2_1345_set4_202087
# edge_JAN_PDE2_1345_set4_204487
# edge_JAN_PDE2_1345_set4_190844
# edge_JAN_PDE2_1345_set4_44746
# edge_JAN_PDE2_1345_set4_122460
# edge_JAN_PDE2_1345_set4_121483
# edge_JAN_PDE2_1345_set4_239416
# edge_JAN_PDE2_1345_set4_73008
# edge_JAN_PDE2_1345_set4_200519
# edge_JAN_PDE2_1345_set4_204450
# edge_JAN_PDE2_1345_set4_190886
# edge_JAN_PDE2_1345_set4_186054
# edge_JAN_PDE2_1345_set4_26471
# edge_JAN_PDE2_1345_set4_73724
# edge_JAN_PDE2_1345_set4_39459
# edge_JAN_PDE2_1345_set4_187035
# edge_JAN_PDE2_1345_set4_121458
# edge_JAN_PDE2_1345_set4_190807
# edge_JAN_PDE2_1345_set4_190882
# edge_JAN_PDE2_1345_set4_72600
# edge_JAN_PDE2_1345_set4_287108
# edge_JAN_PDE2_1345_set4_49347
# edge_JAN_PDE2_1345_set4_73813
# edge_JAN_PDE2_1345_set4_188271
# edge_JAN_PDE2_1345_set4_287305
# edge_JAN_PDE2_1345_set4_73153
# edge_JAN_PDE2_1345_set4_122489
# edge_JAN_PDE2_1345_set4_73007
# edge_JAN_PDE2_1345_set4_318340
# edge_JAN_PDE2_1345_set4_72643
# edge_JAN_PDE2_1345_set4_121481
# edge_JAN_PDE2_1345_set4_204316
# edge_JAN_PDE2_1345_set4_71992
# edge_JAN_PDE2_1345_set4_204440
# edge_JAN_PDE2_1345_set4_315054
# edge_JAN_PDE2_1345_set4_122477
# edge_JAN_PDE2_1345_set4_73781
# edge_JAN_PDE2_1345_set4_7468
# edge_JAN_PDE2_1345_set4_315055
# edge_JAN_PDE2_1345_set4_316584
# edge_JAN_PDE2_1345_set4_1830
# edge_JAN_PDE2_1345_set4_121456
# edge_JAN_PDE2_1345_set4_200493
# edge_JAN_PDE2_1345_set4_122492
# edge_JAN_PDE2_1345_set4_237843
# edge_JAN_PDE2_1345_set4_186899
# edge_JAN_PDE2_1345_set4_240165
# edge_JAN_PDE2_1345_set4_49395
# edge_JAN_PDE2_1345_set4_297010
# edge_JAN_PDE2_1345_set4_120342
# edge_JAN_PDE2_1345_set4_315639
# edge_JAN_PDE2_1345_set4_376385
# edge_JAN_PDE2_1345_set4_46563
# edge_JAN_PDE2_1345_set4_204476
# edge_JAN_PDE2_1345_set4_240139
# edge_JAN_PDE2_1345_set4_190853
# edge_JAN_PDE2_1345_set4_73446
# edge_JAN_PDE2_1345_set4_190819
# edge_JAN_PDE2_1345_set4_200833
# edge_JAN_PDE2_1345_set4_295347
# edge_JAN_PDE2_1345_set4_28055
# edge_JAN_PDE2_1345_set4_287279
# edge_JAN_PDE2_1345_set4_204510
# edge_JAN_PDE2_1345_set4_7467
# edge_JAN_PDE2_1345_set4_49408
# edge_JAN_PDE2_1345_set4_318271
# edge_JAN_PDE2_1345_set4_7276
# edge_JAN_PDE2_1345_set4_43306
# edge_JAN_PDE2_1345_set4_287340
# edge_JAN_PDE2_1345_set4_12308
# edge_JAN_PDE2_1345_set4_282491
# edge_JAN_PDE2_1345_set4_48416
# edge_JAN_PDE2_1345_set4_357530
# edge_JAN_PDE2_1345_set4_204435
# edge_JAN_PDE2_1345_set4_12907
# edge_JAN_PDE2_1345_set4_358553
# edge_JAN_PDE2_1345_set4_117342
# edge_JAN_PDE2_1345_set4_122463
# edge_JAN_PDE2_1345_set4_358538
# edge_JAN_PDE2_1345_set4_316574
# edge_JAN_PDE2_1345_set4_240197
# DONE

# %% [markdown]
# `4b.` Finally, we can collect all the results into one data structure and investigate the outcome.<br>
# Let's also set the number of replicas back to 3, because results from three repeats have been pre-calculated for this tutorial.<br>
# Here, we read the $\Delta G$ values and calculate $\Delta\Delta G$.<br>
# The calculated error reflects the statistical uncertainty and the variation between multiple calculation repeats.

# %%
fe.replicas = 3
fe.analysis_summary( edges=finished_edges )
# fe.analysis_summary()

# %%
fe.resultsAll
# Out:
#                                                 val  err_analyt  err_boot  \
# edge_JAN_PDE2_1345_set4_190778_water_1    26.790000    2.010000  2.620000
# edge_JAN_PDE2_1345_set4_190778_protein_1  11.870000   53.350000  1.880000
# edge_JAN_PDE2_1345_set4_190778_water_2    27.870000    2.430000  1.070000
# edge_JAN_PDE2_1345_set4_190778_protein_2   1.970000   10.470000  1.480000
# edge_JAN_PDE2_1345_set4_190778_water_3    30.420000    1.870000  1.730000
# ...                                             ...         ...       ...
# edge_JAN_PDE2_1345_set4_1830_protein       4.343333   28.716229  4.259313
# edge_JAN_PDE2_1345_set4_315639_water      15.476667    1.886438  1.472995
# edge_JAN_PDE2_1345_set4_315639_protein     0.816667    3.090753  2.671816
# edge_JAN_PDE2_1345_set4_117342_water      31.686667    1.254663  1.137049
# edge_JAN_PDE2_1345_set4_117342_protein    20.850000   12.698997  2.849601
#
#                                           framesA  framesB
# edge_JAN_PDE2_1345_set4_190778_water_1       80.0     80.0
# edge_JAN_PDE2_1345_set4_190778_protein_1     80.0     80.0
# edge_JAN_PDE2_1345_set4_190778_water_2       80.0     80.0
# edge_JAN_PDE2_1345_set4_190778_protein_2     80.0     80.0
# edge_JAN_PDE2_1345_set4_190778_water_3       80.0     80.0
# ...                                           ...      ...
# edge_JAN_PDE2_1345_set4_1830_protein          NaN      NaN
# edge_JAN_PDE2_1345_set4_315639_water          NaN      NaN
# edge_JAN_PDE2_1345_set4_315639_protein        NaN      NaN
# edge_JAN_PDE2_1345_set4_117342_water          NaN      NaN
# edge_JAN_PDE2_1345_set4_117342_protein        NaN      NaN
#
# [800 rows x 5 columns]

# %%
#fe.resultsSummary
with pd.option_context('display.max_rows', None, 'display.max_columns', None):  # more options can be specified also
    print(fe.resultsAll)
# Out:
#                                                  val   err_analyt  err_boot  \
# edge_JAN_PDE2_1345_set4_190778_water_1     26.790000     2.010000  2.620000
# edge_JAN_PDE2_1345_set4_190778_protein_1   11.870000    53.350000  1.880000
# edge_JAN_PDE2_1345_set4_190778_water_2     27.870000     2.430000  1.070000
# edge_JAN_PDE2_1345_set4_190778_protein_2    1.970000    10.470000  1.480000
# edge_JAN_PDE2_1345_set4_190778_water_3     30.420000     1.870000  1.730000
# edge_JAN_PDE2_1345_set4_190778_protein_3    5.540000   127.160000  1.730000
# edge_JAN_PDE2_1345_set4_240291_water_1     56.820000     2.030000  1.240000
# edge_JAN_PDE2_1345_set4_240291_protein_1   30.760000    28.400000  3.380000
# edge_JAN_PDE2_1345_set4_240291_water_2     58.930000     2.150000  1.820000
# edge_JAN_PDE2_1345_set4_240291_protein_2   28.940000    11.860000  3.770000
# edge_JAN_PDE2_1345_set4_240291_water_3     58.060000     2.170000  1.350000
# edge_JAN_PDE2_1345_set4_240291_protein_3   32.960000    29.200000  1.590000
# edge_JAN_PDE2_1345_set4_121483_water_1     65.350000     2.120000  1.160000
# edge_JAN_PDE2_1345_set4_121483_protein_1   43.370000    18.240000  3.890000
# edge_JAN_PDE2_1345_set4_121483_water_2     62.950000     1.680000  1.640000
# edge_JAN_PDE2_1345_set4_121483_protein_2   40.260000    28.200000  1.980000
# edge_JAN_PDE2_1345_set4_121483_water_3     64.600000     2.100000  1.410000
# edge_JAN_PDE2_1345_set4_121483_protein_3   40.180000    32.880000  5.200000
# edge_JAN_PDE2_1345_set4_190914_water_1     12.600000     2.370000  1.120000
# edge_JAN_PDE2_1345_set4_190914_protein_1  -16.220000    41.290000  1.550000
# edge_JAN_PDE2_1345_set4_190914_water_2      7.970000     2.510000  2.690000
# edge_JAN_PDE2_1345_set4_190914_protein_2  -11.960000    20.180000  2.240000
# edge_JAN_PDE2_1345_set4_190914_water_3     11.930000     1.540000  1.100000
# edge_JAN_PDE2_1345_set4_190914_protein_3  -16.730000    14.960000  2.650000
# edge_JAN_PDE2_1345_set4_73008_water_1      -3.260000     2.230000  2.820000
# edge_JAN_PDE2_1345_set4_73008_protein_1   -15.550000     2.290000  2.800000
# edge_JAN_PDE2_1345_set4_73008_water_2       3.710000     1.390000  1.160000
# edge_JAN_PDE2_1345_set4_73008_protein_2   -18.200000     6.230000  1.950000
# edge_JAN_PDE2_1345_set4_73008_water_3      -0.230000     1.850000  2.070000
# edge_JAN_PDE2_1345_set4_73008_protein_3    -7.580000     4.800000  6.860000
# edge_JAN_PDE2_1345_set4_190882_water_1    -46.160000     2.730000  1.540000
# edge_JAN_PDE2_1345_set4_190882_protein_1  -61.050000     8.260000  1.810000
# edge_JAN_PDE2_1345_set4_190882_water_2    -45.480000     2.430000  3.450000
# edge_JAN_PDE2_1345_set4_190882_protein_2  -62.040000     8.440000  1.920000
# edge_JAN_PDE2_1345_set4_190882_water_3    -47.440000     2.310000  1.980000
# edge_JAN_PDE2_1345_set4_190882_protein_3  -69.290000    39.710000  1.270000
# edge_JAN_PDE2_1345_set4_188271_water_1     -0.820000     1.710000  1.410000
# edge_JAN_PDE2_1345_set4_188271_protein_1  -24.860000    29.060000  1.610000
# edge_JAN_PDE2_1345_set4_188271_water_2     -4.170000     2.410000  2.250000
# edge_JAN_PDE2_1345_set4_188271_protein_2  -14.230000   136.780000  1.970000
# edge_JAN_PDE2_1345_set4_188271_water_3      0.900000     2.570000  2.480000
# edge_JAN_PDE2_1345_set4_188271_protein_3  -12.160000    61.410000  1.640000
# edge_JAN_PDE2_1345_set4_26471_water_1     134.660000     1.050000  0.890000
# edge_JAN_PDE2_1345_set4_26471_protein_1   117.900000     2.250000  1.230000
# edge_JAN_PDE2_1345_set4_26471_water_2     132.410000     1.010000  0.930000
# edge_JAN_PDE2_1345_set4_26471_protein_2   109.110000     3.140000  3.470000
# edge_JAN_PDE2_1345_set4_26471_water_3     133.440000     1.110000  0.720000
# edge_JAN_PDE2_1345_set4_26471_protein_3   123.100000     1.530000  1.640000
# edge_JAN_PDE2_1345_set4_73813_water_1      13.120000     1.680000  1.980000
# edge_JAN_PDE2_1345_set4_73813_protein_1    17.870000    27.130000  2.490000
# edge_JAN_PDE2_1345_set4_73813_water_2      19.160000     2.890000  1.040000
# edge_JAN_PDE2_1345_set4_73813_protein_2    -4.640000     3.000000  2.200000
# edge_JAN_PDE2_1345_set4_73813_water_3      14.520000     1.840000  1.550000
# edge_JAN_PDE2_1345_set4_73813_protein_3    -2.750000     4.810000  1.060000
# edge_JAN_PDE2_1345_set4_121481_water_1     55.340000     2.130000  1.890000
# edge_JAN_PDE2_1345_set4_121481_protein_1   32.130000    12.670000  3.650000
# edge_JAN_PDE2_1345_set4_121481_water_2     50.780000     1.790000  1.190000
# edge_JAN_PDE2_1345_set4_121481_protein_2   31.860000    10.460000  2.270000
# edge_JAN_PDE2_1345_set4_121481_water_3     51.770000     2.010000  2.640000
# edge_JAN_PDE2_1345_set4_121481_protein_3   37.440000     8.360000  3.460000
# edge_JAN_PDE2_1345_set4_376385_water_1      8.790000     1.320000  0.890000
# edge_JAN_PDE2_1345_set4_376385_protein_1   -5.710000     3.670000  1.850000
# edge_JAN_PDE2_1345_set4_376385_water_2     10.230000     1.260000  1.120000
# edge_JAN_PDE2_1345_set4_376385_protein_2   -0.790000    65.920000  1.840000
# edge_JAN_PDE2_1345_set4_376385_water_3      9.350000     1.470000  1.460000
# edge_JAN_PDE2_1345_set4_376385_protein_3   -5.050000     4.400000  2.300000
# edge_JAN_PDE2_1345_set4_190778_water       28.360000     1.518575  1.417235
# edge_JAN_PDE2_1345_set4_190778_protein      6.460000    46.922005  2.533488
# edge_JAN_PDE2_1345_set4_240291_water       57.936667     1.322808  1.003192
# edge_JAN_PDE2_1345_set4_240291_protein     30.886667    13.924208  1.992825
# edge_JAN_PDE2_1345_set4_121483_water       64.300000     1.307806  1.001876
# edge_JAN_PDE2_1345_set4_121483_protein     41.270000    15.650412  2.406918
# edge_JAN_PDE2_1345_set4_190914_water       10.833333     1.779146  1.601388
# edge_JAN_PDE2_1345_set4_190914_protein    -14.970000    16.104775  1.748604
# edge_JAN_PDE2_1345_set4_73008_water         0.073333     1.986688  2.039223
# edge_JAN_PDE2_1345_set4_73008_protein     -13.776667     3.839290  3.685038
# edge_JAN_PDE2_1345_set4_190882_water      -46.360000     1.531868  1.490753
# edge_JAN_PDE2_1345_set4_190882_protein    -64.126667    14.032168  2.325012
# edge_JAN_PDE2_1345_set4_188271_water       -1.363333     1.782852  1.704038
# edge_JAN_PDE2_1345_set4_188271_protein    -17.083333    50.532180  3.352870
# edge_JAN_PDE2_1345_set4_26471_water       133.503333     0.812152  0.730098
# edge_JAN_PDE2_1345_set4_26471_protein     116.703333     3.640498  3.592102
# edge_JAN_PDE2_1345_set4_73813_water        15.600000     1.986970  1.764162
# edge_JAN_PDE2_1345_set4_73813_protein       3.493333    10.982310  5.993488
# edge_JAN_PDE2_1345_set4_121481_water       52.630000     1.596856  1.625403
# edge_JAN_PDE2_1345_set4_121481_protein     33.810000     6.232084  2.389230
# edge_JAN_PDE2_1345_set4_376385_water        9.456667     0.839981  0.760240
# edge_JAN_PDE2_1345_set4_376385_protein     -3.850000    21.712660  1.703570
# edge_JAN_PDE2_1345_set4_204497_water_1     22.520000     1.530000  1.130000
# edge_JAN_PDE2_1345_set4_204497_protein_1   -6.100000     3.180000  3.290000
# edge_JAN_PDE2_1345_set4_204497_water_2     20.020000     1.920000  2.320000
# edge_JAN_PDE2_1345_set4_204497_protein_2   -6.720000     8.740000  2.100000
# edge_JAN_PDE2_1345_set4_204497_water_3     20.950000     2.590000  2.440000
# edge_JAN_PDE2_1345_set4_204497_protein_3   -7.050000     2.750000  3.400000
# edge_JAN_PDE2_1345_set4_71401_water_1       5.270000     1.500000  1.000000
# edge_JAN_PDE2_1345_set4_71401_protein_1   -14.610000     1.830000  1.780000
# edge_JAN_PDE2_1345_set4_71401_water_2       4.050000     1.710000  1.170000
# edge_JAN_PDE2_1345_set4_71401_protein_2   -20.310000     4.960000  1.170000
# edge_JAN_PDE2_1345_set4_71401_water_3       4.020000     1.540000  1.750000
# edge_JAN_PDE2_1345_set4_71401_protein_3    -5.160000     3.220000  1.200000
# edge_JAN_PDE2_1345_set4_73883_water_1      21.040000     2.050000  1.590000
# edge_JAN_PDE2_1345_set4_73883_protein_1     0.190000     4.570000  2.720000
# edge_JAN_PDE2_1345_set4_73883_water_2      20.350000     1.690000  1.460000
# edge_JAN_PDE2_1345_set4_73883_protein_2     1.860000     3.290000  4.490000
# edge_JAN_PDE2_1345_set4_73883_water_3      21.050000     1.730000  1.290000
# edge_JAN_PDE2_1345_set4_73883_protein_3    -0.580000    29.250000  1.830000
# edge_JAN_PDE2_1345_set4_202087_water_1      0.120000     1.650000  1.600000
# edge_JAN_PDE2_1345_set4_202087_protein_1  -18.440000     2.630000  2.600000
# edge_JAN_PDE2_1345_set4_202087_water_2      0.220000     1.990000  1.420000
# edge_JAN_PDE2_1345_set4_202087_protein_2  -11.810000    60.240000  3.290000
# edge_JAN_PDE2_1345_set4_202087_water_3      5.100000     2.420000  1.920000
# edge_JAN_PDE2_1345_set4_202087_protein_3  -25.510000     4.850000  2.810000
# edge_JAN_PDE2_1345_set4_357530_water_1     54.290000     3.260000  1.750000
# edge_JAN_PDE2_1345_set4_357530_protein_1   26.360000    61.570000  2.090000
# edge_JAN_PDE2_1345_set4_357530_water_2     54.110000     2.270000  2.210000
# edge_JAN_PDE2_1345_set4_357530_protein_2   31.030000    23.250000  2.440000
# edge_JAN_PDE2_1345_set4_357530_water_3     51.230000     5.310000  0.830000
# edge_JAN_PDE2_1345_set4_357530_protein_3   49.330000   277.760000  2.500000
# edge_JAN_PDE2_1345_set4_72639_water_1      13.830000     2.490000  1.710000
# edge_JAN_PDE2_1345_set4_72639_protein_1     4.610000     3.540000  2.430000
# edge_JAN_PDE2_1345_set4_72639_water_2      10.680000     2.430000  2.030000
# edge_JAN_PDE2_1345_set4_72639_protein_2    -6.600000    20.330000  1.630000
# edge_JAN_PDE2_1345_set4_72639_water_3      15.310000     2.050000  2.830000
# edge_JAN_PDE2_1345_set4_72639_protein_3     3.250000    17.880000  3.740000
# edge_JAN_PDE2_1345_set4_190844_water_1     19.420000     2.830000  1.340000
# edge_JAN_PDE2_1345_set4_190844_protein_1  -11.680000     4.600000  2.790000
# edge_JAN_PDE2_1345_set4_190844_water_2     17.850000     3.000000  1.250000
# edge_JAN_PDE2_1345_set4_190844_protein_2    0.950000     3.330000  2.920000
# edge_JAN_PDE2_1345_set4_190844_water_3     17.530000     3.360000  1.020000
# edge_JAN_PDE2_1345_set4_190844_protein_3   -0.680000    24.150000  3.140000
# edge_JAN_PDE2_1345_set4_316733_water_1     60.650000     2.300000  1.910000
# edge_JAN_PDE2_1345_set4_316733_protein_1   48.710000    22.580000  5.410000
# edge_JAN_PDE2_1345_set4_316733_water_2     55.340000     2.570000  2.380000
# edge_JAN_PDE2_1345_set4_316733_protein_2   47.460000     3.570000  4.800000
# edge_JAN_PDE2_1345_set4_316733_water_3     63.560000     2.820000  2.110000
# edge_JAN_PDE2_1345_set4_316733_protein_3   45.810000     7.420000  1.840000
# edge_JAN_PDE2_1345_set4_287307_water_1      3.150000     1.770000  1.670000
# edge_JAN_PDE2_1345_set4_287307_protein_1  -23.410000    29.200000  1.800000
# edge_JAN_PDE2_1345_set4_287307_water_2      1.990000     2.400000  1.620000
# edge_JAN_PDE2_1345_set4_287307_protein_2  -20.070000    10.090000  0.990000
# edge_JAN_PDE2_1345_set4_287307_water_3      2.950000     1.870000  2.520000
# edge_JAN_PDE2_1345_set4_287307_protein_3  -12.770000     4.070000  3.790000
# edge_JAN_PDE2_1345_set4_9233_water_1       66.870000     3.080000  1.330000
# edge_JAN_PDE2_1345_set4_9233_protein_1     49.360000    26.520000  3.370000
# edge_JAN_PDE2_1345_set4_9233_water_2       69.890000     2.660000  3.850000
# edge_JAN_PDE2_1345_set4_9233_protein_2     58.560000    14.610000  1.240000
# edge_JAN_PDE2_1345_set4_9233_water_3       70.900000     2.040000  2.180000
# edge_JAN_PDE2_1345_set4_9233_protein_3     53.190000     3.360000  3.760000
# edge_JAN_PDE2_1345_set4_239416_water_1     47.030000     2.050000  1.780000
# edge_JAN_PDE2_1345_set4_239416_protein_1   37.970000     8.480000  1.600000
# edge_JAN_PDE2_1345_set4_239416_water_2     51.180000     2.070000  1.160000
# edge_JAN_PDE2_1345_set4_239416_protein_2   28.270000    14.020000  3.790000
# edge_JAN_PDE2_1345_set4_239416_water_3     46.360000     1.870000  1.470000
# edge_JAN_PDE2_1345_set4_239416_protein_3   33.820000    15.760000  1.560000
# edge_JAN_PDE2_1345_set4_49417_water_1     -29.920000     1.640000  1.600000
# edge_JAN_PDE2_1345_set4_49417_protein_1   -47.660000     3.600000  1.590000
# edge_JAN_PDE2_1345_set4_49417_water_2     -25.810000     1.700000  2.000000
# edge_JAN_PDE2_1345_set4_49417_protein_2   -37.060000     1.850000  2.320000
# edge_JAN_PDE2_1345_set4_49417_water_3     -27.720000     1.540000  1.710000
# edge_JAN_PDE2_1345_set4_49417_protein_3   -44.100000     2.800000  2.790000
# edge_JAN_PDE2_1345_set4_73375_water_1     -35.740000     2.030000  1.490000
# edge_JAN_PDE2_1345_set4_73375_protein_1   -49.410000     2.710000  2.850000
# edge_JAN_PDE2_1345_set4_73375_water_2     -40.340000     1.450000  1.250000
# edge_JAN_PDE2_1345_set4_73375_protein_2   -55.310000     6.260000  3.520000
# edge_JAN_PDE2_1345_set4_73375_water_3     -35.240000     2.650000  2.880000
# edge_JAN_PDE2_1345_set4_73375_protein_3   -57.460000     3.200000  2.520000
# edge_JAN_PDE2_1345_set4_204549_water_1     -7.150000     2.070000  1.270000
# edge_JAN_PDE2_1345_set4_204549_protein_1  -32.110000     9.620000  3.360000
# edge_JAN_PDE2_1345_set4_204549_water_2     -7.450000     1.600000  1.790000
# edge_JAN_PDE2_1345_set4_204549_protein_2  -17.550000  1086.100000  1.770000
# edge_JAN_PDE2_1345_set4_204549_water_3     -6.780000     4.320000  0.880000
# edge_JAN_PDE2_1345_set4_204549_protein_3  -23.400000     2.790000  3.700000
# edge_JAN_PDE2_1345_set4_122460_water_1     56.490000     1.920000  1.510000
# edge_JAN_PDE2_1345_set4_122460_protein_1   25.090000     4.550000  2.550000
# edge_JAN_PDE2_1345_set4_122460_water_2     55.730000     2.450000  1.460000
# edge_JAN_PDE2_1345_set4_122460_protein_2   23.890000    26.660000  5.660000
# edge_JAN_PDE2_1345_set4_122460_water_3     55.010000     1.690000  1.090000
# edge_JAN_PDE2_1345_set4_122460_protein_3   30.970000    59.040000  1.820000
# edge_JAN_PDE2_1345_set4_315931_water_1     32.340000     2.670000  0.840000
# edge_JAN_PDE2_1345_set4_315931_protein_1   21.800000     9.550000  2.940000
# edge_JAN_PDE2_1345_set4_315931_water_2     33.330000     2.390000  2.760000
# edge_JAN_PDE2_1345_set4_315931_protein_2   16.520000    11.240000  1.930000
# edge_JAN_PDE2_1345_set4_315931_water_3     36.240000     2.520000  2.060000
# edge_JAN_PDE2_1345_set4_315931_protein_3   19.730000    63.620000  2.060000
# edge_JAN_PDE2_1345_set4_46739_water_1      12.570000     2.390000  2.000000
# edge_JAN_PDE2_1345_set4_46739_protein_1   -21.500000    23.580000  3.680000
# edge_JAN_PDE2_1345_set4_46739_water_2       9.990000     2.460000  2.930000
# edge_JAN_PDE2_1345_set4_46739_protein_2   -16.120000    43.190000  2.030000
# edge_JAN_PDE2_1345_set4_46739_water_3       9.530000     2.580000  1.220000
# edge_JAN_PDE2_1345_set4_46739_protein_3    -8.280000    93.910000  2.440000
# edge_JAN_PDE2_1345_set4_44746_water_1       2.650000     2.180000  1.760000
# edge_JAN_PDE2_1345_set4_44746_protein_1   -21.780000     3.150000  1.680000
# edge_JAN_PDE2_1345_set4_44746_water_2      -2.790000     2.770000  1.810000
# edge_JAN_PDE2_1345_set4_44746_protein_2   -14.780000     5.570000  2.010000
# edge_JAN_PDE2_1345_set4_44746_water_3       1.930000     2.400000  1.170000
# edge_JAN_PDE2_1345_set4_44746_protein_3   -17.580000     6.630000  1.690000
# edge_JAN_PDE2_1345_set4_190886_water_1     14.050000     2.320000  2.540000
# edge_JAN_PDE2_1345_set4_190886_protein_1  -14.290000    69.640000  1.220000
# edge_JAN_PDE2_1345_set4_190886_water_2     10.940000     2.300000  2.670000
# edge_JAN_PDE2_1345_set4_190886_protein_2   -9.380000     9.120000  1.080000
# edge_JAN_PDE2_1345_set4_190886_water_3     13.580000     2.860000  1.430000
# edge_JAN_PDE2_1345_set4_190886_protein_3  -11.510000    45.100000  2.410000
# edge_JAN_PDE2_1345_set4_318412_water_1     65.910000     4.680000  1.090000
# edge_JAN_PDE2_1345_set4_318412_protein_1   40.550000    48.150000  2.550000
# edge_JAN_PDE2_1345_set4_318412_water_2     63.920000     2.230000  1.680000
# edge_JAN_PDE2_1345_set4_318412_protein_2   44.930000    27.770000  1.910000
# edge_JAN_PDE2_1345_set4_318412_water_3     64.130000     3.400000  1.670000
# edge_JAN_PDE2_1345_set4_318412_protein_3   54.270000    28.460000  1.830000
# edge_JAN_PDE2_1345_set4_200839_water_1      6.440000     2.240000  2.730000
# edge_JAN_PDE2_1345_set4_200839_protein_1   -6.680000    21.770000  1.590000
# edge_JAN_PDE2_1345_set4_200839_water_2     12.440000     1.750000  1.930000
# edge_JAN_PDE2_1345_set4_200839_protein_2  -19.190000     3.760000  4.270000
# edge_JAN_PDE2_1345_set4_200839_water_3     11.940000     1.840000  1.900000
# edge_JAN_PDE2_1345_set4_200839_protein_3   -8.140000    29.690000  3.020000
# edge_JAN_PDE2_1345_set4_200519_water_1      4.570000     2.680000  1.340000
# edge_JAN_PDE2_1345_set4_200519_protein_1  -20.340000    26.950000  1.140000
# edge_JAN_PDE2_1345_set4_200519_water_2      3.820000     2.100000  1.760000
# edge_JAN_PDE2_1345_set4_200519_protein_2  -21.960000    23.670000  1.320000
# edge_JAN_PDE2_1345_set4_200519_water_3     -0.010000     1.770000  2.120000
# edge_JAN_PDE2_1345_set4_200519_protein_3   -5.700000    14.950000  5.700000
# edge_JAN_PDE2_1345_set4_204450_water_1    -78.070000     2.510000  2.060000
# edge_JAN_PDE2_1345_set4_204450_protein_1  -96.330000     4.090000  2.330000
# edge_JAN_PDE2_1345_set4_204450_water_2    -75.140000     2.110000  1.670000
# edge_JAN_PDE2_1345_set4_204450_protein_2  -95.390000     2.330000  2.700000
# edge_JAN_PDE2_1345_set4_204450_water_3    -83.410000     1.560000  1.510000
# edge_JAN_PDE2_1345_set4_204450_protein_3  -81.260000     3.270000  3.480000
# edge_JAN_PDE2_1345_set4_122489_water_1     43.680000     2.150000  1.850000
# edge_JAN_PDE2_1345_set4_122489_protein_1   15.420000    48.460000  3.450000
# edge_JAN_PDE2_1345_set4_122489_water_2     43.380000     3.510000  0.760000
# edge_JAN_PDE2_1345_set4_122489_protein_2   17.070000    59.810000  1.460000
# edge_JAN_PDE2_1345_set4_122489_water_3     40.970000     1.820000  1.810000
# edge_JAN_PDE2_1345_set4_122489_protein_3   20.200000    60.170000  1.390000
# edge_JAN_PDE2_1345_set4_73781_water_1      17.690000     2.660000  1.850000
# edge_JAN_PDE2_1345_set4_73781_protein_1    10.320000    12.370000  4.350000
# edge_JAN_PDE2_1345_set4_73781_water_2      14.780000     2.280000  1.390000
# edge_JAN_PDE2_1345_set4_73781_protein_2     6.480000    20.360000  1.530000
# edge_JAN_PDE2_1345_set4_73781_water_3      20.600000     2.240000  2.440000
# edge_JAN_PDE2_1345_set4_73781_protein_3    -2.400000   136.370000  2.090000
# edge_JAN_PDE2_1345_set4_12907_water_1    -102.190000     1.670000  1.430000
# edge_JAN_PDE2_1345_set4_12907_protein_1  -111.800000    41.250000  1.390000
# edge_JAN_PDE2_1345_set4_12907_water_2    -103.980000     3.070000  1.400000
# edge_JAN_PDE2_1345_set4_12907_protein_2  -122.040000    18.240000  4.290000
# edge_JAN_PDE2_1345_set4_12907_water_3    -103.090000     2.010000  1.380000
# edge_JAN_PDE2_1345_set4_12907_protein_3  -121.730000    25.960000  1.560000
# edge_JAN_PDE2_1345_set4_237843_water_1     50.830000     2.710000  2.460000
# edge_JAN_PDE2_1345_set4_237843_protein_1   33.900000    61.370000  1.590000
# edge_JAN_PDE2_1345_set4_237843_water_2     56.550000     2.400000  2.180000
# edge_JAN_PDE2_1345_set4_237843_protein_2   36.720000    81.560000  2.010000
# edge_JAN_PDE2_1345_set4_237843_water_3     54.670000     2.210000  2.340000
# edge_JAN_PDE2_1345_set4_237843_protein_3   46.750000   297.480000  1.720000
# edge_JAN_PDE2_1345_set4_49395_water_1     -15.970000     1.650000  1.480000
# edge_JAN_PDE2_1345_set4_49395_protein_1   -43.210000     7.550000  2.180000
# edge_JAN_PDE2_1345_set4_49395_water_2     -11.490000     2.350000  1.110000
# edge_JAN_PDE2_1345_set4_49395_protein_2   -41.870000     3.030000  2.010000
# edge_JAN_PDE2_1345_set4_49395_water_3     -19.920000     1.910000  2.440000
# edge_JAN_PDE2_1345_set4_49395_protein_3   -33.890000    19.050000  1.150000
# edge_JAN_PDE2_1345_set4_120342_water_1     59.130000     2.950000  1.090000
# edge_JAN_PDE2_1345_set4_120342_protein_1   34.520000   105.140000  4.790000
# edge_JAN_PDE2_1345_set4_120342_water_2     58.210000     2.720000  1.950000
# edge_JAN_PDE2_1345_set4_120342_protein_2   45.840000     5.940000  2.800000
# edge_JAN_PDE2_1345_set4_120342_water_3     54.490000     2.090000  1.770000
# edge_JAN_PDE2_1345_set4_120342_protein_3   35.850000    26.570000  2.460000
# edge_JAN_PDE2_1345_set4_46563_water_1       1.470000     2.120000  1.840000
# edge_JAN_PDE2_1345_set4_46563_protein_1    -4.440000     5.950000  2.970000
# edge_JAN_PDE2_1345_set4_46563_water_2       6.910000     2.210000  1.730000
# edge_JAN_PDE2_1345_set4_46563_protein_2   -17.280000     3.490000  1.800000
# edge_JAN_PDE2_1345_set4_46563_water_3       8.560000     1.950000  2.150000
# edge_JAN_PDE2_1345_set4_46563_protein_3   -24.450000     5.100000  3.690000
# edge_JAN_PDE2_1345_set4_204497_water       21.163333     1.335221  1.346255
# edge_JAN_PDE2_1345_set4_204497_protein     -6.623333     3.214019  1.762937
# edge_JAN_PDE2_1345_set4_71401_water         4.446667     0.964190  0.850345
# edge_JAN_PDE2_1345_set4_71401_protein     -13.360000     4.141054  3.698270
# edge_JAN_PDE2_1345_set4_73883_water        20.813333     1.090562  0.864434
# edge_JAN_PDE2_1345_set4_73883_protein       0.490000    10.097623  1.962131
# edge_JAN_PDE2_1345_set4_202087_water        1.813333     1.783683  1.630314
# edge_JAN_PDE2_1345_set4_202087_protein    -18.586667    20.757119  3.611537
# edge_JAN_PDE2_1345_set4_357530_water       53.210000     2.357334  1.277931
# edge_JAN_PDE2_1345_set4_357530_protein     35.573333    96.670218  5.866899
# edge_JAN_PDE2_1345_set4_72639_water        13.273333     1.771379  1.694068
# edge_JAN_PDE2_1345_set4_72639_protein       0.420000     9.601932  3.285168
# edge_JAN_PDE2_1345_set4_190844_water       18.266667     1.783683  0.845176
# edge_JAN_PDE2_1345_set4_190844_protein     -3.803333     9.064620  3.678678
# edge_JAN_PDE2_1345_set4_316733_water       59.850000     2.478183  2.322853
# edge_JAN_PDE2_1345_set4_316733_protein     47.326667     7.688161  2.516633
# edge_JAN_PDE2_1345_set4_287307_water        2.696667     1.214577  1.160520
# edge_JAN_PDE2_1345_set4_287307_protein    -18.750000    11.154118  2.983504
# edge_JAN_PDE2_1345_set4_9233_water         69.220000     1.814134  1.869186
# edge_JAN_PDE2_1345_set4_9233_protein       53.703333    10.381995  2.745055
# edge_JAN_PDE2_1345_set4_239416_water       48.190000     1.694064  1.504722
# edge_JAN_PDE2_1345_set4_239416_protein     33.353333     7.692572  2.760555
# edge_JAN_PDE2_1345_set4_49417_water       -27.816667     1.359076  1.415004
# edge_JAN_PDE2_1345_set4_49417_protein     -42.940000     3.010999  2.843047
# edge_JAN_PDE2_1345_set4_73375_water       -37.106667     1.805047  1.755522
# edge_JAN_PDE2_1345_set4_73375_protein     -54.060000     3.214488  2.612889
# edge_JAN_PDE2_1345_set4_204549_water       -7.126667     1.633644  0.818540
# edge_JAN_PDE2_1345_set4_204549_protein    -24.353333   363.767647  3.911159
# edge_JAN_PDE2_1345_set4_122460_water       55.743333     1.247200  0.846475
# edge_JAN_PDE2_1345_set4_122460_protein     26.650000    21.642143  2.828947
# edge_JAN_PDE2_1345_set4_315931_water       33.970000     1.788473  1.501221
# edge_JAN_PDE2_1345_set4_315931_protein     19.350000    22.855040  1.806635
# edge_JAN_PDE2_1345_set4_46739_water        10.696667     1.627923  1.458844
# edge_JAN_PDE2_1345_set4_46739_protein     -15.300000    35.612155  3.491268
# edge_JAN_PDE2_1345_set4_44746_water         0.596667     1.973432  1.717324
# edge_JAN_PDE2_1345_set4_44746_protein     -18.046667     3.547952  1.938529
# edge_JAN_PDE2_1345_set4_190886_water       12.856667     1.637584  1.520574
# edge_JAN_PDE2_1345_set4_190886_protein    -11.726667    28.085164  1.522649
# edge_JAN_PDE2_1345_set4_318412_water       64.653333     2.140039  0.990132
# edge_JAN_PDE2_1345_set4_318412_protein     46.583333    20.962328  3.487431
# edge_JAN_PDE2_1345_set4_200839_water       10.273333     1.936438  2.024445
# edge_JAN_PDE2_1345_set4_200839_protein    -11.336667    12.771298  3.714359
# edge_JAN_PDE2_1345_set4_200519_water        2.793333     1.732221  1.566394
# edge_JAN_PDE2_1345_set4_200519_protein    -16.000000    14.137915  4.605193
# edge_JAN_PDE2_1345_set4_204450_water      -78.873333     2.336061  2.220592
# edge_JAN_PDE2_1345_set4_204450_protein    -90.993333     4.385103  4.323292
# edge_JAN_PDE2_1345_set4_122489_water       42.676667     1.664877  1.156294
# edge_JAN_PDE2_1345_set4_122489_protein     17.563333    32.749048  1.751296
# edge_JAN_PDE2_1345_set4_73781_water        17.690000     1.956029  1.788038
# edge_JAN_PDE2_1345_set4_73781_protein       4.800000    47.356558  3.482265
# edge_JAN_PDE2_1345_set4_12907_water      -103.086667     1.388484  0.915476
# edge_JAN_PDE2_1345_set4_12907_protein    -118.523333    17.478843  3.106516
# edge_JAN_PDE2_1345_set4_237843_water       54.016667     1.962227  1.961855
# edge_JAN_PDE2_1345_set4_237843_protein     39.123333   104.073812  3.366133
# edge_JAN_PDE2_1345_set4_49395_water       -15.793333     2.270989  2.227078
# edge_JAN_PDE2_1345_set4_49395_protein     -39.656667     7.561511  2.590527
# edge_JAN_PDE2_1345_set4_120342_water       57.276667     1.931709  1.492346
# edge_JAN_PDE2_1345_set4_120342_protein     38.736667    37.318667  3.554124
# edge_JAN_PDE2_1345_set4_46563_water         5.646667     2.150598  2.075206
# edge_JAN_PDE2_1345_set4_46563_protein     -15.390000     5.575573  5.083092
# edge_JAN_PDE2_1345_set4_314311_water_1     26.300000     2.170000  2.600000
# edge_JAN_PDE2_1345_set4_314311_protein_1   15.790000    34.690000  2.150000
# edge_JAN_PDE2_1345_set4_314311_water_2     20.190000     6.560000  2.340000
# edge_JAN_PDE2_1345_set4_314311_protein_2    9.710000     8.140000  2.640000
# edge_JAN_PDE2_1345_set4_314311_water_3     23.270000     3.570000  2.040000
# edge_JAN_PDE2_1345_set4_314311_protein_3    4.310000    26.780000  1.320000
# edge_JAN_PDE2_1345_set4_46560_water_1      -5.420000     1.570000  1.290000
# edge_JAN_PDE2_1345_set4_46560_protein_1   -14.520000     6.160000  2.980000
# edge_JAN_PDE2_1345_set4_46560_water_2      -7.360000     1.780000  1.260000
# edge_JAN_PDE2_1345_set4_46560_protein_2   -26.450000     5.150000  1.620000
# edge_JAN_PDE2_1345_set4_46560_water_3      -3.730000     1.810000  2.090000
# edge_JAN_PDE2_1345_set4_46560_protein_3   -26.800000     2.110000  2.230000
# edge_JAN_PDE2_1345_set4_204487_water_1      6.400000     1.820000  2.050000
# edge_JAN_PDE2_1345_set4_204487_protein_1   -3.250000     4.970000  2.000000
# edge_JAN_PDE2_1345_set4_204487_water_2      8.840000     1.720000  1.360000
# edge_JAN_PDE2_1345_set4_204487_protein_2  -10.070000    19.040000  1.990000
# edge_JAN_PDE2_1345_set4_204487_water_3      5.680000     1.850000  2.270000
# edge_JAN_PDE2_1345_set4_204487_protein_3  -13.880000     6.680000  3.620000
# edge_JAN_PDE2_1345_set4_72643_water_1      -0.680000     1.950000  2.010000
# edge_JAN_PDE2_1345_set4_72643_protein_1   -16.190000     3.240000  2.940000
# edge_JAN_PDE2_1345_set4_72643_water_2       4.710000     1.890000  2.020000
# edge_JAN_PDE2_1345_set4_72643_protein_2   -18.630000     2.240000  3.340000
# edge_JAN_PDE2_1345_set4_72643_water_3       1.690000     2.130000  1.440000
# edge_JAN_PDE2_1345_set4_72643_protein_3   -13.520000     4.470000  2.780000
# edge_JAN_PDE2_1345_set4_186054_water_1    -50.680000     1.940000  2.400000
# edge_JAN_PDE2_1345_set4_186054_protein_1  -64.030000    26.810000  2.930000
# edge_JAN_PDE2_1345_set4_186054_water_2    -54.050000     1.640000  2.040000
# edge_JAN_PDE2_1345_set4_186054_protein_2  -61.440000    30.000000  2.110000
# edge_JAN_PDE2_1345_set4_186054_water_3    -50.680000     1.610000  0.930000
# edge_JAN_PDE2_1345_set4_186054_protein_3  -57.620000    26.850000  2.180000
# edge_JAN_PDE2_1345_set4_72600_water_1      12.750000     2.230000  1.720000
# edge_JAN_PDE2_1345_set4_72600_protein_1    -3.160000    19.900000  1.700000
# edge_JAN_PDE2_1345_set4_72600_water_2      14.470000     2.070000  1.410000
# edge_JAN_PDE2_1345_set4_72600_protein_2    -3.840000     7.840000  1.550000
# edge_JAN_PDE2_1345_set4_72600_water_3      14.380000     2.170000  3.030000
# edge_JAN_PDE2_1345_set4_72600_protein_3    -3.500000     3.540000  3.340000
# edge_JAN_PDE2_1345_set4_73007_water_1       7.570000     1.530000  1.620000
# edge_JAN_PDE2_1345_set4_73007_protein_1    -6.060000    13.210000  2.680000
# edge_JAN_PDE2_1345_set4_73007_water_2       5.870000     2.050000  2.070000
# edge_JAN_PDE2_1345_set4_73007_protein_2   -11.800000     2.930000  1.110000
# edge_JAN_PDE2_1345_set4_73007_water_3       4.690000     1.880000  1.040000
# edge_JAN_PDE2_1345_set4_73007_protein_3     8.890000    24.590000  3.570000
# edge_JAN_PDE2_1345_set4_190807_water_1    -32.950000     1.760000  0.990000
# edge_JAN_PDE2_1345_set4_190807_protein_1  -34.890000    14.190000  2.270000
# edge_JAN_PDE2_1345_set4_190807_water_2    -25.680000     1.990000  1.580000
# edge_JAN_PDE2_1345_set4_190807_protein_2  -43.320000    24.610000  2.930000
# edge_JAN_PDE2_1345_set4_190807_water_3    -28.710000     1.840000  1.400000
# edge_JAN_PDE2_1345_set4_190807_protein_3  -49.570000    10.500000  2.100000
# edge_JAN_PDE2_1345_set4_73724_water_1     -25.480000     2.290000  1.220000
# edge_JAN_PDE2_1345_set4_73724_protein_1   -43.550000    10.910000  1.870000
# edge_JAN_PDE2_1345_set4_73724_water_2     -28.060000     1.910000  2.250000
# edge_JAN_PDE2_1345_set4_73724_protein_2   -39.670000     4.690000  1.660000
# edge_JAN_PDE2_1345_set4_73724_water_3     -28.140000     2.270000  2.500000
# edge_JAN_PDE2_1345_set4_73724_protein_3   -41.560000     3.560000  3.690000
# edge_JAN_PDE2_1345_set4_316574_water_1     34.970000     6.230000  1.740000
# edge_JAN_PDE2_1345_set4_316574_protein_1   10.140000     4.070000  2.770000
# edge_JAN_PDE2_1345_set4_316574_water_2     24.560000     2.400000  1.740000
# edge_JAN_PDE2_1345_set4_316574_protein_2   14.590000     5.860000  2.930000
# edge_JAN_PDE2_1345_set4_316574_water_3     31.070000     3.850000  1.620000
# edge_JAN_PDE2_1345_set4_316574_protein_3    4.720000    14.920000  2.690000
# edge_JAN_PDE2_1345_set4_187035_water_1     20.270000     3.200000  3.160000
# edge_JAN_PDE2_1345_set4_187035_protein_1   -0.870000    21.460000  1.810000
# edge_JAN_PDE2_1345_set4_187035_water_2     23.100000     1.950000  1.050000
# edge_JAN_PDE2_1345_set4_187035_protein_2   15.850000     7.100000  3.240000
# edge_JAN_PDE2_1345_set4_187035_water_3     22.780000     2.240000  2.400000
# edge_JAN_PDE2_1345_set4_187035_protein_3    9.640000    43.820000  1.470000
# edge_JAN_PDE2_1345_set4_73153_water_1      20.260000     1.390000  1.800000
# edge_JAN_PDE2_1345_set4_73153_protein_1     4.170000     6.330000  1.290000
# edge_JAN_PDE2_1345_set4_73153_water_2      17.540000     1.540000  1.220000
# edge_JAN_PDE2_1345_set4_73153_protein_2    -5.430000    10.980000  1.860000
# edge_JAN_PDE2_1345_set4_73153_water_3      20.430000     1.710000  1.690000
# edge_JAN_PDE2_1345_set4_73153_protein_3    14.840000    32.010000  1.470000
# edge_JAN_PDE2_1345_set4_318340_water_1     31.750000     4.240000  2.120000
# edge_JAN_PDE2_1345_set4_318340_protein_1   12.400000     3.640000  1.380000
# edge_JAN_PDE2_1345_set4_318340_water_2     28.960000     3.740000  1.590000
# edge_JAN_PDE2_1345_set4_318340_protein_2   11.050000     3.060000  7.900000
# edge_JAN_PDE2_1345_set4_318340_water_3     32.580000     2.630000  2.650000
# edge_JAN_PDE2_1345_set4_318340_protein_3   13.090000     3.780000  4.480000
# edge_JAN_PDE2_1345_set4_71992_water_1      20.780000     3.710000  0.710000
# edge_JAN_PDE2_1345_set4_71992_protein_1    14.510000    55.000000  2.050000
# edge_JAN_PDE2_1345_set4_71992_water_2      20.500000     1.490000  1.500000
# edge_JAN_PDE2_1345_set4_71992_protein_2     0.690000    16.300000  3.690000
# edge_JAN_PDE2_1345_set4_71992_water_3      17.730000     2.080000  2.580000
# edge_JAN_PDE2_1345_set4_71992_protein_3     6.460000     4.510000  3.470000
# edge_JAN_PDE2_1345_set4_121458_water_1     61.880000     1.800000  0.780000
# edge_JAN_PDE2_1345_set4_121458_protein_1   42.120000     6.930000  2.180000
# edge_JAN_PDE2_1345_set4_121458_water_2     64.000000     2.140000  1.530000
# edge_JAN_PDE2_1345_set4_121458_protein_2   49.160000    10.800000  3.930000
# edge_JAN_PDE2_1345_set4_121458_water_3     65.830000     2.180000  1.320000
# edge_JAN_PDE2_1345_set4_121458_protein_3   51.860000    58.010000  5.500000
# edge_JAN_PDE2_1345_set4_287108_water_1      1.060000     1.740000  2.190000
# edge_JAN_PDE2_1345_set4_287108_protein_1  -20.910000     9.170000  1.030000
# edge_JAN_PDE2_1345_set4_287108_water_2      2.440000     2.300000  1.360000
# edge_JAN_PDE2_1345_set4_287108_protein_2  -25.350000     9.930000  3.300000
# edge_JAN_PDE2_1345_set4_287108_water_3     -2.030000     1.850000  1.670000
# edge_JAN_PDE2_1345_set4_287108_protein_3  -14.990000     8.630000  1.590000
# edge_JAN_PDE2_1345_set4_358538_water_1     53.200000     3.100000  1.000000
# edge_JAN_PDE2_1345_set4_358538_protein_1   29.600000    15.010000  1.080000
# edge_JAN_PDE2_1345_set4_358538_water_2     54.300000     2.510000  3.190000
# edge_JAN_PDE2_1345_set4_358538_protein_2   30.920000    40.700000  1.630000
# edge_JAN_PDE2_1345_set4_358538_water_3     54.640000     1.710000  1.440000
# edge_JAN_PDE2_1345_set4_358538_protein_3   35.610000    14.780000  1.390000
# edge_JAN_PDE2_1345_set4_204316_water_1     14.740000     2.500000  2.240000
# edge_JAN_PDE2_1345_set4_204316_protein_1   -6.510000    14.600000  1.810000
# edge_JAN_PDE2_1345_set4_204316_water_2     12.260000     2.120000  2.540000
# edge_JAN_PDE2_1345_set4_204316_protein_2  -11.400000     3.720000  2.950000
# edge_JAN_PDE2_1345_set4_204316_water_3     11.980000     2.140000  1.170000
# edge_JAN_PDE2_1345_set4_204316_protein_3   -8.040000    25.540000  1.440000
# edge_JAN_PDE2_1345_set4_315054_water_1     57.570000     5.200000  1.150000
# edge_JAN_PDE2_1345_set4_315054_protein_1   41.320000     6.220000  3.300000
# edge_JAN_PDE2_1345_set4_315054_water_2     57.550000     2.560000  1.030000
# edge_JAN_PDE2_1345_set4_315054_protein_2   41.900000     3.830000  2.380000
# edge_JAN_PDE2_1345_set4_315054_water_3     60.310000     2.370000  1.970000
# edge_JAN_PDE2_1345_set4_315054_protein_3   39.590000     3.330000  1.990000
# edge_JAN_PDE2_1345_set4_7468_water_1       -4.030000     2.940000  1.300000
# edge_JAN_PDE2_1345_set4_7468_protein_1    -28.270000     3.150000  3.300000
# edge_JAN_PDE2_1345_set4_7468_water_2       -4.060000     1.810000  1.620000
# edge_JAN_PDE2_1345_set4_7468_protein_2    -20.500000     8.520000  1.820000
# edge_JAN_PDE2_1345_set4_7468_water_3       -6.710000     2.490000  2.280000
# edge_JAN_PDE2_1345_set4_7468_protein_3    -20.270000     8.560000  4.270000
# edge_JAN_PDE2_1345_set4_121456_water_1     44.680000     2.800000  2.490000
# edge_JAN_PDE2_1345_set4_121456_protein_1   23.440000   180.060000  0.710000
# edge_JAN_PDE2_1345_set4_121456_water_2     47.990000     3.780000  1.420000
# edge_JAN_PDE2_1345_set4_121456_protein_2   21.490000     8.860000  2.570000
# edge_JAN_PDE2_1345_set4_121456_water_3     46.450000     2.470000  2.450000
# edge_JAN_PDE2_1345_set4_121456_protein_3   27.880000     5.800000  4.190000
# edge_JAN_PDE2_1345_set4_204440_water_1     28.540000     1.810000  1.950000
# edge_JAN_PDE2_1345_set4_204440_protein_1   11.380000    19.600000  1.610000
# edge_JAN_PDE2_1345_set4_204440_water_2     26.770000     1.790000  1.840000
# edge_JAN_PDE2_1345_set4_204440_protein_2   15.420000    10.700000  2.630000
# edge_JAN_PDE2_1345_set4_204440_water_3     26.880000     2.390000  2.010000
# edge_JAN_PDE2_1345_set4_204440_protein_3    6.560000    10.050000  1.690000
# edge_JAN_PDE2_1345_set4_315055_water_1     41.810000     4.270000  0.940000
# edge_JAN_PDE2_1345_set4_315055_protein_1   24.920000     5.850000  2.000000
# edge_JAN_PDE2_1345_set4_315055_water_2     48.010000     3.100000  2.280000
# edge_JAN_PDE2_1345_set4_315055_protein_2   33.690000     9.130000  2.620000
# edge_JAN_PDE2_1345_set4_315055_water_3     41.010000     3.120000  3.390000
# edge_JAN_PDE2_1345_set4_315055_protein_3   28.640000   148.680000  1.610000
# edge_JAN_PDE2_1345_set4_200493_water_1      5.960000     1.630000  1.760000
# edge_JAN_PDE2_1345_set4_200493_protein_1  -27.240000    17.990000  1.220000
# edge_JAN_PDE2_1345_set4_200493_water_2     -0.690000     2.510000  2.490000
# edge_JAN_PDE2_1345_set4_200493_protein_2  -20.070000     4.850000  1.750000
# edge_JAN_PDE2_1345_set4_200493_water_3      2.590000     2.450000  1.250000
# edge_JAN_PDE2_1345_set4_200493_protein_3  -17.150000    39.600000  1.980000
# edge_JAN_PDE2_1345_set4_186899_water_1     11.170000     1.840000  1.840000
# edge_JAN_PDE2_1345_set4_186899_protein_1  -10.220000    39.520000  2.610000
# edge_JAN_PDE2_1345_set4_186899_water_2     11.740000     1.680000  1.220000
# edge_JAN_PDE2_1345_set4_186899_protein_2   -2.710000     4.780000  2.360000
# edge_JAN_PDE2_1345_set4_186899_water_3      8.470000     1.940000  1.990000
# edge_JAN_PDE2_1345_set4_186899_protein_3  -15.320000    86.900000  2.980000
# edge_JAN_PDE2_1345_set4_122477_water_1     61.330000     2.050000  2.150000
# edge_JAN_PDE2_1345_set4_122477_protein_1   32.850000    15.400000  3.210000
# edge_JAN_PDE2_1345_set4_122477_water_2     56.000000     1.700000  1.490000
# edge_JAN_PDE2_1345_set4_122477_protein_2   32.940000     3.740000  1.880000
# edge_JAN_PDE2_1345_set4_122477_water_3     62.160000     2.160000  0.850000
# edge_JAN_PDE2_1345_set4_122477_protein_3   32.070000    22.280000  2.980000
# edge_JAN_PDE2_1345_set4_316584_water_1     59.850000     3.200000  1.200000
# edge_JAN_PDE2_1345_set4_316584_protein_1   43.440000    42.270000  1.580000
# edge_JAN_PDE2_1345_set4_316584_water_2     57.460000     2.650000  1.630000
# edge_JAN_PDE2_1345_set4_316584_protein_2   44.280000    50.200000  2.120000
# edge_JAN_PDE2_1345_set4_316584_water_3     57.680000     5.900000  1.720000
# edge_JAN_PDE2_1345_set4_316584_protein_3   47.390000    64.410000  1.330000
# edge_JAN_PDE2_1345_set4_122492_water_1    116.940000     2.050000  1.540000
# edge_JAN_PDE2_1345_set4_122492_protein_1   96.790000    10.520000  1.280000
# edge_JAN_PDE2_1345_set4_122492_water_2    117.930000     2.250000  1.370000
# edge_JAN_PDE2_1345_set4_122492_protein_2   96.000000     6.390000  2.150000
# edge_JAN_PDE2_1345_set4_122492_water_3    121.600000     1.830000  2.100000
# edge_JAN_PDE2_1345_set4_122492_protein_3  107.060000     8.510000  2.300000
# edge_JAN_PDE2_1345_set4_240165_water_1     55.250000     2.400000  1.640000
# edge_JAN_PDE2_1345_set4_240165_protein_1   46.370000     3.520000  3.340000
# edge_JAN_PDE2_1345_set4_240165_water_2     57.620000     3.290000  1.670000
# edge_JAN_PDE2_1345_set4_240165_protein_2   30.180000     2.910000  1.720000
# edge_JAN_PDE2_1345_set4_240165_water_3     53.190000     2.190000  1.580000
# edge_JAN_PDE2_1345_set4_240165_protein_3   41.820000     2.890000  3.490000
# edge_JAN_PDE2_1345_set4_358553_water_1    202.130000     2.370000  1.720000
# edge_JAN_PDE2_1345_set4_358553_protein_1  182.510000    12.070000  1.240000
# edge_JAN_PDE2_1345_set4_358553_water_2    203.120000     2.740000  1.240000
# edge_JAN_PDE2_1345_set4_358553_protein_2  201.970000     3.950000  4.140000
# edge_JAN_PDE2_1345_set4_358553_water_3    204.720000     4.210000  6.000000
# edge_JAN_PDE2_1345_set4_358553_protein_3  189.710000    59.850000  2.260000
# edge_JAN_PDE2_1345_set4_297010_water_1     84.960000     3.100000  3.840000
# edge_JAN_PDE2_1345_set4_297010_protein_1   67.010000     5.180000  1.490000
# edge_JAN_PDE2_1345_set4_297010_water_2     83.320000     2.200000  2.690000
# edge_JAN_PDE2_1345_set4_297010_protein_2   77.090000     3.290000  3.600000
# edge_JAN_PDE2_1345_set4_297010_water_3     82.810000     1.450000  1.260000
# edge_JAN_PDE2_1345_set4_297010_protein_3   68.180000     6.220000  1.690000
# edge_JAN_PDE2_1345_set4_240197_water_1     44.640000     4.020000  3.400000
# edge_JAN_PDE2_1345_set4_240197_protein_1   24.860000   291.600000  2.350000
# edge_JAN_PDE2_1345_set4_240197_water_2     42.120000     3.330000  4.060000
# edge_JAN_PDE2_1345_set4_240197_protein_2   22.320000    31.050000  5.900000
# edge_JAN_PDE2_1345_set4_240197_water_3     46.320000     7.770000  1.590000
# edge_JAN_PDE2_1345_set4_240197_protein_3   29.140000   514.110000  3.350000
# edge_JAN_PDE2_1345_set4_204476_water_1     24.210000     2.200000  2.820000
# edge_JAN_PDE2_1345_set4_204476_protein_1   11.710000    28.980000  1.130000
# edge_JAN_PDE2_1345_set4_204476_water_2     24.110000     1.950000  1.330000
# edge_JAN_PDE2_1345_set4_204476_protein_2   10.800000    76.150000  1.860000
# edge_JAN_PDE2_1345_set4_204476_water_3     25.400000     2.270000  2.250000
# edge_JAN_PDE2_1345_set4_204476_protein_3    3.320000     4.680000  1.610000
# edge_JAN_PDE2_1345_set4_282491_water_1     -5.150000     1.890000  1.020000
# edge_JAN_PDE2_1345_set4_282491_protein_1   -7.720000   306.650000  0.810000
# edge_JAN_PDE2_1345_set4_282491_water_2     -6.760000     2.570000  2.130000
# edge_JAN_PDE2_1345_set4_282491_protein_2  -17.830000    42.070000  4.230000
# edge_JAN_PDE2_1345_set4_282491_water_3     -2.770000     1.660000  1.580000
# edge_JAN_PDE2_1345_set4_282491_protein_3  -15.180000    35.270000  1.900000
# edge_JAN_PDE2_1345_set4_48416_water_1      36.860000     1.860000  1.720000
# edge_JAN_PDE2_1345_set4_48416_protein_1    18.260000    31.620000  4.100000
# edge_JAN_PDE2_1345_set4_48416_water_2      36.870000     2.310000  2.530000
# edge_JAN_PDE2_1345_set4_48416_protein_2    26.960000     8.550000  3.480000
# edge_JAN_PDE2_1345_set4_48416_water_3      40.620000     2.280000  3.370000
# edge_JAN_PDE2_1345_set4_48416_protein_3    35.840000    18.530000  4.880000
# edge_JAN_PDE2_1345_set4_240139_water_1     41.640000     2.520000  3.890000
# edge_JAN_PDE2_1345_set4_240139_protein_1   23.590000     6.900000  1.400000
# edge_JAN_PDE2_1345_set4_240139_water_2     51.810000     3.230000  4.090000
# edge_JAN_PDE2_1345_set4_240139_protein_2   28.680000   129.570000  1.980000
# edge_JAN_PDE2_1345_set4_240139_water_3     43.760000     2.570000  2.400000
# edge_JAN_PDE2_1345_set4_240139_protein_3   29.710000     5.230000  3.780000
# edge_JAN_PDE2_1345_set4_190853_water_1    -13.220000     1.680000  2.270000
# edge_JAN_PDE2_1345_set4_190853_protein_1  -31.490000     2.220000  2.540000
# edge_JAN_PDE2_1345_set4_190853_water_2    -16.760000     1.980000  2.060000
# edge_JAN_PDE2_1345_set4_190853_protein_2  -25.900000     5.210000  2.240000
# edge_JAN_PDE2_1345_set4_190853_water_3     -9.490000     2.440000  0.870000
# edge_JAN_PDE2_1345_set4_190853_protein_3  -32.980000     3.770000  2.690000
# edge_JAN_PDE2_1345_set4_73446_water_1     -34.580000     1.860000  1.240000
# edge_JAN_PDE2_1345_set4_73446_protein_1   -42.640000    17.710000  3.260000
# edge_JAN_PDE2_1345_set4_73446_water_2     -36.230000     1.680000  1.620000
# edge_JAN_PDE2_1345_set4_73446_protein_2   -57.800000     8.760000  1.870000
# edge_JAN_PDE2_1345_set4_73446_water_3     -36.400000     1.600000  1.060000
# edge_JAN_PDE2_1345_set4_73446_protein_3   -42.110000     2.720000  4.820000
# edge_JAN_PDE2_1345_set4_190819_water_1     11.800000     2.780000  1.570000
# edge_JAN_PDE2_1345_set4_190819_protein_1   -9.690000    11.130000  3.270000
# edge_JAN_PDE2_1345_set4_190819_water_2      8.880000     2.330000  2.720000
# edge_JAN_PDE2_1345_set4_190819_protein_2  -14.240000     3.000000  5.510000
# edge_JAN_PDE2_1345_set4_190819_water_3     10.450000     3.920000  1.520000
# edge_JAN_PDE2_1345_set4_190819_protein_3  -10.460000    11.930000  1.480000
# edge_JAN_PDE2_1345_set4_200833_water_1      1.800000     2.300000  1.440000
# edge_JAN_PDE2_1345_set4_200833_protein_1  -15.660000     3.590000  4.350000
# edge_JAN_PDE2_1345_set4_200833_water_2      0.910000     1.820000  2.190000
# edge_JAN_PDE2_1345_set4_200833_protein_2  -13.450000    15.520000  2.770000
# edge_JAN_PDE2_1345_set4_200833_water_3      2.690000     2.320000  1.460000
# edge_JAN_PDE2_1345_set4_200833_protein_3  -18.510000     5.150000  3.210000
# edge_JAN_PDE2_1345_set4_295347_water_1     47.340000     2.340000  1.500000
# edge_JAN_PDE2_1345_set4_295347_protein_1   22.230000    22.380000  1.910000
# edge_JAN_PDE2_1345_set4_295347_water_2     47.920000     1.810000  0.960000
# edge_JAN_PDE2_1345_set4_295347_protein_2   38.280000    12.030000  2.550000
# edge_JAN_PDE2_1345_set4_295347_water_3     42.480000     2.330000  2.070000
# edge_JAN_PDE2_1345_set4_295347_protein_3   28.600000    18.260000  2.390000
# edge_JAN_PDE2_1345_set4_28055_water_1     -26.610000     1.070000  1.180000
# edge_JAN_PDE2_1345_set4_28055_protein_1   -46.560000     2.870000  2.870000
# edge_JAN_PDE2_1345_set4_28055_water_2     -30.270000     1.440000  1.150000
# edge_JAN_PDE2_1345_set4_28055_protein_2   -43.400000    46.710000  1.640000
# edge_JAN_PDE2_1345_set4_28055_water_3     -27.080000     1.230000  0.830000
# edge_JAN_PDE2_1345_set4_28055_protein_3   -44.790000     2.810000  2.320000
# edge_JAN_PDE2_1345_set4_287279_water_1     24.650000     2.760000  1.530000
# edge_JAN_PDE2_1345_set4_287279_protein_1    1.260000     3.480000  3.780000
# edge_JAN_PDE2_1345_set4_287279_water_2     21.760000     2.010000  1.620000
# edge_JAN_PDE2_1345_set4_287279_protein_2    2.960000    28.710000  1.250000
# edge_JAN_PDE2_1345_set4_287279_water_3     19.990000     2.030000  1.940000
# edge_JAN_PDE2_1345_set4_287279_protein_3   -0.700000    18.410000  1.540000
# edge_JAN_PDE2_1345_set4_204510_water_1    -59.370000     2.190000  1.310000
# edge_JAN_PDE2_1345_set4_204510_protein_1  -63.790000    25.540000  2.250000
# edge_JAN_PDE2_1345_set4_204510_water_2    -57.540000     1.480000  1.190000
# edge_JAN_PDE2_1345_set4_204510_protein_2  -76.320000    11.950000  1.540000
# edge_JAN_PDE2_1345_set4_204510_water_3    -59.380000     2.100000  1.470000
# edge_JAN_PDE2_1345_set4_204510_protein_3  -81.940000     2.840000  2.140000
# edge_JAN_PDE2_1345_set4_7467_water_1       -1.020000     1.710000  2.530000
# edge_JAN_PDE2_1345_set4_7467_protein_1    -10.960000     9.120000  1.290000
# edge_JAN_PDE2_1345_set4_7467_water_2       -7.020000     2.440000  1.860000
# edge_JAN_PDE2_1345_set4_7467_protein_2    -20.090000     2.620000  1.610000
# edge_JAN_PDE2_1345_set4_7467_water_3        0.330000     3.540000  1.530000
# edge_JAN_PDE2_1345_set4_7467_protein_3     -7.350000     7.510000  2.470000
# edge_JAN_PDE2_1345_set4_49408_water_1      26.010000     2.500000  1.220000
# edge_JAN_PDE2_1345_set4_49408_protein_1    10.730000    30.720000  1.450000
# edge_JAN_PDE2_1345_set4_49408_water_2      26.120000     2.010000  2.980000
# edge_JAN_PDE2_1345_set4_49408_protein_2     5.130000    12.630000  1.580000
# edge_JAN_PDE2_1345_set4_49408_water_3      29.840000     2.620000  2.650000
# edge_JAN_PDE2_1345_set4_49408_protein_3     7.870000    22.420000  1.500000
# edge_JAN_PDE2_1345_set4_318271_water_1     33.080000     2.790000  3.600000
# edge_JAN_PDE2_1345_set4_318271_protein_1    9.980000     9.970000  1.000000
# ...
# edge_JAN_PDE2_1345_set4_240139_water_1       80.0     80.0
# edge_JAN_PDE2_1345_set4_240139_protein_1     80.0     80.0
# edge_JAN_PDE2_1345_set4_240139_water_2       80.0     80.0
# edge_JAN_PDE2_1345_set4_240139_protein_2     80.0     80.0
# edge_JAN_PDE2_1345_set4_240139_water_3       80.0     80.0
# edge_JAN_PDE2_1345_set4_240139_protein_3     80.0     80.0
# edge_JAN_PDE2_1345_set4_190853_water_1       80.0     80.0
# edge_JAN_PDE2_1345_set4_190853_protein_1     80.0     80.0
# edge_JAN_PDE2_1345_set4_190853_water_2       80.0     80.0
# edge_JAN_PDE2_1345_set4_190853_protein_2     80.0     80.0
# edge_JAN_PDE2_1345_set4_190853_water_3       80.0     80.0
# edge_JAN_PDE2_1345_set4_190853_protein_3     80.0     80.0
# edge_JAN_PDE2_1345_set4_73446_water_1        80.0     80.0
# edge_JAN_PDE2_1345_set4_73446_protein_1      80.0     80.0
# edge_JAN_PDE2_1345_set4_73446_water_2        80.0     80.0
# edge_JAN_PDE2_1345_set4_73446_protein_2      80.0     80.0
# edge_JAN_PDE2_1345_set4_73446_water_3        80.0     80.0
# edge_JAN_PDE2_1345_set4_73446_protein_3      80.0     80.0
# edge_JAN_PDE2_1345_set4_190819_water_1       80.0     80.0
# edge_JAN_PDE2_1345_set4_190819_protein_1     80.0     80.0
# edge_JAN_PDE2_1345_set4_190819_water_2       80.0     80.0
# edge_JAN_PDE2_1345_set4_190819_protein_2     80.0     80.0
# edge_JAN_PDE2_1345_set4_190819_water_3       80.0     80.0
# edge_JAN_PDE2_1345_set4_190819_protein_3     80.0     80.0
# edge_JAN_PDE2_1345_set4_200833_water_1       80.0     80.0
# edge_JAN_PDE2_1345_set4_200833_protein_1     80.0     80.0
# edge_JAN_PDE2_1345_set4_200833_water_2       80.0     80.0
# edge_JAN_PDE2_1345_set4_200833_protein_2     80.0     80.0
# edge_JAN_PDE2_1345_set4_200833_water_3       80.0     80.0
# edge_JAN_PDE2_1345_set4_200833_protein_3     80.0     80.0
# edge_JAN_PDE2_1345_set4_295347_water_1       80.0     80.0
# edge_JAN_PDE2_1345_set4_295347_protein_1     80.0     80.0
# edge_JAN_PDE2_1345_set4_295347_water_2       80.0     80.0
# edge_JAN_PDE2_1345_set4_295347_protein_2     80.0     80.0
# edge_JAN_PDE2_1345_set4_295347_water_3       80.0     80.0
# edge_JAN_PDE2_1345_set4_295347_protein_3     80.0     80.0
# edge_JAN_PDE2_1345_set4_28055_water_1        80.0     80.0
# edge_JAN_PDE2_1345_set4_28055_protein_1      80.0     80.0
# edge_JAN_PDE2_1345_set4_28055_water_2        80.0     80.0
# edge_JAN_PDE2_1345_set4_28055_protein_2      80.0     80.0
# edge_JAN_PDE2_1345_set4_28055_water_3        80.0     80.0
# edge_JAN_PDE2_1345_set4_28055_protein_3      80.0     80.0
# edge_JAN_PDE2_1345_set4_287279_water_1       80.0     80.0
# edge_JAN_PDE2_1345_set4_287279_protein_1     80.0     80.0
# edge_JAN_PDE2_1345_set4_287279_water_2       80.0     80.0
# edge_JAN_PDE2_1345_set4_287279_protein_2     80.0     80.0
# edge_JAN_PDE2_1345_set4_287279_water_3       80.0     80.0
# edge_JAN_PDE2_1345_set4_287279_protein_3     80.0     80.0
# edge_JAN_PDE2_1345_set4_204510_water_1       80.0     80.0
# edge_JAN_PDE2_1345_set4_204510_protein_1     80.0     80.0
# edge_JAN_PDE2_1345_set4_204510_water_2       80.0     80.0
# edge_JAN_PDE2_1345_set4_204510_protein_2     80.0     80.0
# edge_JAN_PDE2_1345_set4_204510_water_3       80.0     80.0
# edge_JAN_PDE2_1345_set4_204510_protein_3     80.0     80.0
# edge_JAN_PDE2_1345_set4_7467_water_1         80.0     80.0
# edge_JAN_PDE2_1345_set4_7467_protein_1       80.0     80.0
# edge_JAN_PDE2_1345_set4_7467_water_2         80.0     80.0
# edge_JAN_PDE2_1345_set4_7467_protein_2       80.0     80.0
# edge_JAN_PDE2_1345_set4_7467_water_3         80.0     80.0
# edge_JAN_PDE2_1345_set4_7467_protein_3       80.0     80.0
# edge_JAN_PDE2_1345_set4_49408_water_1        80.0     80.0
# edge_JAN_PDE2_1345_set4_49408_protein_1      80.0     80.0
# edge_JAN_PDE2_1345_set4_49408_water_2        80.0     80.0
# edge_JAN_PDE2_1345_set4_49408_protein_2      80.0     80.0
# edge_JAN_PDE2_1345_set4_49408_water_3        80.0     80.0
# edge_JAN_PDE2_1345_set4_49408_protein_3      80.0     80.0
# edge_JAN_PDE2_1345_set4_318271_water_1       80.0     80.0
# edge_JAN_PDE2_1345_set4_318271_protein_1     80.0     80.0
# edge_JAN_PDE2_1345_set4_318271_water_2       80.0     80.0
# edge_JAN_PDE2_1345_set4_318271_protein_2     80.0     80.0
# edge_JAN_PDE2_1345_set4_318271_water_3       80.0     80.0
# edge_JAN_PDE2_1345_set4_318271_protein_3     80.0     80.0
# edge_JAN_PDE2_1345_set4_7276_water_1         80.0     80.0
# edge_JAN_PDE2_1345_set4_7276_protein_1       80.0     80.0
# edge_JAN_PDE2_1345_set4_7276_water_2         80.0     80.0
# edge_JAN_PDE2_1345_set4_7276_protein_2       80.0     80.0
# edge_JAN_PDE2_1345_set4_7276_water_3         80.0     80.0
# edge_JAN_PDE2_1345_set4_7276_protein_3       80.0     80.0
# edge_JAN_PDE2_1345_set4_43306_water_1        80.0     80.0
# edge_JAN_PDE2_1345_set4_43306_protein_1      80.0     80.0
# edge_JAN_PDE2_1345_set4_43306_water_2        80.0     80.0
# edge_JAN_PDE2_1345_set4_43306_protein_2      80.0     80.0
# edge_JAN_PDE2_1345_set4_43306_water_3        80.0     80.0
# edge_JAN_PDE2_1345_set4_43306_protein_3      80.0     80.0
# edge_JAN_PDE2_1345_set4_287340_water_1       80.0     80.0
# edge_JAN_PDE2_1345_set4_287340_protein_1     80.0     80.0
# edge_JAN_PDE2_1345_set4_287340_water_2       80.0     80.0
# edge_JAN_PDE2_1345_set4_287340_protein_2     80.0     80.0
# edge_JAN_PDE2_1345_set4_287340_water_3       80.0     80.0
# edge_JAN_PDE2_1345_set4_287340_protein_3     80.0     80.0
# edge_JAN_PDE2_1345_set4_12308_water_1        80.0     80.0
# edge_JAN_PDE2_1345_set4_12308_protein_1      80.0     80.0
# edge_JAN_PDE2_1345_set4_12308_water_2        80.0     80.0
# edge_JAN_PDE2_1345_set4_12308_protein_2      80.0     80.0
# edge_JAN_PDE2_1345_set4_12308_water_3        80.0     80.0
# edge_JAN_PDE2_1345_set4_12308_protein_3      80.0     80.0
# edge_JAN_PDE2_1345_set4_314311_water          NaN      NaN
# edge_JAN_PDE2_1345_set4_314311_protein        NaN      NaN
# edge_JAN_PDE2_1345_set4_46560_water           NaN      NaN
# edge_JAN_PDE2_1345_set4_46560_protein         NaN      NaN
# edge_JAN_PDE2_1345_set4_204487_water          NaN      NaN
# edge_JAN_PDE2_1345_set4_204487_protein        NaN      NaN
# edge_JAN_PDE2_1345_set4_72643_water           NaN      NaN
# edge_JAN_PDE2_1345_set4_72643_protein         NaN      NaN
# edge_JAN_PDE2_1345_set4_186054_water          NaN      NaN
# edge_JAN_PDE2_1345_set4_186054_protein        NaN      NaN
# edge_JAN_PDE2_1345_set4_72600_water           NaN      NaN
# edge_JAN_PDE2_1345_set4_72600_protein         NaN      NaN
# edge_JAN_PDE2_1345_set4_73007_water           NaN      NaN
# edge_JAN_PDE2_1345_set4_73007_protein         NaN      NaN
# edge_JAN_PDE2_1345_set4_190807_water          NaN      NaN
# edge_JAN_PDE2_1345_set4_190807_protein        NaN      NaN
# edge_JAN_PDE2_1345_set4_73724_water           NaN      NaN
# edge_JAN_PDE2_1345_set4_73724_protein         NaN      NaN
# edge_JAN_PDE2_1345_set4_316574_water          NaN      NaN
# edge_JAN_PDE2_1345_set4_316574_protein        NaN      NaN
# edge_JAN_PDE2_1345_set4_187035_water          NaN      NaN
# edge_JAN_PDE2_1345_set4_187035_protein        NaN      NaN
# edge_JAN_PDE2_1345_set4_73153_water           NaN      NaN
# edge_JAN_PDE2_1345_set4_73153_protein         NaN      NaN
# edge_JAN_PDE2_1345_set4_318340_water          NaN      NaN
# edge_JAN_PDE2_1345_set4_318340_protein        NaN      NaN
# edge_JAN_PDE2_1345_set4_71992_water           NaN      NaN
# edge_JAN_PDE2_1345_set4_71992_protein         NaN      NaN
# edge_JAN_PDE2_1345_set4_121458_water          NaN      NaN
# edge_JAN_PDE2_1345_set4_121458_protein        NaN      NaN
# edge_JAN_PDE2_1345_set4_287108_water          NaN      NaN
# edge_JAN_PDE2_1345_set4_287108_protein        NaN      NaN
# edge_JAN_PDE2_1345_set4_358538_water          NaN      NaN
# edge_JAN_PDE2_1345_set4_358538_protein        NaN      NaN
# edge_JAN_PDE2_1345_set4_204316_water          NaN      NaN
# edge_JAN_PDE2_1345_set4_204316_protein        NaN      NaN
# edge_JAN_PDE2_1345_set4_315054_water          NaN      NaN
# edge_JAN_PDE2_1345_set4_315054_protein        NaN      NaN
# edge_JAN_PDE2_1345_set4_7468_water            NaN      NaN
# edge_JAN_PDE2_1345_set4_7468_protein          NaN      NaN
# edge_JAN_PDE2_1345_set4_121456_water          NaN      NaN
# edge_JAN_PDE2_1345_set4_121456_protein        NaN      NaN
# edge_JAN_PDE2_1345_set4_204440_water          NaN      NaN
# edge_JAN_PDE2_1345_set4_204440_protein        NaN      NaN
# edge_JAN_PDE2_1345_set4_315055_water          NaN      NaN
# edge_JAN_PDE2_1345_set4_315055_protein        NaN      NaN
# edge_JAN_PDE2_1345_set4_200493_water          NaN      NaN
# edge_JAN_PDE2_1345_set4_200493_protein        NaN      NaN
# edge_JAN_PDE2_1345_set4_186899_water          NaN      NaN
# edge_JAN_PDE2_1345_set4_186899_protein        NaN      NaN
# edge_JAN_PDE2_1345_set4_122477_water          NaN      NaN
# edge_JAN_PDE2_1345_set4_122477_protein        NaN      NaN
# edge_JAN_PDE2_1345_set4_316584_water          NaN      NaN
# edge_JAN_PDE2_1345_set4_316584_protein        NaN      NaN
# edge_JAN_PDE2_1345_set4_122492_water          NaN      NaN
# edge_JAN_PDE2_1345_set4_122492_protein        NaN      NaN
# edge_JAN_PDE2_1345_set4_240165_water          NaN      NaN
# edge_JAN_PDE2_1345_set4_240165_protein        NaN      NaN
# edge_JAN_PDE2_1345_set4_358553_water          NaN      NaN
# edge_JAN_PDE2_1345_set4_358553_protein        NaN      NaN
# edge_JAN_PDE2_1345_set4_297010_water          NaN      NaN
# edge_JAN_PDE2_1345_set4_297010_protein        NaN      NaN
# edge_JAN_PDE2_1345_set4_240197_water          NaN      NaN
# edge_JAN_PDE2_1345_set4_240197_protein        NaN      NaN
# edge_JAN_PDE2_1345_set4_204476_water          NaN      NaN
# edge_JAN_PDE2_1345_set4_204476_protein        NaN      NaN
# edge_JAN_PDE2_1345_set4_282491_water          NaN      NaN
# edge_JAN_PDE2_1345_set4_282491_protein        NaN      NaN
# edge_JAN_PDE2_1345_set4_48416_water           NaN      NaN
# edge_JAN_PDE2_1345_set4_48416_protein         NaN      NaN
# edge_JAN_PDE2_1345_set4_240139_water          NaN      NaN
# edge_JAN_PDE2_1345_set4_240139_protein        NaN      NaN
# edge_JAN_PDE2_1345_set4_190853_water          NaN      NaN
# edge_JAN_PDE2_1345_set4_190853_protein        NaN      NaN
# edge_JAN_PDE2_1345_set4_73446_water           NaN      NaN
# edge_JAN_PDE2_1345_set4_73446_protein         NaN      NaN
# edge_JAN_PDE2_1345_set4_190819_water          NaN      NaN
# edge_JAN_PDE2_1345_set4_190819_protein        NaN      NaN
# edge_JAN_PDE2_1345_set4_200833_water          NaN      NaN
# edge_JAN_PDE2_1345_set4_200833_protein        NaN      NaN
# edge_JAN_PDE2_1345_set4_295347_water          NaN      NaN
# edge_JAN_PDE2_1345_set4_295347_protein        NaN      NaN
# edge_JAN_PDE2_1345_set4_28055_water           NaN      NaN
# edge_JAN_PDE2_1345_set4_28055_protein         NaN      NaN
# edge_JAN_PDE2_1345_set4_287279_water          NaN      NaN
# edge_JAN_PDE2_1345_set4_287279_protein        NaN      NaN
# edge_JAN_PDE2_1345_set4_204510_water          NaN      NaN
# edge_JAN_PDE2_1345_set4_204510_protein        NaN      NaN
# edge_JAN_PDE2_1345_set4_7467_water            NaN      NaN
# edge_JAN_PDE2_1345_set4_7467_protein          NaN      NaN
# edge_JAN_PDE2_1345_set4_49408_water           NaN      NaN
# edge_JAN_PDE2_1345_set4_49408_protein         NaN      NaN
# edge_JAN_PDE2_1345_set4_318271_water          NaN      NaN
# edge_JAN_PDE2_1345_set4_318271_protein        NaN      NaN
# edge_JAN_PDE2_1345_set4_7276_water            NaN      NaN
# edge_JAN_PDE2_1345_set4_7276_protein          NaN      NaN
# edge_JAN_PDE2_1345_set4_43306_water           NaN      NaN
# edge_JAN_PDE2_1345_set4_43306_protein         NaN      NaN
# edge_JAN_PDE2_1345_set4_287340_water          NaN      NaN
# edge_JAN_PDE2_1345_set4_287340_protein        NaN      NaN
# edge_JAN_PDE2_1345_set4_12308_water           NaN      NaN
# edge_JAN_PDE2_1345_set4_12308_protein         NaN      NaN
# edge_JAN_PDE2_1345_set4_39459_water_1        80.0     80.0
# edge_JAN_PDE2_1345_set4_39459_protein_1      80.0     80.0
# edge_JAN_PDE2_1345_set4_39459_water_2        80.0     80.0
# edge_JAN_PDE2_1345_set4_39459_protein_2      80.0     80.0
# edge_JAN_PDE2_1345_set4_39459_water_3        80.0     80.0
# edge_JAN_PDE2_1345_set4_39459_protein_3      80.0     80.0
# edge_JAN_PDE2_1345_set4_122463_water_1       80.0     80.0
# edge_JAN_PDE2_1345_set4_122463_protein_1     80.0     80.0
# edge_JAN_PDE2_1345_set4_122463_water_2       80.0     80.0
# edge_JAN_PDE2_1345_set4_122463_protein_2     80.0     80.0
# edge_JAN_PDE2_1345_set4_122463_water_3       80.0     80.0
# edge_JAN_PDE2_1345_set4_122463_protein_3     80.0     80.0
# edge_JAN_PDE2_1345_set4_49347_water_1        80.0     80.0
# edge_JAN_PDE2_1345_set4_49347_protein_1      80.0     80.0
# edge_JAN_PDE2_1345_set4_49347_water_2        80.0     80.0
# edge_JAN_PDE2_1345_set4_49347_protein_2      80.0     80.0
# edge_JAN_PDE2_1345_set4_49347_water_3        80.0     80.0
# edge_JAN_PDE2_1345_set4_49347_protein_3      80.0     80.0
# edge_JAN_PDE2_1345_set4_204435_water_1       80.0     80.0
# edge_JAN_PDE2_1345_set4_204435_protein_1     80.0     80.0
# edge_JAN_PDE2_1345_set4_204435_water_2       80.0     80.0
# edge_JAN_PDE2_1345_set4_204435_protein_2     80.0     80.0
# edge_JAN_PDE2_1345_set4_204435_water_3       80.0     80.0
# edge_JAN_PDE2_1345_set4_204435_protein_3     80.0     80.0
# edge_JAN_PDE2_1345_set4_287305_water_1       80.0     80.0
# edge_JAN_PDE2_1345_set4_287305_protein_1     80.0     80.0
# edge_JAN_PDE2_1345_set4_287305_water_2       80.0     80.0
# edge_JAN_PDE2_1345_set4_287305_protein_2     80.0     80.0
# edge_JAN_PDE2_1345_set4_287305_water_3       80.0     80.0
# edge_JAN_PDE2_1345_set4_287305_protein_3     80.0     80.0
# edge_JAN_PDE2_1345_set4_1830_water_1         80.0     80.0
# edge_JAN_PDE2_1345_set4_1830_protein_1       80.0     80.0
# edge_JAN_PDE2_1345_set4_1830_water_2         80.0     80.0
# edge_JAN_PDE2_1345_set4_1830_protein_2       80.0     80.0
# edge_JAN_PDE2_1345_set4_1830_water_3         80.0     80.0
# edge_JAN_PDE2_1345_set4_1830_protein_3       80.0     80.0
# edge_JAN_PDE2_1345_set4_315639_water_1       80.0     80.0
# edge_JAN_PDE2_1345_set4_315639_protein_1     80.0     80.0
# edge_JAN_PDE2_1345_set4_315639_water_2       80.0     80.0
# edge_JAN_PDE2_1345_set4_315639_protein_2     80.0     80.0
# edge_JAN_PDE2_1345_set4_315639_water_3       80.0     80.0
# edge_JAN_PDE2_1345_set4_315639_protein_3     80.0     80.0
# edge_JAN_PDE2_1345_set4_117342_water_1       80.0     80.0
# edge_JAN_PDE2_1345_set4_117342_protein_1     80.0     80.0
# edge_JAN_PDE2_1345_set4_117342_water_2       80.0     80.0
# edge_JAN_PDE2_1345_set4_117342_protein_2     80.0     80.0
# edge_JAN_PDE2_1345_set4_117342_water_3       80.0     80.0
# edge_JAN_PDE2_1345_set4_117342_protein_3     80.0     80.0
# edge_JAN_PDE2_1345_set4_39459_water           NaN      NaN
# edge_JAN_PDE2_1345_set4_39459_protein         NaN      NaN
# edge_JAN_PDE2_1345_set4_122463_water          NaN      NaN
# edge_JAN_PDE2_1345_set4_122463_protein        NaN      NaN
# edge_JAN_PDE2_1345_set4_49347_water           NaN      NaN
# edge_JAN_PDE2_1345_set4_49347_protein         NaN      NaN
# edge_JAN_PDE2_1345_set4_204435_water          NaN      NaN
# edge_JAN_PDE2_1345_set4_204435_protein        NaN      NaN
# edge_JAN_PDE2_1345_set4_287305_water          NaN      NaN
# edge_JAN_PDE2_1345_set4_287305_protein        NaN      NaN
# edge_JAN_PDE2_1345_set4_1830_water            NaN      NaN
# edge_JAN_PDE2_1345_set4_1830_protein          NaN      NaN
# edge_JAN_PDE2_1345_set4_315639_water          NaN      NaN
# edge_JAN_PDE2_1345_set4_315639_protein        NaN      NaN
# edge_JAN_PDE2_1345_set4_117342_water          NaN      NaN
# edge_JAN_PDE2_1345_set4_117342_protein        NaN      NaN

# %%
#fe.resultsSummary
with pd.option_context('display.max_rows', None, 'display.max_columns', None):  # more options can be specified also
    print(fe.resultsSummary)
# Out:
#                                       val  err_analyt  err_boot
# edge_JAN_PDE2_1345_set4_190778 -21.900000   46.946572  2.902950
# edge_JAN_PDE2_1345_set4_240291 -27.050000   13.986901  2.231087
# edge_JAN_PDE2_1345_set4_121483 -23.030000   15.704959  2.607107
# edge_JAN_PDE2_1345_set4_190914 -25.803333   16.202751  2.371088
# edge_JAN_PDE2_1345_set4_73008  -13.850000    4.322855  4.211643
# edge_JAN_PDE2_1345_set4_190882 -17.766667   14.115536  2.761888
# edge_JAN_PDE2_1345_set4_188271 -15.720000   50.563621  3.761048
# edge_JAN_PDE2_1345_set4_26471  -16.800000    3.729989  3.665548
# edge_JAN_PDE2_1345_set4_73813  -12.106667   11.160609  6.247732
# edge_JAN_PDE2_1345_set4_121481 -18.820000    6.433415  2.889698
# edge_JAN_PDE2_1345_set4_376385 -13.306667   21.728902  1.865507
# edge_JAN_PDE2_1345_set4_204497 -27.786667    3.480336  2.218186
# edge_JAN_PDE2_1345_set4_71401  -17.806667    4.251823  3.794771
# edge_JAN_PDE2_1345_set4_73883  -20.323333   10.156344  2.144109
# edge_JAN_PDE2_1345_set4_202087 -20.400000   20.833615  3.962465
# edge_JAN_PDE2_1345_set4_357530 -17.636667   96.698956  6.004466
# edge_JAN_PDE2_1345_set4_72639  -12.853333    9.763958  3.696241
# edge_JAN_PDE2_1345_set4_190844 -22.070000    9.238445  3.774519
# edge_JAN_PDE2_1345_set4_316733 -12.523333    8.077698  3.424775
# edge_JAN_PDE2_1345_set4_287307 -21.446667   11.220052  3.201266
# edge_JAN_PDE2_1345_set4_9233   -15.516667   10.539303  3.321022
# edge_JAN_PDE2_1345_set4_239416 -14.836667    7.876897  3.144019
# edge_JAN_PDE2_1345_set4_49417  -15.123333    3.303513  3.175713
# edge_JAN_PDE2_1345_set4_73375  -16.953333    3.686614  3.147864
# edge_JAN_PDE2_1345_set4_204549 -17.226667  363.771315  3.995894
# edge_JAN_PDE2_1345_set4_122460 -29.093333   21.678050  2.952873
# edge_JAN_PDE2_1345_set4_315931 -14.620000   22.924910  2.348956
# edge_JAN_PDE2_1345_set4_46739  -25.996667   35.649344  3.783805
# edge_JAN_PDE2_1345_set4_44746  -18.643333    4.059852  2.589806
# edge_JAN_PDE2_1345_set4_190886 -24.583333   28.132865  2.151884
# edge_JAN_PDE2_1345_set4_318412 -18.070000   21.071283  3.625263
# edge_JAN_PDE2_1345_set4_200839 -21.610000   12.917269  4.230230
# edge_JAN_PDE2_1345_set4_200519 -18.793333   14.243638  4.864298
# edge_JAN_PDE2_1345_set4_204450 -12.120000    4.968531  4.860235
# edge_JAN_PDE2_1345_set4_122489 -25.113333   32.791340  2.098584
# edge_JAN_PDE2_1345_set4_73781  -12.890000   47.396937  3.914492
# edge_JAN_PDE2_1345_set4_12907  -15.436667   17.533906  3.238602
# edge_JAN_PDE2_1345_set4_237843 -14.893333  104.092308  3.896116
# edge_JAN_PDE2_1345_set4_49395  -23.863333    7.895178  3.416242
# edge_JAN_PDE2_1345_set4_120342 -18.540000   37.368628  3.854723
# edge_JAN_PDE2_1345_set4_46563  -21.036667    5.975959  5.490383
# edge_JAN_PDE2_1345_set4_314311 -13.316667   15.299172  3.574743
# edge_JAN_PDE2_1345_set4_46560  -17.086667    4.534861  3.768654
# edge_JAN_PDE2_1345_set4_204487 -16.040000    7.494276  3.257150
# edge_JAN_PDE2_1345_set4_72643  -18.020000    2.887336  2.704897
# edge_JAN_PDE2_1345_set4_186054  -9.226667   16.238153  2.452071
# edge_JAN_PDE2_1345_set4_72600  -17.366667    7.632790  1.908723
# edge_JAN_PDE2_1345_set4_73007   -9.033333   10.753327  5.417913
# edge_JAN_PDE2_1345_set4_190807 -13.480000   10.924103  4.231061
# edge_JAN_PDE2_1345_set4_73724  -14.366667    4.267436  2.231624
# edge_JAN_PDE2_1345_set4_316574 -20.383333    6.931143  3.855213
# edge_JAN_PDE2_1345_set4_187035 -13.843333   17.718262  4.488311
# edge_JAN_PDE2_1345_set4_73153  -14.883333   12.376822  5.031880
# edge_JAN_PDE2_1345_set4_318340 -18.916667    3.042985  3.497247
# edge_JAN_PDE2_1345_set4_71992  -12.450000   18.044733  3.953965
# edge_JAN_PDE2_1345_set4_121458 -16.190000   20.820037  3.606265
# edge_JAN_PDE2_1345_set4_287108 -20.906667    6.137657  3.090667
# edge_JAN_PDE2_1345_set4_358538 -22.003333   15.038376  2.124199
# edge_JAN_PDE2_1345_set4_204316 -21.643333   10.044791  2.204087
# edge_JAN_PDE2_1345_set4_315054 -17.540000    3.511348  1.978191
# edge_JAN_PDE2_1345_set4_7468   -18.080000    4.936941  3.152321
# edge_JAN_PDE2_1345_set4_121456 -22.103333   58.683071  2.697574
# edge_JAN_PDE2_1345_set4_204440 -16.276667    8.585421  2.681140
# edge_JAN_PDE2_1345_set4_315055 -14.526667   48.205060  3.324409
# edge_JAN_PDE2_1345_set4_200493 -24.106667   15.045115  3.291861
# edge_JAN_PDE2_1345_set4_186899 -19.876667   31.907456  3.572784
# edge_JAN_PDE2_1345_set4_122477 -27.210000    9.431880  2.425045
# edge_JAN_PDE2_1345_set4_316584 -13.293333   30.746393  1.768790
# edge_JAN_PDE2_1345_set4_122492 -18.873333    5.899594  3.470258
# edge_JAN_PDE2_1345_set4_240165 -15.896667    4.711933  4.538470
# edge_JAN_PDE2_1345_set4_358553 -11.926667   21.085649  5.393522
# edge_JAN_PDE2_1345_set4_297010 -12.936667    4.283936  3.410645
# edge_JAN_PDE2_1345_set4_240197 -18.920000  196.363736  3.606572
# edge_JAN_PDE2_1345_set4_204476 -15.963333   27.606019  2.724504
# edge_JAN_PDE2_1345_set4_282491  -8.683333  102.904045  3.246445
# edge_JAN_PDE2_1345_set4_48416  -11.096667   13.390990  5.132294
# edge_JAN_PDE2_1345_set4_240139 -18.410000   45.486325  3.938675
# edge_JAN_PDE2_1345_set4_190853 -16.966667    3.473571  3.045790
# edge_JAN_PDE2_1345_set4_73446  -11.780000    8.038499  4.818569
# edge_JAN_PDE2_1345_set4_190819 -21.840000    6.095532  2.839911
# edge_JAN_PDE2_1345_set4_200833 -17.673333    5.944295  2.556389
# edge_JAN_PDE2_1345_set4_295347 -16.210000   11.278138  4.390062
# edge_JAN_PDE2_1345_set4_28055  -16.930000   15.810919  1.934839
# edge_JAN_PDE2_1345_set4_287279 -20.960000   11.248604  2.251145
# edge_JAN_PDE2_1345_set4_204510 -15.253333   10.430900  4.628844
# edge_JAN_PDE2_1345_set4_7467   -10.230000    5.651815  3.933498
# edge_JAN_PDE2_1345_set4_49408  -19.413333   13.559380  2.345308
# edge_JAN_PDE2_1345_set4_318271 -23.603333   24.214516  2.135056
# edge_JAN_PDE2_1345_set4_7276   -17.206667    9.338786  2.932490
# edge_JAN_PDE2_1345_set4_43306  -10.723333   19.652076  4.664132
# edge_JAN_PDE2_1345_set4_287340 -16.090000   17.053611  3.371420
# edge_JAN_PDE2_1345_set4_12308  -18.290000   30.158897  5.282233
# edge_JAN_PDE2_1345_set4_39459   -7.676667   54.755318  3.482027
# edge_JAN_PDE2_1345_set4_122463 -17.966667   15.414531  3.659909
# edge_JAN_PDE2_1345_set4_49347  -15.443333    2.133423  1.515363
# edge_JAN_PDE2_1345_set4_204435 -14.426667    3.823648  3.631004
# edge_JAN_PDE2_1345_set4_287305 -28.503333   18.422890  3.329558
# edge_JAN_PDE2_1345_set4_1830   -11.450000   28.746255  4.366161
# edge_JAN_PDE2_1345_set4_315639 -14.660000    3.620967  3.050953
# edge_JAN_PDE2_1345_set4_117342 -10.836667   12.760827  3.068078

# %%
def grid_mols_with_annotation(mols, labels, sub_img_size=(250,250), mols_per_row=10, title="", annotation_size=22, title_size=25, y_offset=-20):
    """Annotates a MolsToGridImage given a set of labels for each mol with better font size options and title"""
    
    img = Chem.Draw.MolsToGridImage(mols, molsPerRow=mols_per_row, subImgSize=sub_img_size, maxMols=len(mols), returnPNG=False)
    
    fig, ax = plt.subplots(figsize=(40,40))
    plt.title(title, fontsize=title_size)
    text_pos = (sub_img_size[0]/2, sub_img_size[1]+y_offset)
    pos_ctr = 0
    plt.axis("off")
    for cmpd_text in labels:
        plt.annotate(cmpd_text, text_pos, fontsize=annotation_size, horizontalalignment='center')
        pos_ctr += 1
        text_pos = (text_pos[0]+sub_img_size[0], text_pos[1])
        if (pos_ctr % mols_per_row) == 0:
            text_pos = (sub_img_size[0]/2, text_pos[1] + sub_img_size[1])

    ax.imshow(img, origin="upper")

# %%
cutoff_ddg=-16

cal2J = 4.184
def lig_to_dG(lig):
    RT=0.001985875*300 #kcal/mol
    return(-RT*float(lig.GetProp('[V] hPDE2_pIC50'))*np.log(10))
red_dG=lig_to_dG(reference_lig)

tight_binders=[]
legends=[]
tight_dGs=[]
for i,l in enumerate(test_ligs):
    edge=f"edge_JAN_PDE2_1345_{l.GetProp('ID')}"
    if(edge in finished_edges):
        val=fe.resultsSummary.at[edge,'val']
        uncert=fe.resultsSummary.at[edge,'err_boot']
#         if(val<cutoff_ddg):
        tight_binders.append(Chem.MolFromSmiles(Chem.MolToSmiles(l)))
        legends.append(f"{l.GetProp('ID')},\nddG={val:.2f}+-{uncert:.2f} kJ/mol\ndG={fe.resultsSummary.loc[edge,'val']/cal2J + red_dG: .2f}+-{uncert/cal2J:.2f} kcal/mol")
        tight_dGs.append(fe.resultsSummary.loc[edge,'val']/cal2J + red_dG)
order=np.argsort(tight_dGs)
            
# Draw.MolsToGridImage([tight_binders[i] for i in order],
#                      legends=[legends[i] for i in order],
#                      subImgSize = (200,200), molsPerRow=5, maxMols=101)

   
grid_mols_with_annotation([tight_binders[i] for i in order], [legends[i] for i in order],
                     sub_img_size =(200,200), mols_per_row=10, y_offset=-5)

# %%
print(len(tight_binders))
# Out:
# 100

# %%
from rdkit.Chem import rdRGroupDecomposition as rdRGD
from contextlib import contextmanager,redirect_stderr,redirect_stdout
from os import devnull
@contextmanager
def suppress_stdout_stderr():
    """A context manager that redirects stdout and stderr to devnull"""
    with open(devnull, 'w') as fnull:
        with redirect_stderr(fnull) as err, redirect_stdout(fnull) as out:
            yield (err, out)

ordered_ligs_Rgroup_only=[]

core_smiles="c7(C)nc8ccccc8n8c(c6c(Cl)[cH][cH][cH][cH]6)nnc78"
core=Chem.MolFromSmiles(core_smiles)

with suppress_stdout_stderr():
    res,unmatched = rdRGD.RGroupDecompose([core], [tight_binders[i] for i in order], asSmiles=True)# print(unmatched)
if(len(unmatched)>0):
    raise()

for i,l in enumerate(res):
    new_l={}
    for rg in l:
        if rg=='Core':
            continue;
        if l[rg][:3]!='[H]':
            new_l[rg]=l[rg]
    if(len(new_l)==1):
        Rgroup_smi=new_l['R1']
        smi_params=Chem.rdmolfiles.SmilesParserParams()
        smi_params.removeHs=True
        Rgroup=Chem.AddHs(Chem.MolFromSmiles(Rgroup_smi))
        Rgroup_smi=Chem.MolToSmiles(Rgroup)
#         Rgroup_smi=Rgroup_smi.replace("[*:1]", "[*:R_2]")
#         Rgroup_smi=Rgroup_smi.replace("()", "")
        Rgroup=Chem.MolFromSmiles(Rgroup_smi, smi_params)

        for i in range(Rgroup.GetNumAtoms()):
            symb=Rgroup.GetAtomWithIdx(i).GetSymbol()
            if(symb=="*"):
                Rgroup.GetAtomWithIdx(i).SetProp("_displayLabel","R<sub>core</sub>")

        ordered_ligs_Rgroup_only.append(Chem.PropertyMol.PropertyMol(Rgroup))

# %%
grid_mols_with_annotation(ordered_ligs_Rgroup_only[:5],
                 labels=[legends[i] for i in order[:5]],
                 sub_img_size = (200,200), mols_per_row=5, annotation_size=25, y_offset=-25)

# %% [markdown]
# ### save preliminary results for finished ligands

# %%
# cal2J = 4.184
# def lig_to_dG(lig):
#     RT=0.001985875*300 #kcal/mol
#     return(-RT*float(lig.GetProp('[V] hPDE2_pIC50'))*np.log(10))
# red_dG=lig_to_dG(reference_lig)

# save_ligs=[]
# for edge in fe.resultsSummary.index:
#     ligname=edge[19:]
#     for lig in test_ligs:
#         if lig.GetProp('ID')==ligname:
#             lig.SetProp("ddG", str(fe.resultsSummary.loc[edge,'val']/cal2J) ) # kcal/mol
#             lig.SetProp("dG", str(fe.resultsSummary.loc[edge,'val']/cal2J + red_dG) ) # kcal/mol
#             lig.SetProp("dG_err", str(fe.resultsSummary.loc[edge,'err_boot']/cal2J) )  # kcal/mol
#             save_ligs.append(PropertyMol.PropertyMol(lig))
            
# print(len(save_ligs))

# fname="finished_ligs_prelim.pickle"

# with  open( fname, "wb" ) as f:
#     pickle.dump(save_ligs, f)

# %% [markdown]
# # save the stable ligs as a pickle for training

# %%
cal2J = 4.184
def lig_to_dG(lig):
    RT=0.001985875*300 #kcal/mol
    return(-RT*float(lig.GetProp('[V] hPDE2_pIC50'))*np.log(10))
red_dG=lig_to_dG(reference_lig)

save_ligs=[]
for edge in fe.resultsSummary.index:
    ligname=edge[19:]
    for lig in test_ligs:
        if lig.GetProp('ID')==ligname:
            lig.SetProp("ddG", str(fe.resultsSummary.loc[edge,'val']/cal2J) ) # kcal/mol
            lig.SetProp("dG", str(fe.resultsSummary.loc[edge,'val']/cal2J + red_dG) ) # kcal/mol
            lig.SetProp("dG_err", str(fe.resultsSummary.loc[edge,'err_boot']/cal2J) )  # kcal/mol
            save_ligs.append(PropertyMol.PropertyMol(lig))
            
print(len(save_ligs))

fname="stable_ligs.pickle"

with  open( fname, "wb" ) as f:
    pickle.dump(save_ligs, f)
# Out:
# 100

# %%
# cal2J = 4.184
# def lig_to_dG(lig):
#     RT=0.001985875*300 #kcal/mol
#     return(-RT*float(lig.GetProp('[V] hPDE2_pIC50'))*np.log(10))

# print(f"ref lig dG: {lig_to_dG(reference_lig)} kcal/mol")

# %%
# # fix the saved ligands' dG values
# fname="stable_ligs.pickle"
# with open(fname, 'rb') as f:
#     save_ligs = pickle.load(f)
    
# red_dG=lig_to_dG(reference_lig)
    
# for i,lig in enumerate(save_ligs):
#     ddG=float(lig.GetProp("ddG"))
#     lig.SetProp("dG", str(ddG + red_dG) ) # kcal/mol
#     save_ligs[i]=PropertyMol.PropertyMol(lig)
    
# fname="stable_ligs_fixed_dG.pickle"
# with  open( fname, "wb" ) as f:
#     pickle.dump(save_ligs, f)

# %% [markdown]
# # Also write dG value into the big 34K lig DB pickle file

# %%
all_ligs_db_file=f"{pocket_fit_folder}/filtered_subset_without_weird_chemistry_with_2D_no_core_tSNE_and_step4_dG.pickle"
with open(all_ligs_db_file, 'rb') as f:
    ligs_set4f = pickle.load(f)
    
with open("stable_ligs.pickle", 'rb') as f:
# with open("finished_ligs_prelim.pickle", 'rb') as f:
    step_known_ligs = pickle.load(f)

known_lig_idxs_in_set4f=[]
known_lig_idxs_in_step=[]
known_lig_idxs=[l.GetProp('ID') for l in step_known_ligs]
for i,lig in enumerate(ligs_set4f):
    if(lig.GetProp('ID') in known_lig_idxs):
        known_lig_idxs_in_set4f.append(i)
        known_lig_idxs_in_step.append(known_lig_idxs.index(lig.GetProp('ID')))

# %%
print(known_lig_idxs_in_step)
print(known_lig_idxs_in_set4f)
# Out:
# [97, 88, 85, 60, 20, 91, 36, 7, 82, 92, 89, 28, 42, 40, 27, 75, 94, 38, 86, 22, 12, 54, 46, 16, 44, 47, 4, 52, 23, 78, 49, 35, 8, 13, 99, 39, 61, 55, 9, 2, 25, 93, 66, 34, 68, 45, 65, 51, 6, 0, 48, 79, 17, 77, 5, 29, 3, 64, 32, 80, 31, 14, 58, 95, 62, 33, 73, 43, 11, 84, 24, 37, 21, 76, 69, 72, 1, 74, 56, 83, 96, 19, 90, 81, 71, 41, 59, 63, 98, 26, 50, 67, 18, 87, 53, 30, 15, 57, 70, 10]
# [932, 3085, 3219, 3220, 3940, 4950, 5114, 9210, 9537, 9858, 11075, 11845, 12548, 12551, 12613, 12930, 13287, 13331, 13344, 13353, 13853, 13978, 14077, 14079, 14082, 14129, 14130, 14147, 14173, 14178, 14203, 14241, 14259, 14263, 14624, 15144, 15196, 15197, 15199, 15200, 15400, 15402, 15412, 15417, 15419, 20814, 20906, 20918, 21006, 21078, 21094, 21100, 21103, 21105, 21124, 21125, 21130, 21158, 21171, 21264, 21266, 21401, 21500, 21525, 21528, 21531, 21549, 21557, 21563, 21568, 21595, 22468, 22488, 22522, 22525, 22541, 22567, 26949, 27164, 27205, 27209, 27210, 27225, 27547, 27567, 27777, 27854, 27855, 27941, 27953, 27998, 27999, 28007, 28012, 28027, 28032, 30333, 30555, 30562, 32518]

# %%
for i in range(len(known_lig_idxs_in_step)):
    idx_step=known_lig_idxs_in_step[i]
    idx_set4f=known_lig_idxs_in_set4f[i]
    
    #print(idx_step0, idx_set4f)
    
    old_lig=step_known_ligs[idx_step]
    new_lig=ligs_set4f[idx_set4f]
    

    new_lig.SetProp("ddG", old_lig.GetProp("ddG") ) # kcal/mol
    new_lig.SetProp("dG", old_lig.GetProp("dG") ) # kcal/mol
    new_lig.SetProp("dG_err", old_lig.GetProp("dG_err") ) # kcal/mol
    
    ligs_set4f[idx_set4f]=PropertyMol.PropertyMol(new_lig)

fname=f"{pocket_fit_folder}/filtered_subset_without_weird_chemistry_with_2D_no_core_tSNE_and_step5_dG.pickle"
with  open( fname, "wb" ) as f:
    pickle.dump(ligs_set4f, f)
    
del ligs_set4f

# %%
all_no_core_ligs_db_file=f"{pocket_fit_folder}/filtered_subset_without_weird_chemistry_no_core_ligs_with_step4_dG.pickle"

with open(all_no_core_ligs_db_file, 'rb') as f:
    no_core_ligs_set4f = pickle.load(f)
    
    
for i in range(len(known_lig_idxs_in_step)):
    idx_step=known_lig_idxs_in_step[i]
    idx_set4f=known_lig_idxs_in_set4f[i]
    
    #print(idx_step, idx_set4f)
    
    old_lig=step_known_ligs[idx_step]
    new_lig=no_core_ligs_set4f[idx_set4f]
    

    new_lig.SetProp("ddG", old_lig.GetProp("ddG") ) # kcal/mol
    new_lig.SetProp("dG", old_lig.GetProp("dG") ) # kcal/mol
    new_lig.SetProp("dG_err", old_lig.GetProp("dG_err") ) # kcal/mol
    
    no_core_ligs_set4f[idx_set4f]=PropertyMol.PropertyMol(new_lig)
    
fname=f"{pocket_fit_folder}/filtered_subset_without_weird_chemistry_no_core_ligs_with_step5_dG.pickle"
with  open( fname, "wb" ) as f:
    pickle.dump(no_core_ligs_set4f, f)
    
del no_core_ligs_set4f
